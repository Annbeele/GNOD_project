# %% [markdown]
# ## Web Scraping Lab 1:
#
#
# ### Prepare your project:
#
# #### Business goal:
#
# Make sure you've understood the big picture of your project: the goal of the company (Gnod), their current product (Gnoosic), their strategy, and how your project fits into this context. Re-read the business case and the e-mail from the CTO, take a look at the flowchart and create an initial Trello board with the tasks you think you'll have to acomplish.
#
# #### Scraping popular songs:
#
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputed song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# You have find data on the internet about currently popular songs. Billboard mantains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import random

# 2. find url and store it in avariable
url = "https://www.billboard.com/charts/hot-100"

# 3. download html with a get request
response = requests.get(url)

# %%
#check response status code 
response.status_code
# Out:
# 200

# %%
#parse and store the contents of the url call
soup=BeautifulSoup(response.content, 'html.parser')

# %%
#prettify the soup 
# jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 
print(soup.prettify)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#Miguel's solution: using CSS

songs = soup.select('button > span.chart-element__information > span.chart-element__information__song.text--truncate.color--primary')

# %%
titles=[]
artists=[]

for i in soup.find_all('span', {'class':'chart-element__information__song'}):
    titles.append(i.get_text())

for i in soup.find_all('span', {'class':'chart-element__information__artist'}):
    artists.append(i.get_text())

# %%
len(titles)
# Out:
# 100

# %%
len(artists)
# Out:
# 100

# %%
top_100_hot_songs=pd.DataFrame({'Title':titles, 'Artist':artists})

# %%
top_100_hot_songs
# Out:
#                              Title  \
# 0                           Butter
# 1                         Good 4 U
# 2                       Levitating
# 3                     Kiss Me More
# 4   Montero (Call Me By Your Name)
# ..                             ...
# 95               All I Know So Far
# 96                     What's Next
# 97                  Enough For You
# 98                      Juggernaut
# 99                         Tell Em
#
#                                                Artist
# 0                                                 BTS
# 1                                      Olivia Rodrigo
# 2                           Dua Lipa Featuring DaBaby
# 3                              Doja Cat Featuring SZA
# 4                                           Lil Nas X
# ..                                                ...
# 95                                               P!nk
# 96                                              Drake
# 97                                     Olivia Rodrigo
# 98  Tyler, The Creator Featuring Lil Uzi Vert & Ph...
# 99                                     Cochise & $NOT
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Bonus

# %% [markdown]
# Can you find other websites with lists of "hot" songs? What about songs that were popular on a certain decade?
#
# You can scrape more lists and add extra features to the project.

# %%
#create another column with age 2010 and then append rows from other scrapped charts
#and make entries: top 2001 x exemple. Thats one way

#another in which charts the songs have appeared?

#no podem posar current per les de ara xq llavors es torna un objecte, un string.
#If these borads release every month podem posar the date of the release

# %%
# 2. find url and store it in avariable
url = "http://www.discjockey.org/top-100-songs-of-the-1980s/"

# 3. download html with a get request
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
#parse and store the contents of the url call
soup2=BeautifulSoup(response.content, 'html.parser')

# %%
#prettify the soup
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <title>
#    Top 100 Songs of the 1980s - Chicago DJ Fourth Estate Audio
#   </title>
#   <meta content="Top 100 songs of the 1980s - Chicago DJ Fourth Estate Audio" name="description"/>
#   <meta content="Chicago DJ Fourth Estate Audio Presents the Top Songs of the 1980s" name="keywords"/>
#   Chicago DJ,Chicago Wedding DJ,Fourth Estate Audio,Top Songs of the 1980s
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="p0oIwbkp79V1fHXzfr6krKOff3OLHM1I3VUKcHEQx4c" name="google-site-verification"/>
#   <script src="/site/template/assets/functions.js">
#   </script>
#   <script src="/site/template/assets/rollover.js">
#   </script>
#   <script src="/site/epage/assets/newwindow.js">
#   </script>
#   <link href="/site/template/assets/home_template_fourthestate_895/css/template0.css?v=2" id="templatecss" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/assets/home_template_fourthestate_895/css/layout0.css?v=2" id="layoutcss" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/modules/cssx/modules895.css" id="modulescss" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/modules/cssx/modules895.css" id="modulescssprint1" media="print" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/assets/home_template_fourthestate_895/css/instance.css?v=2" id="instancecss" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/assets/home_template_fourthestate_895/css/print0.css?v=2" id="printcss" media="print" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/modules/css/print.css" id="modulescssprint2" media="print" rel="stylesheet" type="text/css"/>
#   <link href="/site/template/assets/home_template_fourthestate_895/favicon.ico" rel="shortcut icon"/>
#   <!-- ClickTale Top part -->
#   <script type="text/javascript">
#    var WRInitTime=(new Date()).getTime();
#   </script>
#   <!-- ClickTale end of Top part -->
#   <script src="/site/template/assets/scripts/ultimatefade_caption.js" type="text/javascript">
#   </script>
#   <script src="https://code.jquery.com/jquery-2.1.4.min.js" type="text/javascript">
#   </script>
#   <script src="/site/template/assets/scripts/jquery/cycle/jquery.cycle.all.min.js" type="text/javascript">
#   </script>
#   <script src="/site/template/assets/scripts/responsive_lightbox/jquery.lightbox.min.js" type="text/javascript">
#   </script>
#   <link href="/site/template/assets/scripts/responsive_lightbox/jquery.lightbox.min.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    $(document).ready(function() {
#
#         $(".photo-thumb-link").lightbox();$(".comp-slideshow-03 p a").lightbox();
#         $(".comp-slideshow-03 br").remove();
#
#         var viewportWidth = $(window).width();
#         if(viewportWidth >= 800){
#             $("#homeslider").html('<video width="400" height="150" autoplay muted loop><source src="https://discjockey.s3.us-east-2.amazonaws.com/masthead_video_small.mp4" type="video/mp4"></video>');
#         }
#
#     });
#   </script>
#   <script>
#    $(document).ready(function(){$("#tabs-menu a").click(function(){$("#nav").slideToggle("200")})});
#   </script>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#  </head>
#  <body class="tab91355 itemlevel3 parent91357" id="item94069">
#   <div id="wrap">
#    <div id="header">
#     <div id="logo">
#      <a href="/">
#       <img alt="Fourth Estate Audio" border="0" src="/site/template/assets/spacer.gif"/>
#      </a>
#     </div>
#     <div id="homeslider" style="width: 400px;height:150px;">
#     </div>
#    </div>
#    <div id="tabs">
#     <div id="tabs-menu">
#      <a href="#">
#       Menu ▼
#      </a>
#     </div>
#     <div id="nav">
#      <ul id="navul">
#       <li id="t91232">
#        <a href="/">
#         <span>
#          Home
#         </span>
#        </a>
#       </li>
#       <li id="t91350">
#        <a href="/why-choose-us/">
#         <span>
#          Why Choose Us?
#         </span>
#        </a>
#       </li>
#       <li id="t91351">
#        <a href="/chicago-dj-reviews/">
#         <span>
#          Our Reviews
#         </span>
#        </a>
#       </li>
#       <li class="currenttab" id="t91355">
#        <a class="active" href="/your-event/">
#         <span>
#          Your Event
#         </span>
#        </a>
#       </li>
#       <li id="t91509">
#        <a href="/pricing-availability/">
#         <span>
#          Pricing/Availability
#         </span>
#        </a>
#       </li>
#       <li id="t91423">
#        <a href="/how-to-hire-us/">
#         <span>
#          How to Hire Us
#         </span>
#        </a>
#       </li>
#       <li id="t91391">
#        <a href="/select-your-music/">
#         <span>
#          Select Your Music
#         </span>
#        </a>
#       </li>
#       <li id="t91352">
#        <a href="/contact-us/">
#         <span>
#          Contact Us
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div id="main-body">
#     <div id="breadcrumbbar">
#      <div id="breadcrumblist">
#       <a class="breadcrumblevel0" href="http://www.discjockey.org">
#        Home
#       </a>
#       <span class="breadcrumblevel0 breadcrumbs-arrow">
#        &gt;
#       </span>
#       <a class="breadcrumblevel1" href="/your-event/">
#        Your Event
#       </a>
#       <span class="breadcrumblevel1 breadcrumbs-arrow">
#        &gt;
#       </span>
#       <a class="breadcrumblevel2" href="/reunion-dj/">
#        Chicago Class Reunion DJs
#       </a>
#       <span class="breadcrumblevel2 breadcrumbs-arrow">
#        &gt;
#       </span>
#       <span class="breadcrumbs-selected breadcrumblevel3" id="breadcrumb-selected">
#        Top 100 Songs of the 1980s
#       </span>
#      </div>
#     </div>
#     <div id="main-table-body">
#      <div id="main-table-body-content">
#       <div id="content">
#        <div id="content-header">
#        </div>
#        <div class="titleNotShown" id="content-body">
#         <div class="comp-content comp-editor-01" id="divcomp518725">
#          <h1 style="text-align:center">
#           Top Songs of the 1980's
#           <br/>
#           Planning a Party? These
#           <a href="http://www.discjockey.org" target="_blank">
#            Chicago DJ
#           </a>
#           Pros KNOW the Eighties!
#          </h1>
#          <table border="0" class="musicTable" id="musicTable">
#           <thead>
#            <tr>
#             <th>
#              Rank
#             </th>
#             <th>
#              Song Title
#             </th>
#             <th>
#              Song Artist
#             </th>
#             <th>
#              Year
#             </th>
#             <th>
#              Genre
#             </th>
#            </tr>
#           </thead>
#           <tfoot>
#            <tr>
#             <td colspan="5">
#              Top songs of the 1980's is updated by the minute by
#              <a href="http://www.gigbuilder.com" target="_blank">
#               Gigbuilder
#              </a>
#              - The world's most popular Event Management System.
#             </td>
#            </tr>
#           </tfoot>
#           <tbody>
#            <tr>
#             <td>
#              1
#             </td>
#             <td>
#              Don't Stop Believin'
#             </td>
#             <td>
#              Journey
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              2
#             </td>
#             <td>
#              You Shook Me All Night Long
#             </td>
#             <td>
#              AC/DC
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              3
#             </td>
#             <td>
#              Love Shack
#             </td>
#             <td>
#              B-52's
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              4
#             </td>
#             <td>
#              Livin' On A Prayer
#             </td>
#             <td>
#              Bon Jovi
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              5
#             </td>
#             <td>
#              Pour Some Sugar On Me
#             </td>
#             <td>
#              Def Leppard
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              6
#             </td>
#             <td>
#              Billie Jean
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              7
#             </td>
#             <td>
#              Celebration
#             </td>
#             <td>
#              Kool &amp; The Gang
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Disco
#             </td>
#            </tr>
#            <tr>
#             <td>
#              8
#             </td>
#             <td>
#              Footloose
#             </td>
#             <td>
#              Kenny Loggins
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              9
#             </td>
#             <td>
#              Thriller
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              10
#             </td>
#             <td>
#              I Wanna Dance With Somebody (Who Loves Me)
#             </td>
#             <td>
#              Whitney Houston
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              11
#             </td>
#             <td>
#              Girls Just Want To Have Fun
#             </td>
#             <td>
#              Cyndi Lauper
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              12
#             </td>
#             <td>
#              Summer Of 69
#             </td>
#             <td>
#              Bryan Adams
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              13
#             </td>
#             <td>
#              The Way You Make Me Feel
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              14
#             </td>
#             <td>
#              Jessie's Girl
#             </td>
#             <td>
#              Rick Springfield
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              15
#             </td>
#             <td>
#              (I've Had) The Time Of My Life
#             </td>
#             <td>
#              Bill Medley &amp; Jennifer Warnes
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              16
#             </td>
#             <td>
#              Pretty Young Thing (P.Y.T)
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              17
#             </td>
#             <td>
#              Push It
#             </td>
#             <td>
#              Salt-N-Pepa
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              18
#             </td>
#             <td>
#              Faithfully
#             </td>
#             <td>
#              Journey
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              19
#             </td>
#             <td>
#              Bust A Move
#             </td>
#             <td>
#              Young M.C.
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              20
#             </td>
#             <td>
#              Crazy Little Thing Called Love
#             </td>
#             <td>
#              Queen
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              21
#             </td>
#             <td>
#              Beat It
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              22
#             </td>
#             <td>
#              Sweet Child O' Mine
#             </td>
#             <td>
#              Guns N' Roses
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              23
#             </td>
#             <td>
#              Take Me Home Tonight
#             </td>
#             <td>
#              Eddie Money
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              24
#             </td>
#             <td>
#              Red Red Wine
#             </td>
#             <td>
#              UB40
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              25
#             </td>
#             <td>
#              What I Like About You
#             </td>
#             <td>
#              Romantics
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              26
#             </td>
#             <td>
#              Like A Prayer
#             </td>
#             <td>
#              Madonna
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              27
#             </td>
#             <td>
#              Kiss
#             </td>
#             <td>
#              Prince
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              28
#             </td>
#             <td>
#              White Wedding
#             </td>
#             <td>
#              Billy Idol
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              29
#             </td>
#             <td>
#              I Love Rock 'N Roll
#             </td>
#             <td>
#              Joan Jett &amp; Blackhearts
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              30
#             </td>
#             <td>
#              Another One Bites The Dust
#             </td>
#             <td>
#              Queen
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              31
#             </td>
#             <td>
#              Come on Eileen
#             </td>
#             <td>
#              Dexy's Midnight Runners
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              32
#             </td>
#             <td>
#              Super Freak
#             </td>
#             <td>
#              Rick James
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              33
#             </td>
#             <td>
#              Mony Mony
#             </td>
#             <td>
#              Billy Idol
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              34
#             </td>
#             <td>
#              Wild Thing
#             </td>
#             <td>
#              Tone Loc
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              35
#             </td>
#             <td>
#              It's Tricky
#             </td>
#             <td>
#              Run-D.M.C.
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              36
#             </td>
#             <td>
#              Sharp Dressed Man
#             </td>
#             <td>
#              ZZ Top
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              37
#             </td>
#             <td>
#              Take On Me
#             </td>
#             <td>
#              a-ha
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              38
#             </td>
#             <td>
#              (You Gotta) Fight For Your Right (To Party!)
#             </td>
#             <td>
#              Beastie Boys
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              39
#             </td>
#             <td>
#              Hit Me With Your Best Shot
#             </td>
#             <td>
#              Pat Benatar
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              40
#             </td>
#             <td>
#              Fishin' in the Dark
#             </td>
#             <td>
#              The Nitty Gritty Dirt Band
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Country
#             </td>
#            </tr>
#            <tr>
#             <td>
#              41
#             </td>
#             <td>
#              Smooth Criminal
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              42
#             </td>
#             <td>
#              You Spin Me Round (Like A Record)
#             </td>
#             <td>
#              Dead Or Alive
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              43
#             </td>
#             <td>
#              Rock With You
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              44
#             </td>
#             <td>
#              Any Way You Want It
#             </td>
#             <td>
#              Journey
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              45
#             </td>
#             <td>
#              Copperhead Road
#             </td>
#             <td>
#              Steve Earle
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              46
#             </td>
#             <td>
#              Walking On Sunshine
#             </td>
#             <td>
#              Katrina &amp; The Waves
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              47
#             </td>
#             <td>
#              It Takes Two
#             </td>
#             <td>
#              Rob Base &amp; D.J. E-Z Rock
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              48
#             </td>
#             <td>
#              You Make My Dreams Come True
#             </td>
#             <td>
#              Daryl Hall &amp; John Oates
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              49
#             </td>
#             <td>
#              Forever And Ever, Amen
#             </td>
#             <td>
#              Randy Travis
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Country
#             </td>
#            </tr>
#            <tr>
#             <td>
#              50
#             </td>
#             <td>
#              The Safety Dance
#             </td>
#             <td>
#              Men Without Hats
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              51
#             </td>
#             <td>
#              Open Arms
#             </td>
#             <td>
#              Journey
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              52
#             </td>
#             <td>
#              All Night Long (All Night)
#             </td>
#             <td>
#              Lionel Richie
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              53
#             </td>
#             <td>
#              Your Love
#             </td>
#             <td>
#              Outfield
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              54
#             </td>
#             <td>
#              Blister In The Sun
#             </td>
#             <td>
#              Violent Femmes
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              55
#             </td>
#             <td>
#              Jack &amp; Diane
#             </td>
#             <td>
#              John Cougar
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              56
#             </td>
#             <td>
#              Kokomo
#             </td>
#             <td>
#              Beach Boys
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              57
#             </td>
#             <td>
#              1999
#             </td>
#             <td>
#              Prince
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              58
#             </td>
#             <td>
#              Free Fallin'
#             </td>
#             <td>
#              Tom Petty
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              59
#             </td>
#             <td>
#              Funky Cold Medina
#             </td>
#             <td>
#              Tone Loc
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              60
#             </td>
#             <td>
#              Eye Of The Tiger
#             </td>
#             <td>
#              Survivor
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              61
#             </td>
#             <td>
#              Wanna Be Startin' Somethin'
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              62
#             </td>
#             <td>
#              You Give Love A Bad Name
#             </td>
#             <td>
#              Bon Jovi
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              63
#             </td>
#             <td>
#              Let's Go Crazy
#             </td>
#             <td>
#              Prince &amp; The Revolution
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              64
#             </td>
#             <td>
#              Could You Be Loved
#             </td>
#             <td>
#              Bob Marley &amp; The Wailers
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Reggae
#             </td>
#            </tr>
#            <tr>
#             <td>
#              65
#             </td>
#             <td>
#              Get Down On It
#             </td>
#             <td>
#              Kool &amp; The Gang
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              66
#             </td>
#             <td>
#              Never Gonna Give You Up
#             </td>
#             <td>
#              Rick Astley
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              67
#             </td>
#             <td>
#              Brass Monkey
#             </td>
#             <td>
#              Beastie Boys
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              68
#             </td>
#             <td>
#              Africa
#             </td>
#             <td>
#              Toto
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              69
#             </td>
#             <td>
#              You Dropped A Bomb On Me
#             </td>
#             <td>
#              Gap Band
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              70
#             </td>
#             <td>
#              Wake Me Up Before You Go-Go
#             </td>
#             <td>
#              Wham!
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              71
#             </td>
#             <td>
#              It's Raining Men
#             </td>
#             <td>
#              Weather Girls
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              72
#             </td>
#             <td>
#              Back In Black
#             </td>
#             <td>
#              AC/DC
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              73
#             </td>
#             <td>
#              Man In The Mirror
#             </td>
#             <td>
#              Michael Jackson
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              74
#             </td>
#             <td>
#              Pump Up The Jam
#             </td>
#             <td>
#              Technotronic Feat. Felly
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              75
#             </td>
#             <td>
#              In Your Eyes
#             </td>
#             <td>
#              Peter Gabriel
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              76
#             </td>
#             <td>
#              Uptown Girl
#             </td>
#             <td>
#              Billy Joel
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              77
#             </td>
#             <td>
#              Dead Man's Party
#             </td>
#             <td>
#              Oingo Boingo
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              78
#             </td>
#             <td>
#              Paradise City
#             </td>
#             <td>
#              Guns N' Roses
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              79
#             </td>
#             <td>
#              Dancing In The Dark
#             </td>
#             <td>
#              Bruce Springsteen
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              80
#             </td>
#             <td>
#              Let's Groove
#             </td>
#             <td>
#              Earth, Wind &amp; Fire
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              81
#             </td>
#             <td>
#              Conga
#             </td>
#             <td>
#              Gloria Estefan &amp; Miami Sound Machine
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              82
#             </td>
#             <td>
#              Every Little Thing She Does Is Magic
#             </td>
#             <td>
#              Police
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              83
#             </td>
#             <td>
#              Could I Have This Dance
#             </td>
#             <td>
#              Anne Murray
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              84
#             </td>
#             <td>
#              Under Pressure
#             </td>
#             <td>
#              Queen &amp; David Bowie
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              85
#             </td>
#             <td>
#              Glory Days
#             </td>
#             <td>
#              Bruce Springsteen
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              86
#             </td>
#             <td>
#              She's Got A Way
#             </td>
#             <td>
#              Billy Joel
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              87
#             </td>
#             <td>
#              Forever Young
#             </td>
#             <td>
#              Rod Stewart
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              88
#             </td>
#             <td>
#              Can't Fight This Feeling
#             </td>
#             <td>
#              REO Speedwagon
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              89
#             </td>
#             <td>
#              Dancing With Myself
#             </td>
#             <td>
#              Billy Idol
#             </td>
#             <td>
#              1981
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              90
#             </td>
#             <td>
#              Just Like Heaven
#             </td>
#             <td>
#              Cure
#             </td>
#             <td>
#              1987
#             </td>
#             <td>
#              Alternative
#             </td>
#            </tr>
#            <tr>
#             <td>
#              91
#             </td>
#             <td>
#              Funkytown
#             </td>
#             <td>
#              Lipps Inc.
#             </td>
#             <td>
#              1980
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              92
#             </td>
#             <td>
#              Walk Like An Egyptian
#             </td>
#             <td>
#              Bangles
#             </td>
#             <td>
#              1986
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              93
#             </td>
#             <td>
#              You're The Inspiration
#             </td>
#             <td>
#              Chicago
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              94
#             </td>
#             <td>
#              Jump
#             </td>
#             <td>
#              Van Halen
#             </td>
#             <td>
#              1984
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              95
#             </td>
#             <td>
#              Tainted Love
#             </td>
#             <td>
#              Soft Cell
#             </td>
#             <td>
#              1982
#             </td>
#             <td>
#              Popular
#             </td>
#            </tr>
#            <tr>
#             <td>
#              96
#             </td>
#             <td>
#              Heaven
#             </td>
#             <td>
#              Bryan Adams
#             </td>
#             <td>
#              1985
#             </td>
#             <td>
#              Oldies
#             </td>
#            </tr>
#            <tr>
#             <td>
#              97
#             </td>
#             <td>
#              Here And Now
#             </td>
#             <td>
#              Luther Vandross
#             </td>
#             <td>
#              1989
#             </td>
#             <td>
#              Ballad
#             </td>
#            </tr>
#            <tr>
#             <td>
#              98
#             </td>
#             <td>
#              Nothin' But A Good Time
#             </td>
#             <td>
#              Poison
#             </td>
#             <td>
#              1988
#             </td>
#             <td>
#              Rock
#             </td>
#            </tr>
#            <tr>
#             <td>
#              99
#             </td>
#             <td>
#              Its Raining Men
#             </td>
#             <td>
#              Weather Girls
#             </td>
#             <td>
#              1983
#             </td>
#             <td>
#              Funk
#             </td>
#            </tr>
#            <tr>
#             <td>
#              100
#             </td>
#             <td>
#              Strokin
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <p>
#          </p>
#         </div>
#        </div>
#        <div id="content-footer">
#        </div>
#       </div>
#      </div>
#      <div id="main-table-body-sidebar">
#       <div id="sidebar">
#        <div id="menu-header">
#         <div id="sm">
#          <a href="http://www.facebook.com/FourthEstateAudio" id="sm-fb" target="_blank">
#           <img alt="Facebook" border="0" height="32" src="/site/assets/spacer.gif" width="32"/>
#          </a>
#          <a href="http://pinterest.com/chicagodjlights/#" id="sm-pin" target="_blank">
#           <img alt="Pinterest" border="0" height="32" src="/site/assets/spacer.gif" width="32"/>
#          </a>
#          <a href="http://www.youtube.com/user/chicagodjlights/videos?view=0" id="sm-youtube" target="_blank">
#           <img alt="Youtube" border="0" height="32" src="/site/assets/spacer.gif" width="32"/>
#          </a>
#         </div>
#        </div>
#        <div id="menu">
#         <h3>
#          <a href="/your-event/" id="menu-h3">
#           Your Event
#          </a>
#         </h3>
#         <ul>
#          <li>
#           <a href="/chicago-wedding-dj/" id="m91356">
#            Chicago Wedding DJ
#           </a>
#          </li>
#          <li id="current-submenu-li">
#           <a class="current" href="/reunion-dj/" id="m91357">
#            Chicago Class Reunion DJs
#           </a>
#           <ul>
#            <li>
#             <a href="/top-100-songs-of-the-2010s/" id="subm167639">
#              Top 100 Songs of the 2010s
#             </a>
#            </li>
#            <li>
#             <a href="/top-100-songs-of-the-2000s/" id="subm94067">
#              Top 100 Songs of the 2000s
#             </a>
#            </li>
#            <li>
#             <a href="/top-100-songs-of-the-1990s/" id="subm94066">
#              Top 100 Songs of the 1990s
#             </a>
#            </li>
#            <li id="current-submenu-li-li">
#             <a class="subcurrent" href="/top-100-songs-of-the-1980s/" id="subm94069">
#              Top 100 Songs of the 1980s
#             </a>
#            </li>
#            <li>
#             <a href="/top-100-songs-of-the-1970s/" id="subm94070">
#              Top 100 Songs of the 1970s
#             </a>
#            </li>
#            <li>
#             <a href="/top-100-songs-of-the-1960s/" id="subm94071">
#              Top 100 Songs of the 1960s
#             </a>
#            </li>
#            <li>
#             <a href="/top-100-songs-of-the-1950s/" id="subm94074">
#              Top 100 Songs of the 1950s
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/outdoor-events/" id="m91359">
#            Outdoor Events
#           </a>
#          </li>
#          <li>
#           <a href="/corporate-events/" id="m91360">
#            Corporate Events
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div id="menu-footer">
#         <p>
#          <a href="/about-us/" title="About Us">
#           <img alt="About Us" src="/site/template/assets/home_template_fourthestate_895/images/DontHireAWeddingDJ155x233.jpg"/>
#          </a>
#         </p>
#        </div>
#       </div>
#      </div>
#      <div id="third-column">
#       <div id="side-ctas">
#        <a href="/best-chicago-dj/" title="The Second Best DJ in Chicago">
#         <img alt="The Second Best DJ in Chicago" src="/site/template/assets/home_template_fourthestate_895/images/best-dj-banner.png"/>
#        </a>
#        <a href="/chicago-wedding-dj/" title="Your Dream Wedding">
#         <img alt="Your Dream Wedding" src="/site/template/assets/home_template_fourthestate_895/images/dream-wedding-banner.png"/>
#        </a>
#        <a href="/how-to-hire-us/" title="Hire Us Here">
#         <img alt="Hire Us Here" src="/site/template/assets/home_template_fourthestate_895/images/hire-us-banner.png"/>
#        </a>
#        <a href="/select-your-music/" title="Select Your Music">
#         <img alt="Select Your Music" src="/site/template/assets/home_template_fourthestate_895/images/select-banner.png"/>
#        </a>
#        <a href="/blog/" title="Read Our Blog">
#         <img alt="Read Our Blog" src="/site/template/assets/home_template_fourthestate_895/images/read_our_blog.png"/>
#        </a>
#       </div>
#      </div>
#      <div style="clear: both;">
#      </div>
#     </div>
#     <div style="clear: both;">
#     </div>
#    </div>
#    <div id="clearfooter">
#    </div>
#   </div>
#   <div id="footer">
#    <div id="footerwrap">
#     <div id="contact-info">
#      <span class="text">
#       <strong>
#        Phone:
#       </strong>
#       630.654.4440
#      </span>
#      <span class="text">
#       <strong>
#        Fax:
#       </strong>
#       630.654.4467
#      </span>
#     </div>
#     <div id="footer-email-bt">
#      <a href="mailto:jaycongdon@hotmail.com">
#       Contact Us
#      </a>
#     </div>
#     <div id="footer-client-login-bt">
#      <a href="http://gigbuilder.com/cal/il/discjockey.nsf/interactive.html" target="_blank">
#       Client Login
#      </a>
#     </div>
#     <div id="footer-pay-bt">
#      <a href="/how-to-pay-us/">
#       How to Pay Us
#      </a>
#     </div>
#     <div id="poweredby" style="color: #00639b;">
#      <a href="https://www.epagecity.com/contact/" title="Website Design">
#       Web Design
#      </a>
#      by ePageCity
#     </div>
#    </div>
#   </div>
#   <!-- ClickTale Bottom part -->
#   <div id="ClickTaleDiv" style="display: none;">
#   </div>
#   <script type="text/javascript">
#    if(document.location.protocol!='https:')
#   document.write(unescape("%3Cscript%20src='http://s.clicktale.net/WRd.js'%20type='text/javascript'%3E%3C/script%3E"));
#   </script>
#   <script type="text/javascript">
#    if(typeof ClickTale=='function') ClickTale(8444,1,"www14");
#   </script>
#   <script type="text/javascript">
#    var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
# document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#   </script>
#   <script type="text/javascript">
#    try {
# var pageTracker = _gat._getTracker("UA-15284412-1");
# pageTracker._trackPageview();
# } catch(err) {}
#   </script>
#  </body>
# </html>

# %%
top_80s_songs = []
top_80s_artists = []

for q in soup2.select('td:nth-child(2)'):
    top_80s_songs.append(q.get_text())

for q in soup2.select("td:nth-child(3)"):
    top_80s_artists.append(q.get_text())

# %%
len(top_80s_songs)
# Out:
# 100

# %%
len(top_80s_artists)
# Out:
# 99

# %%
#we remove the last song as it has no artist
# pop deletes the last element of a column
top_80s_songs.pop()
# Out:
# 'Strokin'

# %%
len(top_80s_songs)
# Out:
# 99

# %%
hits_80s=pd.DataFrame({"title_80":top_80s_songs, "artist_80":top_80s_artists})

# %%
hits_80s
# Out:
#                        title_80        artist_80
# 0          Don't Stop Believin'          Journey
# 1   You Shook Me All Night Long            AC/DC
# 2                    Love Shack           B-52's
# 3            Livin' On A Prayer         Bon Jovi
# 4         Pour Some Sugar On Me      Def Leppard
# ..                          ...              ...
# 94                 Tainted Love        Soft Cell
# 95                       Heaven      Bryan Adams
# 96                 Here And Now  Luther Vandross
# 97      Nothin' But A Good Time           Poison
# 98              Its Raining Men    Weather Girls
#
# [99 rows x 2 columns]

# %% [markdown]
# # Creating the recommender

# %%
import random

# %%
#top_100_songs['Title'].values

# %%
#def song_choice():
 #   song = input('Which song do you like? ')
    #  if song in top_100_songs['Title'].values:
   #     print('Oh, nice one! We reccomend you to listen to:', random.choice(top_100_songs['Title']))
  #  else:
   #     print('This song is not hot, try another song so we can give you a recommendation')

# %%
# song_choice()

# %%
def billboard_scraper():
    from bs4 import BeautifulSoup
    import requests
    import pandas as pd
    import random
    # 2. find url and store it in avariable
    url = "https://www.billboard.com/charts/hot-100"
    # 3. download html with a get request
    response = requests.get(url)
    soup=BeautifulSoup(response.content, 'html.parser')
    titles=[]
    artists=[]
    for i in soup.find_all('span', {'class':'chart-element__information__song'}):
        titles.append(i.get_text())
    for i in soup.find_all('span', {'class':'chart-element__information__artist'}):
        artists.append(i.get_text())
    return pd.DataFrame({'song':titles, 'artist':artists})

# %%
# Create the prototype
def hits_80s_scraper():

    # 2. find url and store it in avariable
    url = "http://www.discjockey.org/top-100-songs-of-the-1980s/"

    # 3. download html with a get request
    response = requests.get(url)
    soup=BeautifulSoup(response.content, 'html.parser')
    
    top_80s_songs = []
    top_80s_artists = []

    for q in soup2.select('td:nth-child(2)'):
        top_80s_songs.append(q.get_text())

    for q in soup2.select("td:nth-child(3)"):
        top_80s_artists.append(q.get_text())
    
    top_80s_songs.pop()
    
    return pd.DataFrame({"title_80":top_80s_songs, "artist_80":top_80s_artists})

# %%
from random import randint

# %%
def hot_recommender():
    from billboard_scraper import billboard_scraper

billboard = billboard_scraper()

song = input("What song do you like?")

song_row = billboard[billboard["song"].str.contains(song)]
if len(song_row) == 0 :
    print("That song is not in the list")
else:
    check_song = input("did you mean " + song_row["song"].values[0] + "by " + song_row["artist"].values[0]+"? ")
    
    if check_song == 'yes':
            print("That's a hot song")
            random_song = randint(0, len(billboard)-1)
            print("You might also like " + billboard["song"][random_song] + "by " + billboard["artist"][random_song])
    else:
            print("Ah, not the one I had in mind")
# Out:
# What song do you like?Butter
# did you mean Butterby BTS? yes
# That's a hot song
# You might also like Rapstarby Polo G

# %% [markdown]
# ## 80s from spotify

# %%
import getpass

# %%
client_id=str(getpass.getpass('client_id?'))
client_secret = str(getpass.getpass('client_secret?'))
# Out:
# client_id?········
# client_secret?········

# %%
import spotipy # install if needed
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=client_id,
    client_secret=client_secret))

# %%
# https://open.spotify.com/playlist/3acAVwCcB38UtE24t92tex?si=e39ecf230a2f4177

# %%
playlist = sp.user_playlist_tracks("spotify", "3acAVwCcB38UtE24t92tex")
#esta funcion solo devuelve hasta 100 canciones!

# %%
#para q me salgan todos los resultados hago:

def get_playlist_tracks(user_id, playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# 2- call function on playlist
full_playlist= get_playlist_tracks('spotify', '3acAVwCcB38UtE24t92tex')

# %%
full_playlist
# Out:
# [{'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'},
#       'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT',
#       'id': '0lZoBs4Pzo7R89JM9lxwoT',
#       'name': 'Duran Duran',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lZoBs4Pzo7R89JM9lxwoT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/02tfQwJSOLP77oCd9U8bqm'},
#     'href': 'https://api.spotify.com/v1/albums/02tfQwJSOLP77oCd9U8bqm',
#     'id': '02tfQwJSOLP77oCd9U8bqm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739977eb01e4e40c8357435ef9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029977eb01e4e40c8357435ef9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519977eb01e4e40c8357435ef9',
#       'width': 64}],
#     'name': "Rio (Collector's Edition)",
#     'release_date': '1982-05-10',
#     'release_date_precision': 'day',
#     'total_tracks': 29,
#     'type': 'album',
#     'uri': 'spotify:album:02tfQwJSOLP77oCd9U8bqm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'},
#      'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT',
#      'id': '0lZoBs4Pzo7R89JM9lxwoT',
#      'name': 'Duran Duran',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lZoBs4Pzo7R89JM9lxwoT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 220626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0901090'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/39lSeqnyjZJejRuaREfyLL'},
#    'href': 'https://api.spotify.com/v1/tracks/39lSeqnyjZJejRuaREfyLL',
#    'id': '39lSeqnyjZJejRuaREfyLL',
#    'is_local': False,
#    'name': 'Hungry Like the Wolf - 2009 Remaster',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5776fc355b811f08fc4143bcf039706d56bcc843?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:39lSeqnyjZJejRuaREfyLL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#       'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#       'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#       'name': 'Dire Straits',
#       'type': 'artist',
#       'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2BPgOlvV3aTHJ7av8LhGn5'},
#     'href': 'https://api.spotify.com/v1/albums/2BPgOlvV3aTHJ7av8LhGn5',
#     'id': '2BPgOlvV3aTHJ7av8LhGn5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734bd5401f50d53893f222d3f7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024bd5401f50d53893f222d3f7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514bd5401f50d53893f222d3f7',
#       'width': 64}],
#     'name': 'Sultans Of Swing - The Very Best Of Dire Straits',
#     'release_date': '1998-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2BPgOlvV3aTHJ7av8LhGn5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0WwSkZ7LtFUFjGjMZBMt6T'},
#      'href': 'https://api.spotify.com/v1/artists/0WwSkZ7LtFUFjGjMZBMt6T',
#      'id': '0WwSkZ7LtFUFjGjMZBMt6T',
#      'name': 'Dire Straits',
#      'type': 'artist',
#      'uri': 'spotify:artist:0WwSkZ7LtFUFjGjMZBMt6T'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 249333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF088500675'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7w4Tbkbx081vRJa8ol56Qf'},
#    'href': 'https://api.spotify.com/v1/tracks/7w4Tbkbx081vRJa8ol56Qf',
#    'id': '7w4Tbkbx081vRJa8ol56Qf',
#    'is_local': False,
#    'name': 'Walk Of Life',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:7w4Tbkbx081vRJa8ol56Qf'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aX2dmV8XoHYCOQRxjPESG'},
#       'href': 'https://api.spotify.com/v1/artists/1aX2dmV8XoHYCOQRxjPESG',
#       'id': '1aX2dmV8XoHYCOQRxjPESG',
#       'name': 'The Human League',
#       'type': 'artist',
#       'uri': 'spotify:artist:1aX2dmV8XoHYCOQRxjPESG'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Vgpl5ixDyU5W7lVDLeFhi'},
#     'href': 'https://api.spotify.com/v1/albums/3Vgpl5ixDyU5W7lVDLeFhi',
#     'id': '3Vgpl5ixDyU5W7lVDLeFhi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273532a9f4829d857a21bbc6a6c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02532a9f4829d857a21bbc6a6c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851532a9f4829d857a21bbc6a6c',
#       'width': 64}],
#     'name': 'The Very Best Of The Human League',
#     'release_date': '2003-09-15',
#     'release_date_precision': 'day',
#     'total_tracks': 28,
#     'type': 'album',
#     'uri': 'spotify:album:3Vgpl5ixDyU5W7lVDLeFhi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1aX2dmV8XoHYCOQRxjPESG'},
#      'href': 'https://api.spotify.com/v1/artists/1aX2dmV8XoHYCOQRxjPESG',
#      'id': '1aX2dmV8XoHYCOQRxjPESG',
#      'name': 'The Human League',
#      'type': 'artist',
#      'uri': 'spotify:artist:1aX2dmV8XoHYCOQRxjPESG'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 238000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAA0200924'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5lmYpa6EaVAKAlwxMf7q5c'},
#    'href': 'https://api.spotify.com/v1/tracks/5lmYpa6EaVAKAlwxMf7q5c',
#    'id': '5lmYpa6EaVAKAlwxMf7q5c',
#    'is_local': False,
#    'name': "Don't You Want Me - 2002 - Remaster",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5lmYpa6EaVAKAlwxMf7q5c'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19ra5tSw0tWufvUp8GotLo'},
#       'href': 'https://api.spotify.com/v1/artists/19ra5tSw0tWufvUp8GotLo',
#       'id': '19ra5tSw0tWufvUp8GotLo',
#       'name': 'George Michael',
#       'type': 'artist',
#       'uri': 'spotify:artist:19ra5tSw0tWufvUp8GotLo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/34K1Kvskt9arWy8E1Gz3Lw'},
#     'href': 'https://api.spotify.com/v1/albums/34K1Kvskt9arWy8E1Gz3Lw',
#     'id': '34K1Kvskt9arWy8E1Gz3Lw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b7a9a6a2bf311630d3fc6956',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b7a9a6a2bf311630d3fc6956',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b7a9a6a2bf311630d3fc6956',
#       'width': 64}],
#     'name': 'Faith',
#     'release_date': '1987-10-30',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:34K1Kvskt9arWy8E1Gz3Lw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19ra5tSw0tWufvUp8GotLo'},
#      'href': 'https://api.spotify.com/v1/artists/19ra5tSw0tWufvUp8GotLo',
#      'id': '19ra5tSw0tWufvUp8GotLo',
#      'name': 'George Michael',
#      'type': 'artist',
#      'uri': 'spotify:artist:19ra5tSw0tWufvUp8GotLo'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 193200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1000855'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0HEmnAUT8PHznIAAmVXqFJ'},
#    'href': 'https://api.spotify.com/v1/tracks/0HEmnAUT8PHznIAAmVXqFJ',
#    'id': '0HEmnAUT8PHznIAAmVXqFJ',
#    'is_local': False,
#    'name': 'Faith - Remastered',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ad227db8dedb8bbe85768d81a804db1d6e537967?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0HEmnAUT8PHznIAAmVXqFJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FNwL9lX7pHLeBZ4s1J5Cm'},
#     'href': 'https://api.spotify.com/v1/albums/6FNwL9lX7pHLeBZ4s1J5Cm',
#     'id': '6FNwL9lX7pHLeBZ4s1J5Cm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e57abff98ab5e7552b97ce6b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e57abff98ab5e7552b97ce6b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e57abff98ab5e7552b97ce6b',
#       'width': 64}],
#     'name': 'Pure Hits',
#     'release_date': '2008-06-16',
#     'release_date_precision': 'day',
#     'total_tracks': 50,
#     'type': 'album',
#     'uri': 'spotify:album:6FNwL9lX7pHLeBZ4s1J5Cm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hN9F0iuULZYWXppob22Aj'},
#      'href': 'https://api.spotify.com/v1/artists/6hN9F0iuULZYWXppob22Aj',
#      'id': '6hN9F0iuULZYWXppob22Aj',
#      'name': 'Simple Minds',
#      'type': 'artist',
#      'uri': 'spotify:artist:6hN9F0iuULZYWXppob22Aj'}],
#    'available_markets': [],
#    'disc_number': 2,
#    'duration_ms': 260666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAA0100587'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7jtGa7FmUx7YxTbiy6tEsX'},
#    'href': 'https://api.spotify.com/v1/tracks/7jtGa7FmUx7YxTbiy6tEsX',
#    'id': '7jtGa7FmUx7YxTbiy6tEsX',
#    'is_local': False,
#    'name': "Don't You (Forget About Me) - 2001 Remastered Version",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7jtGa7FmUx7YxTbiy6tEsX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#       'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#       'id': '58lV9VcRSjABbAbfWS6skp',
#       'name': 'Bon Jovi',
#       'type': 'artist',
#       'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Ad4QdO0EJr1c2livr9cmm'},
#     'href': 'https://api.spotify.com/v1/albums/3Ad4QdO0EJr1c2livr9cmm',
#     'id': '3Ad4QdO0EJr1c2livr9cmm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f0d41275363a36b5772b49b2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f0d41275363a36b5772b49b2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f0d41275363a36b5772b49b2',
#       'width': 64}],
#     'name': 'Bon Jovi Greatest Hits',
#     'release_date': '2010-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:3Ad4QdO0EJr1c2livr9cmm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#      'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#      'id': '58lV9VcRSjABbAbfWS6skp',
#      'name': 'Bon Jovi',
#      'type': 'artist',
#      'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 250626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USPR38619998'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3X7abqSXC4xrxuC1ykpWcY'},
#    'href': 'https://api.spotify.com/v1/tracks/3X7abqSXC4xrxuC1ykpWcY',
#    'id': '3X7abqSXC4xrxuC1ykpWcY',
#    'is_local': False,
#    'name': "Livin' On A Prayer",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3X7abqSXC4xrxuC1ykpWcY'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQIn7N5CuRDP8wEI7FiDA'},
#       'href': 'https://api.spotify.com/v1/artists/3CQIn7N5CuRDP8wEI7FiDA',
#       'id': '3CQIn7N5CuRDP8wEI7FiDA',
#       'name': 'Run–D.M.C.',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CQIn7N5CuRDP8wEI7FiDA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7AFsTiojVaB2I58oZ1tMRg'},
#     'href': 'https://api.spotify.com/v1/albums/7AFsTiojVaB2I58oZ1tMRg',
#     'id': '7AFsTiojVaB2I58oZ1tMRg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273894ae4df775c6b47438991af',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02894ae4df775c6b47438991af',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851894ae4df775c6b47438991af',
#       'width': 64}],
#     'name': 'Raising Hell',
#     'release_date': '1986-05-15',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:7AFsTiojVaB2I58oZ1tMRg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CQIn7N5CuRDP8wEI7FiDA'},
#      'href': 'https://api.spotify.com/v1/artists/3CQIn7N5CuRDP8wEI7FiDA',
#      'id': '3CQIn7N5CuRDP8wEI7FiDA',
#      'name': 'Run–D.M.C.',
#      'type': 'artist',
#      'uri': 'spotify:artist:3CQIn7N5CuRDP8wEI7FiDA'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ey4PD4MYsKc5I2dolUwbH'},
#      'href': 'https://api.spotify.com/v1/artists/7Ey4PD4MYsKc5I2dolUwbH',
#      'id': '7Ey4PD4MYsKc5I2dolUwbH',
#      'name': 'Aerosmith',
#      'type': 'artist',
#      'uri': 'spotify:artist:7Ey4PD4MYsKc5I2dolUwbH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 310386,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAR19900334'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6qUEOWqOzu1rLPUPQ1ECpx'},
#    'href': 'https://api.spotify.com/v1/tracks/6qUEOWqOzu1rLPUPQ1ECpx',
#    'id': '6qUEOWqOzu1rLPUPQ1ECpx',
#    'is_local': False,
#    'name': 'Walk This Way (feat. Aerosmith)',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c7a8010bbddcd0d793a832de76a24d2cae5ab497?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6qUEOWqOzu1rLPUPQ1ECpx'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#       'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#       'id': '3fMbdgg4jU18AjLCKBhRSm',
#       'name': 'Michael Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ubQZz8WgIfvjSoekS5daO'},
#     'href': 'https://api.spotify.com/v1/albums/3ubQZz8WgIfvjSoekS5daO',
#     'id': '3ubQZz8WgIfvjSoekS5daO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732e01bd3a6ebc8c9bcc0b4e4c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022e01bd3a6ebc8c9bcc0b4e4c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512e01bd3a6ebc8c9bcc0b4e4c',
#       'width': 64}],
#     'name': 'The Essential Michael Jackson',
#     'release_date': '2005-07-19',
#     'release_date_precision': 'day',
#     'total_tracks': 38,
#     'type': 'album',
#     'uri': 'spotify:album:3ubQZz8WgIfvjSoekS5daO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#      'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#      'id': '3fMbdgg4jU18AjLCKBhRSm',
#      'name': 'Michael Jackson',
#      'type': 'artist',
#      'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 258040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19902990'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2dzMbi6uW2EE4cgzxf8vcO'},
#    'href': 'https://api.spotify.com/v1/tracks/2dzMbi6uW2EE4cgzxf8vcO',
#    'id': '2dzMbi6uW2EE4cgzxf8vcO',
#    'is_local': False,
#    'name': 'Beat It - Single Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:2dzMbi6uW2EE4cgzxf8vcO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7HCpCOgvZQMt2YwPtp1y8p'},
#     'href': 'https://api.spotify.com/v1/albums/7HCpCOgvZQMt2YwPtp1y8p',
#     'id': '7HCpCOgvZQMt2YwPtp1y8p',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273833510f734a8ac5a46307433',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02833510f734a8ac5a46307433',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851833510f734a8ac5a46307433',
#       'width': 64}],
#     'name': 'Pure Driving Rock',
#     'release_date': '2008-06-16',
#     'release_date_precision': 'day',
#     'total_tracks': 50,
#     'type': 'album',
#     'uri': 'spotify:album:7HCpCOgvZQMt2YwPtp1y8p'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TzHIUhVpeeDxyJPpQfnV3'},
#      'href': 'https://api.spotify.com/v1/artists/2TzHIUhVpeeDxyJPpQfnV3',
#      'id': '2TzHIUhVpeeDxyJPpQfnV3',
#      'name': 'Katrina & The Waves',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TzHIUhVpeeDxyJPpQfnV3'}],
#    'available_markets': [],
#    'disc_number': 3,
#    'duration_ms': 238880,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA28500061'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7n1sAeis4HONDsNnnqmtaU'},
#    'href': 'https://api.spotify.com/v1/tracks/7n1sAeis4HONDsNnnqmtaU',
#    'id': '7n1sAeis4HONDsNnnqmtaU',
#    'is_local': False,
#    'name': 'Walking On Sunshine',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7n1sAeis4HONDsNnnqmtaU'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0PFtn5NtBbbUNbU9EAmIWF'},
#       'href': 'https://api.spotify.com/v1/artists/0PFtn5NtBbbUNbU9EAmIWF',
#       'id': '0PFtn5NtBbbUNbU9EAmIWF',
#       'name': 'TOTO',
#       'type': 'artist',
#       'uri': 'spotify:artist:0PFtn5NtBbbUNbU9EAmIWF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/62U7xIHcID94o20Of5ea4D'},
#     'href': 'https://api.spotify.com/v1/albums/62U7xIHcID94o20Of5ea4D',
#     'id': '62U7xIHcID94o20Of5ea4D',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734a052b99c042dc15f933145b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024a052b99c042dc15f933145b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514a052b99c042dc15f933145b',
#       'width': 64}],
#     'name': 'Toto IV',
#     'release_date': '1982-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:62U7xIHcID94o20Of5ea4D'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0PFtn5NtBbbUNbU9EAmIWF'},
#      'href': 'https://api.spotify.com/v1/artists/0PFtn5NtBbbUNbU9EAmIWF',
#      'id': '0PFtn5NtBbbUNbU9EAmIWF',
#      'name': 'TOTO',
#      'type': 'artist',
#      'uri': 'spotify:artist:0PFtn5NtBbbUNbU9EAmIWF'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 331200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM18200245'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/37BTh5g05cxBIRYMbw8g2T'},
#    'href': 'https://api.spotify.com/v1/tracks/37BTh5g05cxBIRYMbw8g2T',
#    'id': '37BTh5g05cxBIRYMbw8g2T',
#    'is_local': False,
#    'name': 'Rosanna',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4fa6f146755af45f9784a87c6bed9e39982dd10e?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:37BTh5g05cxBIRYMbw8g2T'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rvjqX7ttXeg3mTy8Xscbt'},
#       'href': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt',
#       'id': '0rvjqX7ttXeg3mTy8Xscbt',
#       'name': 'Journey',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rvjqX7ttXeg3mTy8Xscbt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5pfpXvoJtSIFrbPIoBEv3R'},
#     'href': 'https://api.spotify.com/v1/albums/5pfpXvoJtSIFrbPIoBEv3R',
#     'id': '5pfpXvoJtSIFrbPIoBEv3R',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f6ce5c138493ac768d9afc8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f6ce5c138493ac768d9afc8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f6ce5c138493ac768d9afc8',
#       'width': 64}],
#     'name': 'The Essential Journey',
#     'release_date': '2001-10-16',
#     'release_date_precision': 'day',
#     'total_tracks': 32,
#     'type': 'album',
#     'uri': 'spotify:album:5pfpXvoJtSIFrbPIoBEv3R'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rvjqX7ttXeg3mTy8Xscbt'},
#      'href': 'https://api.spotify.com/v1/artists/0rvjqX7ttXeg3mTy8Xscbt',
#      'id': '0rvjqX7ttXeg3mTy8Xscbt',
#      'name': 'Journey',
#      'type': 'artist',
#      'uri': 'spotify:artist:0rvjqX7ttXeg3mTy8Xscbt'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 248906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM18100116'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/77NNZQSqzLNqh2A9JhLRkg'},
#    'href': 'https://api.spotify.com/v1/tracks/77NNZQSqzLNqh2A9JhLRkg',
#    'id': '77NNZQSqzLNqh2A9JhLRkg',
#    'is_local': False,
#    'name': "Don't Stop Believin'",
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5908f4536c2b1111045c46555811fe61112d5c26?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:77NNZQSqzLNqh2A9JhLRkg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-01-27T15:49:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aq8T2RcspxVOGgMrTzjWc'},
#       'href': 'https://api.spotify.com/v1/artists/6aq8T2RcspxVOGgMrTzjWc',
#       'id': '6aq8T2RcspxVOGgMrTzjWc',
#       'name': 'Soft Cell',
#       'type': 'artist',
#       'uri': 'spotify:artist:6aq8T2RcspxVOGgMrTzjWc'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/47vTL5g54UdpLG62R3sJb7'},
#     'href': 'https://api.spotify.com/v1/albums/47vTL5g54UdpLG62R3sJb7',
#     'id': '47vTL5g54UdpLG62R3sJb7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f29e9e5991966cd36387741b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f29e9e5991966cd36387741b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f29e9e5991966cd36387741b',
#       'width': 64}],
#     'name': 'Tainted Love / Where Did Our Love Go',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:47vTL5g54UdpLG62R3sJb7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6aq8T2RcspxVOGgMrTzjWc'},
#      'href': 'https://api.spotify.com/v1/artists/6aq8T2RcspxVOGgMrTzjWc',
#      'id': '6aq8T2RcspxVOGgMrTzjWc',
#      'name': 'Soft Cell',
#      'type': 'artist',
#      'uri': 'spotify:artist:6aq8T2RcspxVOGgMrTzjWc'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 156906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF088100001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Du6gEDduLCB9FIm9xIE4w'},
# ...
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43mhFhQ4JAknA7Ik1bOZuV'},
#       'href': 'https://api.spotify.com/v1/artists/43mhFhQ4JAknA7Ik1bOZuV',
#       'id': '43mhFhQ4JAknA7Ik1bOZuV',
#       'name': 'Pat Benatar',
#       'type': 'artist',
#       'uri': 'spotify:artist:43mhFhQ4JAknA7Ik1bOZuV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Dz62BSPfz8XMmJCFtB9iN'},
#     'href': 'https://api.spotify.com/v1/albums/0Dz62BSPfz8XMmJCFtB9iN',
#     'id': '0Dz62BSPfz8XMmJCFtB9iN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ba1488cfe27aa7f6f0233475',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ba1488cfe27aa7f6f0233475',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ba1488cfe27aa7f6f0233475',
#       'width': 64}],
#     'name': 'Live From Earth',
#     'release_date': '1983-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0Dz62BSPfz8XMmJCFtB9iN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/43mhFhQ4JAknA7Ik1bOZuV'},
#      'href': 'https://api.spotify.com/v1/artists/43mhFhQ4JAknA7Ik1bOZuV',
#      'id': '43mhFhQ4JAknA7Ik1bOZuV',
#      'name': 'Pat Benatar',
#      'type': 'artist',
#      'uri': 'spotify:artist:43mhFhQ4JAknA7Ik1bOZuV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 325066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCH38400020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/06dAFXkgM2OGAkGS3CxpEm'},
#    'href': 'https://api.spotify.com/v1/tracks/06dAFXkgM2OGAkGS3CxpEm',
#    'id': '06dAFXkgM2OGAkGS3CxpEm',
#    'is_local': False,
#    'name': 'Love Is A Battlefield',
#    'popularity': 49,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:06dAFXkgM2OGAkGS3CxpEm'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-18T05:58:18Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IFXsrXBpwbIqtOUOiAa3p'},
#       'href': 'https://api.spotify.com/v1/artists/6IFXsrXBpwbIqtOUOiAa3p',
#       'id': '6IFXsrXBpwbIqtOUOiAa3p',
#       'name': 'Rick Springfield',
#       'type': 'artist',
#       'uri': 'spotify:artist:6IFXsrXBpwbIqtOUOiAa3p'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BD',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'FM',
#      'GD',
#      'GT',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'ID',
#      'IN',
#      'JM',
#      'KH',
#      'KN',
#      'KR',
#      'LA',
#      'LC',
#      'LK',
#      'MO',
#      'MV',
#      'MX',
#      'MY',
#      'NI',
#      'NP',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PY',
#      'SG',
#      'SR',
#      'SV',
#      'TH',
#      'TL',
#      'TT',
#      'TW',
#      'US',
#      'UY',
#      'VC',
#      'VN'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4KKFWTePKtgb6mOwFDqxYa'},
#     'href': 'https://api.spotify.com/v1/albums/4KKFWTePKtgb6mOwFDqxYa',
#     'id': '4KKFWTePKtgb6mOwFDqxYa',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734a57b8b911a372d77dfc1ba7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024a57b8b911a372d77dfc1ba7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514a57b8b911a372d77dfc1ba7',
#       'width': 64}],
#     'name': 'Working Class Dog',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4KKFWTePKtgb6mOwFDqxYa'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6IFXsrXBpwbIqtOUOiAa3p'},
#      'href': 'https://api.spotify.com/v1/artists/6IFXsrXBpwbIqtOUOiAa3p',
#      'id': '6IFXsrXBpwbIqtOUOiAa3p',
#      'name': 'Rick Springfield',
#      'type': 'artist',
#      'uri': 'spotify:artist:6IFXsrXBpwbIqtOUOiAa3p'}],
#    'available_markets': ['AG',
#     'AR',
#     'BB',
#     'BD',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BZ',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'DM',
#     'DO',
#     'EC',
#     'FM',
#     'GD',
#     'GT',
#     'GY',
#     'HK',
#     'HN',
#     'HT',
#     'ID',
#     'IN',
#     'JM',
#     'KH',
#     'KN',
#     'KR',
#     'LA',
#     'LC',
#     'LK',
#     'MO',
#     'MV',
#     'MX',
#     'MY',
#     'NI',
#     'NP',
#     'PA',
#     'PE',
#     'PH',
#     'PK',
#     'PY',
#     'SG',
#     'SR',
#     'SV',
#     'TH',
#     'TL',
#     'TT',
#     'TW',
#     'US',
#     'UY',
#     'VC',
#     'VN'],
#    'disc_number': 1,
#    'duration_ms': 194120,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC18108188'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5RsUlxLto4NZbhJpqJbHfN'},
#    'href': 'https://api.spotify.com/v1/tracks/5RsUlxLto4NZbhJpqJbHfN',
#    'id': '5RsUlxLto4NZbhJpqJbHfN',
#    'is_local': False,
#    'name': "Jessie's Girl",
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ced741429ab4c3a747d813149c8ed6f61d390f74?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5RsUlxLto4NZbhJpqJbHfN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-18T05:58:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/tomdavis19'},
#    'href': 'https://api.spotify.com/v1/users/tomdavis19',
#    'id': 'tomdavis19',
#    'type': 'user',
#    'uri': 'spotify:user:tomdavis19'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CLVPk9FcywjClBcTvWPkT'},
#       'href': 'https://api.spotify.com/v1/artists/2CLVPk9FcywjClBcTvWPkT',
#       'id': '2CLVPk9FcywjClBcTvWPkT',
#       'name': 'Loverboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CLVPk9FcywjClBcTvWPkT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6oZb0svo8JG9mVxZmHjPxE'},
#     'href': 'https://api.spotify.com/v1/albums/6oZb0svo8JG9mVxZmHjPxE',
#     'id': '6oZb0svo8JG9mVxZmHjPxE',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739c56254072383ce8172ab4c6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029c56254072383ce8172ab4c6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519c56254072383ce8172ab4c6',
#       'width': 64}],
#     'name': 'Get Lucky',
#     'release_date': '1981',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6oZb0svo8JG9mVxZmHjPxE'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CLVPk9FcywjClBcTvWPkT'},
#      'href': 'https://api.spotify.com/v1/artists/2CLVPk9FcywjClBcTvWPkT',
#      'id': '2CLVPk9FcywjClBcTvWPkT',
#      'name': 'Loverboy',
#      'type': 'artist',
#      'uri': 'spotify:artist:2CLVPk9FcywjClBcTvWPkT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 221000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAC228100002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/35k31HZI4z9PbBOioaI4dZ'},
#    'href': 'https://api.spotify.com/v1/tracks/35k31HZI4z9PbBOioaI4dZ',
#    'id': '35k31HZI4z9PbBOioaI4dZ',
#    'is_local': False,
#    'name': 'Working for the Weekend',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3fb4df4d5c847e68185ab29628e1a09006fe8e01?cid=48ab974ef0144ac3b768087512038973',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:35k31HZI4z9PbBOioaI4dZ'},
#   'video_thumbnail': {'url': None}}]

# %%
len(full_playlist)
# Out:
# 151

# %% [markdown]
# #### Exploring the playlist

# %%
full_playlist[0].keys()
#info for each track
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
full_playlist[0]['track'].keys()
# = playlist['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %% [markdown]
# #### Extracting track ids and artist ids

# %%
def get_track_ids_from_playlist(playlist):
    track_id=[]
    for item in playlist:
        track_id.append(item['track']['id'])
    
    return track_id

# %%
# Testing function:

get_track_ids_from_playlist(full_playlist)
# Out:
# ['39lSeqnyjZJejRuaREfyLL',
#  '7w4Tbkbx081vRJa8ol56Qf',
#  '5lmYpa6EaVAKAlwxMf7q5c',
#  '0HEmnAUT8PHznIAAmVXqFJ',
#  '7jtGa7FmUx7YxTbiy6tEsX',
#  '3X7abqSXC4xrxuC1ykpWcY',
#  '6qUEOWqOzu1rLPUPQ1ECpx',
#  '2dzMbi6uW2EE4cgzxf8vcO',
#  '7n1sAeis4HONDsNnnqmtaU',
#  '37BTh5g05cxBIRYMbw8g2T',
#  '77NNZQSqzLNqh2A9JhLRkg',
#  '5Du6gEDduLCB9FIm9xIE4w',
#  '0qi4b1l0eT3jpzeNHeFXDT',
#  '3KuAa8Y79xlfJgYtBKbynY',
#  '6A8OnjnpShshNpcqWtZRjr',
#  '0ikz6tENMONtK6qGkOrU3c',
#  '7GhIk7Il098yCjg4BQjzvb',
#  '7N3PAbqfTjSEU1edb2tY8j',
#  '4RvWPyQ5RL0ao9LPZeSouE',
#  '6W2VbtvMrDXm5vYeB7amkO',
#  '2I3jWxB1atY6KAnwnIZbcD',
#  '5ZEKq8JRtVVXZXEZ9eI9Wf',
#  '3AgvZyLH4sWkII5bnU80aQ',
#  '5eU8qMd0TpaLqTGDZJaLDs',
#  '15MJ5NThPjj6xhPcts8MiY',
#  '11IzgLRXV7Cgek3tEgGgjw',
#  '4kjgGgDbNN4nR3OZYuRkUe',
#  '6KqWBiEZxRmPPGDc0PkRoV',
#  '45oFq8ZKV9KDhzYb2Rh1y4',
#  '5TgD3Wh5ZUZnUU4tmVvJbx',
#  '5prTs2HAw2G4idHZyeFp8o',
#  '7HKxTNVlkHsfMLhigmhC0I',
#  '084PXFhuurZHjsjgdwQci6',
#  '6t1FIJlZWTQfIZhsGjaulM',
#  '3U7H63zKWLjOuFZJUmTowp',
#  '57JVGBtBLCfHw2muk5416J',
#  '0DhTXf8sZ1ahNpPD9ibmge',
#  '34x6hEJgGAOQvmlMql5Ige',
#  '18AXbzPzBS8Y3AkgSxzJPb',
#  '4uOKFydzAejjSFqYbv1XPt',
#  '61UU9qfuXmdFyqCSE7v5gz',
#  '0GONea6G2XdnHWjNZd6zt3',
#  '2rKs3UV10xv1NAdVCQH4gm',
#  '2F1fnE1a8zQCogM6jJifHH',
#  '72AO8u6lcjKp0CBeaPZT8I',
#  '0ObLFkX9bnGBZMFVeLFRN4',
#  '765E8MK8PYdkDQilOkEDdD',
#  '29r3fDexnrto7WABfpblNH',
#  '0aAR5HogGoT68EWFbyRFqx',
#  '4aMT5LHe8A2uIc11H8Cx2m',
#  '1td7gSf8cdWKZBLVtsRnYP',
#  '3rOD3MfHaXawznE0vrjM5B',
#  '3ZZq9396zv8pcn5GYVhxUi',
#  '0viZ7D81W8pD65TkzaFkXT',
#  '1E8qiEnaCzyiOicYsabbtX',
#  '4YwbSZaYeYja8Umyt222Qf',
#  '6bmHdVrNxawHecz0zUFSDh',
#  '5JGEAz15LkPoOtFHttDtVs',
#  '5UqqOfFa9DYXALpCCF8VwB',
#  '1jDJFeK9x3OZboIAHsY9k2',
#  '4sz1Ng2Cgidfqqiy0pNL6R',
#  '6CSLNGruNhqpb5zhfs5n3i',
#  '1QbQL5m30YNvukitIqAnFG',
#  '0p7T2DoRUeLX47sa3Ar2Ny',
#  '2RWFncSWZEhSRRifqiDNVV',
#  '3zLZ7AVfbYuy0BnRWLafZg',
#  '7yBl8YmvcgwwYlazJcvowE',
#  '2rzPxJ8y7ekQwmAIVyStmf',
#  '3dh2LlmeMqKJbzn2WUgt3d',
#  '5suJZTE8SpSmR4zMqxLg3V',
#  '4HUtl3utOjpVEEXiXJmXVj',
#  '00MI0oGDVJYM1qWbyUOIhH',
#  '165NAtd2DRPKNQ6EVY0VG9',
#  '02kqNEFXbcFg22pyvUyjmI',
#  '7nGgkIi6JzhcdwOx7rDZEJ',
#  '21MsRs5ShUpwYsr6xfuPyH',
#  '7woZGXjtaYwuvSoU1zToB3',
#  '5wiu4PUC6CLNNbC48vqGOb',
#  '63nVsCAdxu9OdeRhe58wiE',
#  '36lkJSDyMEZoWTqtRj8Q8q',
#  '28o8m1o9RGtySbmQJtAvym',
#  '2STQAr3BRiAeeveJ07gZh7',
#  '4xh7W7tlNMIczFhupCPniY',
#  '7HKez549fwJQDzx3zLjHKC',
#  '05XkaRvGIt5LtllUuhMAKA',
#  '5pKJtX4wBeby9qIfFhyOJj',
#  '6eBK3edMW7bEzecF1eCezc',
#  '46ERhnELy62toOMlxe14a3',
#  '5AbrdOBpQBsokNEoHCBdph',
#  '3btRbeejnidrYVyJt6J7Gz',
#  '3pv1zg1cEaSkfI6KrztXcV',
#  '12tgeg7ebk5bPe1yaRlSZl',
#  '0Sqoc9LwnywG5rMKrPil1Q',
#  '6Fj36toK6ky8HhyZdVTsce',
#  '3KTxIOIZIE7UM6vwCX4Ofv',
#  '4XluM0ZU23YGFfAWIfWWR5',
#  '1DWmir4zA2RO1HkAeD2vrD',
#  '3f9rDvpiE3CWQ0sWClzi0R',
#  '6uU5OBhGUE1ngSKDj4wtoq',
#  '2TxMiY9AxY3YTiStOG69wU',
#  '3y7j9iz5XfbDOySTspM4Ss',
#  '23IK8TF2MSiLnuEjaYPfVV',
#  '58ouLz1kKVf68BvQeZQHBz',
#  '0WYsZQBSAn0p0nRGEs0oXV',
#  '7gTH723Ynh5smCgLWbG91b',
#  '2sXp9Qmvc7mRaDBjBgcGGi',
#  '5izGeTxueiFX1UPFGohY9w',
#  '0yelVo6DA76GpFfBRPnK0j',
#  '5LYJ631w9ps5h9tdvac7yP',
#  '6hQszXJIYhtjmSTmDqZpeU',
#  '5Wf3fhu9g29AA7nqZfEvrY',
#  '4KYYBswaPuKPaKaLzoBcIE',
#  '7Ewz6bJ97vUqk5HdkvguFQ',
#  '1At0C8SdwvSpERXtgefXuc',
#  '715sEYWkafd4xvl87dwZgu',
#  '4yqtwO7MQIIXqoiRBPHAgR',
#  '1VKXBgsRK7lWDSVbfANlf3',
#  '1Ih6wTuQems9OkYTzcZdhM',
#  '6QueWxs5YJnRtqIdsH0EGR',
#  '5nBiM1Hjby8YnuLE59UBT0',
#  '35ItUJlMtjOQW3SSiTCrrw',
#  '0xpBr84T3FTm9j4D1MdPtk',
#  '0f798jZ9aYI34zo4lchKd0',
#  '0c2VC70y7jq5qMPQnuunCP',
#  '2uXewDKMktNkkMfotqSxN6',
#  '4uvjOKsp7mSjrDhWdkLPBY',
#  '3tmeua6TKrQAEyniklh9D9',
#  '3CFRrpmTnGYi0JC7QDIxFP',
#  '6dQhl7KGOjjWT0er2iXWI9',
#  '7vJnM5FUcOV3xAKJHSSUWj',
#  '3imnzhFxhvrlLtvQP2um4B',
#  '28P5HAF0Kll9Xd9dX4qw7A',
#  '3kNIXrf4wOLxBh40tA5NtN',
#  '6hdNOhGNR1x0q7xPfOfYhm',
#  '7nm8w9dMwTjlWDosdnxBSn',
#  '7IBJfXwBlrrdkGqpQzOFgb',
#  '6bSUwRCwMvLDOZRvWLN9Ea',
#  '6LoSKNsYkRQbyuiReooMjG',
#  '1HmzAZUvhQLhLo2z3ocpZI',
#  '3cKoZTSXsSBal8cU77fnqF',
#  '5pDmunv6G71w7NSjOPXbYw',
#  '1E2iehquphUsbmj8VTzWdQ',
#  '0sTHEo24E8LxasEkSnpUkx',
#  '75wP08AtMfGfjk0nPdvVw3',
#  '08cX6cPeOywTzqTaLF6lXn',
#  '1Jj6MF0xDOMA3Ut2Z368Bx',
#  '2zjt2hHBbiv5SuxYg8Z7eP',
#  '0vOkmmJEtjuFZDzrQSFzEE',
#  '06dAFXkgM2OGAkGS3CxpEm',
#  '5RsUlxLto4NZbhJpqJbHfN',
#  '35k31HZI4z9PbBOioaI4dZ']

# %%
def get_artist_ids_from_playlist(playlist):
    artist_id=[]
    for item in full_playlist:
        artist_id.append(item['track']['artists'][0]['id'])
    
    return artist_id

# %%
# Testing function:

get_artist_ids_from_playlist(full_playlist)
# Out:
# ['0lZoBs4Pzo7R89JM9lxwoT',
#  '0WwSkZ7LtFUFjGjMZBMt6T',
#  '1aX2dmV8XoHYCOQRxjPESG',
#  '19ra5tSw0tWufvUp8GotLo',
#  '6hN9F0iuULZYWXppob22Aj',
#  '58lV9VcRSjABbAbfWS6skp',
#  '3CQIn7N5CuRDP8wEI7FiDA',
#  '3fMbdgg4jU18AjLCKBhRSm',
#  '2TzHIUhVpeeDxyJPpQfnV3',
#  '0PFtn5NtBbbUNbU9EAmIWF',
#  '0rvjqX7ttXeg3mTy8Xscbt',
#  '6aq8T2RcspxVOGgMrTzjWc',
#  '762310PdDnwsDxAQxzQkfX',
#  '1G1mX30GpUJqOr1QU2eBSs',
#  '6tbjWDEIzxoDsBA1FuhfPW',
#  '5lpH0xAS4fVfLkACg9DAuM',
#  '0gxyHStUsqpMadRV0Di1Qt',
#  '2cnMpRsOVqtPMfq7YiFE6K',
#  '4bthk9UfsYUYdcFyqxmSUU',
#  '3Y3xIwWyq5wnNHPp5gPjOW',
#  '20p5D2KrE8CGuOjHtxsyTp',
#  '51l0uqRxGaczYr4271pVIC',
#  '2kreKea2n96dXjcyAU9j5N',
#  '1eClJfHLoDI4rZe5HxzBFv',
#  '2aS6jYh7ysTL1ZUsHneNgM',
#  '1dfeR4HaWDbWqFHLkxsg1d',
#  '3gMaNLQm7D9MornNILzdSl',
#  '3sc7iUG1Wwpwx7bHeZolgx',
#  '771qBvjnXOH9Azr6lKy6FB',
#  '19xz1vcuKNjniGEftTOSSH',
#  '0SD4eZCN4Kr0wQk56hCdh2',
#  '4tpUmLEVLCGFr93o8hFFIB',
#  '51l0uqRxGaczYr4271pVIC',
#  '057gc1fxmJ2vkctjQJ7Tal',
#  '58lV9VcRSjABbAbfWS6skp',
#  '1dfeR4HaWDbWqFHLkxsg1d',
#  '0LyfQWJT6nXafLPZqxe9Of',
#  '3Y3xIwWyq5wnNHPp5gPjOW',
#  '4lxfqrEsLX6N1N4OCSkILp',
#  '69MEO1AADKg1IZrq2XLzo5',
#  '0SD4eZCN4Kr0wQk56hCdh2',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '0kObWap02DEg9EAJ3PBxzf',
#  '6IFXsrXBpwbIqtOUOiAa3p',
#  '51Blml2LZPmy7TTiAg47vQ',
#  '5IDs1CK15HegSAhGEbSYXo',
#  '4lxfqrEsLX6N1N4OCSkILp',
#  '0f3EsoviYnRKTkmayI3cux',
#  '3oZa8Xs6IjlIUGLAhVyK4G',
#  '5IFCkqu9J6xdWeYMk5I889',
#  '3sc7iUG1Wwpwx7bHeZolgx',
#  '4AYkFtEBnNnGuoo8HaHErd',
#  '0f3EsoviYnRKTkmayI3cux',
#  '43mhFhQ4JAknA7Ik1bOZuV',
#  '0WwSkZ7LtFUFjGjMZBMt6T',
#  '4lxfqrEsLX6N1N4OCSkILp',
#  '4salDzkGmfycRqNUbyBphh',
#  '51Blml2LZPmy7TTiAg47vQ',
#  '1XE70WwxhnrXNAJYQQ9ygx',
#  '3PhoLpVuITZKcymswpck5b',
#  '0lZoBs4Pzo7R89JM9lxwoT',
#  '3VNITwohbvU5Wuy5PC6dsI',
#  '0smy8yDrRoI4CnhpOuthg0',
#  '5dbuFbrHa1SJlQhQX9OUJ2',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '1aX2dmV8XoHYCOQRxjPESG',
#  '3oZa8Xs6IjlIUGLAhVyK4G',
#  '0lZoBs4Pzo7R89JM9lxwoT',
#  '51Blml2LZPmy7TTiAg47vQ',
#  '02Xpf8IlAGeelWAQZP33kQ',
#  '2eogQKWWoohI3BSnoG7E2U',
#  '1n2LWYgwtGp7EzDapUoniE',
#  '4tpUmLEVLCGFr93o8hFFIB',
#  '19ra5tSw0tWufvUp8GotLo',
#  '7Bah8E0kCETqEpAHI6CPzQ',
#  '3lPQ2Fk5JOwGWAF3ORFCqH',
#  '2UZMlIwnkgAEDBsw1Rejkn',
#  '3VNITwohbvU5Wuy5PC6dsI',
#  '7Bah8E0kCETqEpAHI6CPzQ',
#  '3iDD7bnsjL9J4fO298r0L0',
#  '0PFtn5NtBbbUNbU9EAmIWF',
#  '3oDbviiivRWhXwIE8hxkVV',
#  '08GQAI4eElDnROBrJRGE0X',
#  '22bE4uQ6baNwSHPVcDxLCe',
#  '7xkAwz0bQTGDSbkofyQt3U',
#  '3PhoLpVuITZKcymswpck5b',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '58lV9VcRSjABbAbfWS6skp',
#  '4STHEaNw4mPZ2tzheohgXB',
#  '58lV9VcRSjABbAbfWS6skp',
#  '3RFGnJaDVOyxL9YcFaKatu',
#  '7A9yZMTrFZcgEWAX2kBfK6',
#  '0smy8yDrRoI4CnhpOuthg0',
#  '6is2U7I1jlI8PjxNZOHIMV',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '6IFXsrXBpwbIqtOUOiAa3p',
#  '0kObWap02DEg9EAJ3PBxzf',
#  '6IFXsrXBpwbIqtOUOiAa3p',
#  '6OWapcJm9xd55ci9CYbAuT',
#  '3RFGnJaDVOyxL9YcFaKatu',
#  '26bcq2nyj5GB7uRr558iQg',
#  '6twIAGnYuIT1pncMAsXnEm',
#  '6Zh3xrWlA0SA9Fsfj9AVwm',
#  '5dbuFbrHa1SJlQhQX9OUJ2',
#  '3lPQ2Fk5JOwGWAF3ORFCqH',
#  '5NGO30tJxFlKixkPSgXcFE',
#  '530Sdm7eqqzWBdDmILMgnu',
#  '3xs0LEzcPXtgNfMNcHzLIP',
#  '6ZNeppgfBLPUyugks9Yn1u',
#  '3zXw2Eh96iTT51pytzHdZi',
#  '1HvcqyRLS9nF8hAbTWOqpr',
#  '7A9yZMTrFZcgEWAX2kBfK6',
#  '3Z02hBLubJxuFJfhacLSDc',
#  '1aX2dmV8XoHYCOQRxjPESG',
#  '7A9yZMTrFZcgEWAX2kBfK6',
#  '0WwSkZ7LtFUFjGjMZBMt6T',
#  '2yTUYhIf8fxptTIy3KLuJD',
#  '3gMaNLQm7D9MornNILzdSl',
#  '3gMaNLQm7D9MornNILzdSl',
#  '2TPyCsRoh2tjeZLTQ2ojlj',
#  '1dfeR4HaWDbWqFHLkxsg1d',
#  '3CkvROUTQ6nRi9yQOcsB50',
#  '4bthk9UfsYUYdcFyqxmSUU',
#  '7A9yZMTrFZcgEWAX2kBfK6',
#  '0L9xkvBPcEp1nrhDrodxc5',
#  '4C3uGP8vRDzxrhJxZiOjTe',
#  '2iM28IgKg89v1o7BTQAVPo',
#  '4lxfqrEsLX6N1N4OCSkILp',
#  '5jVeqi3PNaTOajfvBa4uFn',
#  '3Y3xIwWyq5wnNHPp5gPjOW',
#  '4BoRxUdrcgbbq1rxJvvhg9',
#  '26bcq2nyj5GB7uRr558iQg',
#  '6kz53iCdBSqhQCZ21CoLcc',
#  '2The4Ur661sLPGndcUuuLu',
#  '057gc1fxmJ2vkctjQJ7Tal',
#  '32lVGr0fSRGT6okLKHiP68',
#  '3zXw2Eh96iTT51pytzHdZi',
#  '1Ha0Fz4i0d4gu5fZbhBCtH',
#  '1dfeR4HaWDbWqFHLkxsg1d',
#  '43mhFhQ4JAknA7Ik1bOZuV',
#  '5NGO30tJxFlKixkPSgXcFE',
#  '0rvjqX7ttXeg3mTy8Xscbt',
#  '0NyzfcGDZZ6GM25EBG9BYK',
#  '4tX2TplrkIP4v05BNC903e',
#  '1n2LWYgwtGp7EzDapUoniE',
#  '2BTZIqw0ntH9MvilQ3ewNY',
#  '2BTZIqw0ntH9MvilQ3ewNY',
#  '43mhFhQ4JAknA7Ik1bOZuV',
#  '43mhFhQ4JAknA7Ik1bOZuV',
#  '6IFXsrXBpwbIqtOUOiAa3p',
#  '2CLVPk9FcywjClBcTvWPkT']

# %% [markdown]
# #### Removing duplicated artist ids

# %%
artist_ids = get_artist_ids_from_playlist(full_playlist)
artist_ids = list(dict.fromkeys(artist_ids))
len(artist_ids)
# Out:
# 93

# %% [markdown]
# #### Get all songs from each artist

# %% [markdown]
# - In order to get all songs from an artist, we first need to get all albums. Then, we will get all songs from each album

# %% [markdown]
# ##### Get album ids

# %%
def get_ablum_names_from_artist_ids(artist_ids):
    
    album_names = []
    for i in artist_ids:
        albums_info = sp.artist_albums(i, album_type='album')
        albums_info_items = albums_info['items']
        # print(albums_info_items)   --->  [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'}, 'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT', 'id': '0lZoBs4Pzo7R89JM9lxwoT', 'name': 'Duran Duran',
        while albums_info['next']:
            albums_info = sp.next(albums_info)
            albums_info_items.extend(albums_info['items'])
        for i in albums_info_items:
            album_names.append(i['name'])
    
    return album_names

# %%
def get_ablum_ids_from_artist_ids(artist_ids):
    
    album_ids=[]
    for i in artist_ids:
        albums_info = sp.artist_albums(i, album_type='album')
        albums_info_items = albums_info['items']
        # print(albums_info_items)   --->  [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'}, 'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT', 'id': '0lZoBs4Pzo7R89JM9lxwoT', 'name': 'Duran Duran',
        while albums_info['next']:
            albums_info = sp.next(albums_info)
            albums_info_items.extend(albums_info['items'])
        for i in albums_info_items:
            album_ids.append(i['id'])
    
    return album_ids

# %%
len(get_ablum_ids_from_artist_ids(artist_ids))
# Out:
# 2240

# %% [markdown]
# #### Removing duplicated album ids

# %%
album_ids = get_ablum_ids_from_artist_ids(artist_ids)
album_ids = list(dict.fromkeys(album_ids))
len(album_ids)
# Out:
# 2238

# %% [markdown]
# ##### Get all song names from album ids

# %%
def get_song_names_from_album_ids(album_ids):
    
    song_names=[]
    for i in album_ids:
        albums_tracks= sp.album_tracks(i)
        albums_tracks_items = albums_tracks['items']
        # print(albums_info_items)   --->  [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'}, 'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT', 'id': '0lZoBs4Pzo7R89JM9lxwoT', 'name': 'Duran Duran',
        while albums_tracks['next']:
            albums_tracks = sp.next(albums_tracks)
            albums_tracks_items.extend(albums_tracks['items'])
        for i in albums_tracks_items:
            song_names.append(i['name'])
    
    return song_names

# %%
len(get_song_names_from_album_ids(album_ids))
# Out:
# 34243

# %% [markdown]
# ### Get track id, artist id, audio features of all 34.243 songs

# %%
def get_song_ids_from_album_ids(album_ids):
    
    song_ids=[]
    for i in album_ids:
        albums_tracks= sp.album_tracks(i)
        albums_tracks_items = albums_tracks['items']
        # print(albums_info_items)   --->  [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lZoBs4Pzo7R89JM9lxwoT'}, 'href': 'https://api.spotify.com/v1/artists/0lZoBs4Pzo7R89JM9lxwoT', 'id': '0lZoBs4Pzo7R89JM9lxwoT', 'name': 'Duran Duran',
        while albums_tracks['next']:
            albums_tracks = sp.next(albums_tracks)
            albums_tracks_items.extend(albums_tracks['items'])
        for i in albums_tracks_items:
            song_ids.append(i['id'])
    
    return song_ids

# %%
song_ids = get_song_ids_from_album_ids(album_ids)

# %%
#02tfQwJSOLP77oCd9U8bqm --> duran duran album: Rio(Collectors Edition)

#39lSeqnyjZJejRuaREfyLL --> duran duran song: hungry like a wolf

# %%
songs_100 = song_ids[0:50]

# %%
songs_500 = song_ids[0:500]

# %% [markdown]
# sp.tracks function can only take 51 songs!

# %%
#info_all_tracks = sp.tracks(['39lSeqnyjZJejRuaREfyLL'])

# %%
info_all_tracks = sp.tracks(songs_100)

# %% [markdown]
# #### Splittingg the 34243 songs into groups of 50

# %%
def track_chunks(song_ids):
    chunks = [song_ids[x:x+50] for x in range(0, len(song_ids), 50)]
    return chunks

# %%
def track_chunks_100(song_ids):
    chunks = [song_ids[x:x+100] for x in range(0, len(song_ids), 100)]
    return chunks

# %%
#track_chunks(song_ids)

# %%
# just taking the 1st artist:

def first_artist_name_from_song_ids_complete (song_ids):
    
    chunks = track_chunks(song_ids)
    
    artist_names = []
    
    for i in chunks:
        track_info = sp.tracks(i)
        track_info_track = track_info['tracks']
        
        for i in track_info_track:
            artist_names.append(i['artists'][0]['name'])
        
        
    return artist_names

# %%
len(first_artist_name_from_song_ids_complete(song_ids))
# Out:
# 34243

# %%
len(song_ids)
# Out:
# 34243

# %%
#def artist_ids_from_song_ids_complete (song_ids):
    
#    chunks = track_chunks(song_ids)
    
#    artist_names = []
    
#    for i in chunks:
#        track_info = sp.tracks(i)
#        track_info_track = track_info['tracks']
        
#        for i in track_info_track:
#            track_artist = i['artists']
            
#            for i in track_artist:
#                artist_names.append(i['name'])
        
        
#   return artist_names

# %% [markdown]
# #### Dataframe of songs and artists

# %%
titles = get_song_names_from_album_ids(album_ids)

# %%
artists = first_artist_name_from_song_ids_complete(song_ids)

# %%
d = list(zip(titles,artists))
titles_artists_df = pd.DataFrame(d, columns=['title','artist'])

# %%
titles_artists_df.head()
# Out:
#                          title       artist
# 0               Opening - Live  Duran Duran
# 1                 Intro - Live  Duran Duran
# 2           Medazzaland - Live  Duran Duran
# 3   Big Bang Generation - Live  Duran Duran
# 4  Hungry Like the Wolf - Live  Duran Duran

# %%
titles_artists_df.shape
# Out:
# (34243, 2)

# %% [markdown]
# ### Audio features

# %%
titles_artists_df_100 = titles_artists_df[: 100]

# %%
titles_artists_df_100
# Out:
#                           title       artist
# 0                Opening - Live  Duran Duran
# 1                  Intro - Live  Duran Duran
# 2            Medazzaland - Live  Duran Duran
# 3    Big Bang Generation - Live  Duran Duran
# 4   Hungry Like the Wolf - Live  Duran Duran
# ..                          ...          ...
# 95  The Man Who Stole A Leopard  Duran Duran
# 96         Other People's Lives  Duran Duran
# 97                 Mediterranea  Duran Duran
# 98  Too Bad You're So Beautiful  Duran Duran
# 99               Runway Runaway  Duran Duran
#
# [100 rows x 2 columns]

# %%
audio_feat_df=pd.DataFrame(sp.audio_features(tracks=songs_100))

# %%
audio_feat_list=sp.audio_features(tracks=songs_100)

# %%
audio_feat_list
# Out:
# [{'danceability': 0.307,
#   'energy': 0.153,
#   'key': 10,
#   'loudness': -25.952,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.883,
#   'instrumentalness': 0.971,
#   'liveness': 0.84,
#   'valence': 0.13,
#   'tempo': 79.853,
#   'type': 'audio_features',
#   'id': '3kjoAqJUsLs8TKZaofvPnd',
#   'uri': 'spotify:track:3kjoAqJUsLs8TKZaofvPnd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kjoAqJUsLs8TKZaofvPnd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kjoAqJUsLs8TKZaofvPnd',
#   'duration_ms': 171880,
#   'time_signature': 4},
#  {'danceability': 0.478,
#   'energy': 0.561,
#   'key': 10,
#   'loudness': -14.545,
#   'mode': 0,
#   'speechiness': 0.0754,
#   'acousticness': 0.121,
#   'instrumentalness': 0.0114,
#   'liveness': 0.881,
#   'valence': 0.257,
#   'tempo': 118.898,
#   'type': 'audio_features',
#   'id': '4NTNiAtUyadCRye3LlHnGY',
#   'uri': 'spotify:track:4NTNiAtUyadCRye3LlHnGY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NTNiAtUyadCRye3LlHnGY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NTNiAtUyadCRye3LlHnGY',
#   'duration_ms': 65200,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.927,
#   'key': 10,
#   'loudness': -6.744,
#   'mode': 0,
#   'speechiness': 0.069,
#   'acousticness': 0.0555,
#   'instrumentalness': 0.0477,
#   'liveness': 0.701,
#   'valence': 0.537,
#   'tempo': 118.744,
#   'type': 'audio_features',
#   'id': '1CqNphayCWFkjvVBM8Tc9y',
#   'uri': 'spotify:track:1CqNphayCWFkjvVBM8Tc9y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CqNphayCWFkjvVBM8Tc9y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CqNphayCWFkjvVBM8Tc9y',
#   'duration_ms': 227520,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.902,
#   'key': 6,
#   'loudness': -6.028,
#   'mode': 0,
#   'speechiness': 0.104,
#   'acousticness': 0.00157,
#   'instrumentalness': 0.0121,
#   'liveness': 0.697,
#   'valence': 0.245,
#   'tempo': 99.944,
#   'type': 'audio_features',
#   'id': '0r5JSBykFXMEbYkhapxZ3o',
#   'uri': 'spotify:track:0r5JSBykFXMEbYkhapxZ3o',
#   'track_href': 'https://api.spotify.com/v1/tracks/0r5JSBykFXMEbYkhapxZ3o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0r5JSBykFXMEbYkhapxZ3o',
#   'duration_ms': 347440,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.932,
#   'key': 7,
#   'loudness': -5.841,
#   'mode': 1,
#   'speechiness': 0.0711,
#   'acousticness': 0.0338,
#   'instrumentalness': 9.28e-06,
#   'liveness': 0.717,
#   'valence': 0.665,
#   'tempo': 128.864,
#   'type': 'audio_features',
#   'id': '2QUrwP0t7rWiD8Beit13h4',
#   'uri': 'spotify:track:2QUrwP0t7rWiD8Beit13h4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QUrwP0t7rWiD8Beit13h4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QUrwP0t7rWiD8Beit13h4',
#   'duration_ms': 204067,
#   'time_signature': 4},
#  {'danceability': 0.281,
#   'energy': 0.578,
#   'key': 2,
#   'loudness': -5.872,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.024,
#   'instrumentalness': 9.42e-06,
#   'liveness': 0.699,
#   'valence': 0.177,
#   'tempo': 129.021,
#   'type': 'audio_features',
#   'id': '0v20RVp8fqU8SALt8Pastg',
#   'uri': 'spotify:track:0v20RVp8fqU8SALt8Pastg',
#   'track_href': 'https://api.spotify.com/v1/tracks/0v20RVp8fqU8SALt8Pastg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0v20RVp8fqU8SALt8Pastg',
#   'duration_ms': 218707,
#   'time_signature': 4},
#  {'danceability': 0.494,
#   'energy': 0.837,
#   'key': 0,
#   'loudness': -5.354,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.00513,
#   'instrumentalness': 0.0162,
#   'liveness': 0.82,
#   'valence': 0.515,
#   'tempo': 128.941,
#   'type': 'audio_features',
#   'id': '0uu4WLNaELy4X3wGWx9qkq',
#   'uri': 'spotify:track:0uu4WLNaELy4X3wGWx9qkq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0uu4WLNaELy4X3wGWx9qkq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0uu4WLNaELy4X3wGWx9qkq',
#   'duration_ms': 313013,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.698,
#   'key': 8,
#   'loudness': -5.881,
#   'mode': 1,
#   'speechiness': 0.058,
#   'acousticness': 0.0271,
#   'instrumentalness': 3.05e-05,
#   'liveness': 0.776,
#   'valence': 0.337,
#   'tempo': 124.775,
#   'type': 'audio_features',
#   'id': '2TAUDaQbdaX6n2K0UzmbFQ',
#   'uri': 'spotify:track:2TAUDaQbdaX6n2K0UzmbFQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TAUDaQbdaX6n2K0UzmbFQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TAUDaQbdaX6n2K0UzmbFQ',
#   'duration_ms': 255467,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.701,
#   'key': 1,
#   'loudness': -7.299,
#   'mode': 0,
#   'speechiness': 0.0392,
#   'acousticness': 0.0419,
#   'instrumentalness': 0.00066,
#   'liveness': 0.989,
#   'valence': 0.331,
#   'tempo': 86.012,
#   'type': 'audio_features',
#   'id': '1ICYXdDq5B2R0B51opUHz1',
#   'uri': 'spotify:track:1ICYXdDq5B2R0B51opUHz1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ICYXdDq5B2R0B51opUHz1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ICYXdDq5B2R0B51opUHz1',
#   'duration_ms': 337147,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.689,
#   'key': 0,
#   'loudness': -6.674,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.0318,
#   'instrumentalness': 1.91e-06,
#   'liveness': 0.815,
#   'valence': 0.377,
#   'tempo': 113.644,
#   'type': 'audio_features',
#   'id': '3GwOxticDVhjKtx7J33tbz',
#   'uri': 'spotify:track:3GwOxticDVhjKtx7J33tbz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GwOxticDVhjKtx7J33tbz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GwOxticDVhjKtx7J33tbz',
#   'duration_ms': 361147,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.733,
#   'key': 7,
#   'loudness': -6.379,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'acousticness': 0.0073,
#   'instrumentalness': 3.56e-05,
#   'liveness': 0.779,
#   'valence': 0.399,
#   'tempo': 96.011,
#   'type': 'audio_features',
#   'id': '0xYMDt67FFwsNqCb8jHVwG',
#   'uri': 'spotify:track:0xYMDt67FFwsNqCb8jHVwG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xYMDt67FFwsNqCb8jHVwG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xYMDt67FFwsNqCb8jHVwG',
#   'duration_ms': 337840,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.744,
#   'key': 9,
#   'loudness': -9.003,
#   'mode': 1,
#   'speechiness': 0.0249,
#   'acousticness': 0.0113,
#   'instrumentalness': 0.058,
#   'liveness': 0.946,
#   'valence': 0.335,
#   'tempo': 99.949,
#   'type': 'audio_features',
#   'id': '4MUNNsHJWFjM1aMQwJDdqG',
#   'uri': 'spotify:track:4MUNNsHJWFjM1aMQwJDdqG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4MUNNsHJWFjM1aMQwJDdqG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MUNNsHJWFjM1aMQwJDdqG',
#   'duration_ms': 283573,
#   'time_signature': 3},
#  {'danceability': 0.404,
#   'energy': 0.778,
#   'key': 0,
#   'loudness': -6.368,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.129,
#   'instrumentalness': 6e-05,
#   'liveness': 0.692,
#   'valence': 0.376,
#   'tempo': 173.892,
#   'type': 'audio_features',
#   'id': '5ajQvWo3ZKBV9nsnM47f3T',
#   'uri': 'spotify:track:5ajQvWo3ZKBV9nsnM47f3T',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ajQvWo3ZKBV9nsnM47f3T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ajQvWo3ZKBV9nsnM47f3T',
#   'duration_ms': 326547,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.857,
#   'key': 9,
#   'loudness': -6.254,
#   'mode': 0,
#   'speechiness': 0.0632,
#   'acousticness': 0.0151,
#   'instrumentalness': 0.00276,
#   'liveness': 0.771,
#   'valence': 0.385,
#   'tempo': 138.235,
#   'type': 'audio_features',
#   'id': '0d1ZBMWqFGV3lDGIhxGtkt',
#   'uri': 'spotify:track:0d1ZBMWqFGV3lDGIhxGtkt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0d1ZBMWqFGV3lDGIhxGtkt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0d1ZBMWqFGV3lDGIhxGtkt',
#   'duration_ms': 262893,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.895,
#   'key': 7,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0768,
#   'acousticness': 0.0366,
#   'instrumentalness': 4.21e-05,
#   'liveness': 0.795,
#   'valence': 0.35,
#   'tempo': 126.232,
#   'type': 'audio_features',
#   'id': '6h2lDrHbhZj2wUpVX8OUFd',
#   'uri': 'spotify:track:6h2lDrHbhZj2wUpVX8OUFd',
#   'track_href': 'https://api.spotify.com/v1/tracks/6h2lDrHbhZj2wUpVX8OUFd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6h2lDrHbhZj2wUpVX8OUFd',
#   'duration_ms': 358680,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.939,
#   'key': 2,
#   'loudness': -5.556,
#   'mode': 1,
#   'speechiness': 0.0742,
#   'acousticness': 0.026,
#   'instrumentalness': 0.0299,
#   'liveness': 0.979,
#   'valence': 0.711,
#   'tempo': 161.792,
#   'type': 'audio_features',
#   'id': '7LwarhbK2SCOubSYT9Hxsf',
#   'uri': 'spotify:track:7LwarhbK2SCOubSYT9Hxsf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LwarhbK2SCOubSYT9Hxsf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LwarhbK2SCOubSYT9Hxsf',
#   'duration_ms': 223333,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -9.158,
#   'mode': 1,
#   'speechiness': 0.026,
#   'acousticness': 0.0279,
#   'instrumentalness': 1.87e-06,
#   'liveness': 0.728,
#   'valence': 0.178,
#   'tempo': 120.631,
#   'type': 'audio_features',
#   'id': '7edL9lqUDCxbMctSw5zG0y',
#   'uri': 'spotify:track:7edL9lqUDCxbMctSw5zG0y',
#   'track_href': 'https://api.spotify.com/v1/tracks/7edL9lqUDCxbMctSw5zG0y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7edL9lqUDCxbMctSw5zG0y',
#   'duration_ms': 398707,
#   'time_signature': 4},
#  {'danceability': 0.446,
#   'energy': 0.709,
#   'key': 1,
#   'loudness': -6.477,
#   'mode': 0,
#   'speechiness': 0.0328,
#   'acousticness': 0.048,
#   'instrumentalness': 4.69e-05,
#   'liveness': 0.561,
#   'valence': 0.334,
#   'tempo': 139.807,
#   'type': 'audio_features',
#   'id': '1H69q2ckMIeF6y7nagqxC3',
#   'uri': 'spotify:track:1H69q2ckMIeF6y7nagqxC3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1H69q2ckMIeF6y7nagqxC3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1H69q2ckMIeF6y7nagqxC3',
#   'duration_ms': 364893,
#   'time_signature': 4},
#  {'danceability': 0.428,
#   'energy': 0.955,
#   'key': 9,
#   'loudness': -5.901,
#   'mode': 1,
#   'speechiness': 0.19,
#   'acousticness': 0.0148,
#   'instrumentalness': 0.000185,
#   'liveness': 0.762,
#   'valence': 0.297,
#   'tempo': 140.926,
#   'type': 'audio_features',
#   'id': '0Cxb1MoV37Gn1nUAtFbuqP',
#   'uri': 'spotify:track:0Cxb1MoV37Gn1nUAtFbuqP',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Cxb1MoV37Gn1nUAtFbuqP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Cxb1MoV37Gn1nUAtFbuqP',
#   'duration_ms': 393813,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.488,
#   'key': 5,
#   'loudness': -11.389,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.000148,
#   'instrumentalness': 0.00156,
#   'liveness': 0.105,
#   'valence': 0.142,
#   'tempo': 114.973,
#   'type': 'audio_features',
#   'id': '3KDVFcme5CjSt3d6f4mbLZ',
#   'uri': 'spotify:track:3KDVFcme5CjSt3d6f4mbLZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KDVFcme5CjSt3d6f4mbLZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KDVFcme5CjSt3d6f4mbLZ',
#   'duration_ms': 424153,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.694,
#   'key': 0,
#   'loudness': -7.095,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.000518,
#   'instrumentalness': 0.000174,
#   'liveness': 0.322,
#   'valence': 0.205,
#   'tempo': 121.925,
#   'type': 'audio_features',
#   'id': '4DfvfbW1WokVPg2hfsuVPk',
#   'uri': 'spotify:track:4DfvfbW1WokVPg2hfsuVPk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DfvfbW1WokVPg2hfsuVPk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DfvfbW1WokVPg2hfsuVPk',
#   'duration_ms': 284240,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.638,
#   'key': 3,
#   'loudness': -7.155,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.00218,
#   'instrumentalness': 0.000181,
#   'liveness': 0.157,
#   'valence': 0.385,
#   'tempo': 160.043,
#   'type': 'audio_features',
#   'id': '0NwwFE9EQpAluo1lEKVaO6',
#   'uri': 'spotify:track:0NwwFE9EQpAluo1lEKVaO6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0NwwFE9EQpAluo1lEKVaO6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NwwFE9EQpAluo1lEKVaO6',
#   'duration_ms': 266551,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.876,
#   'key': 4,
#   'loudness': -4.56,
#   'mode': 0,
#   'speechiness': 0.0385,
#   'acousticness': 0.00452,
#   'instrumentalness': 4.25e-06,
#   'liveness': 0.916,
#   'valence': 0.63,
#   'tempo': 112.981,
#   'type': 'audio_features',
#   'id': '5IqeUhO0rBh9Ob3lOSTeG9',
#   'uri': 'spotify:track:5IqeUhO0rBh9Ob3lOSTeG9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IqeUhO0rBh9Ob3lOSTeG9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IqeUhO0rBh9Ob3lOSTeG9',
#   'duration_ms': 261135,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.726,
#   'key': 9,
#   'loudness': -6.126,
#   'mode': 0,
#   'speechiness': 0.0598,
#   'acousticness': 0.000576,
#   'instrumentalness': 0.00171,
#   'liveness': 0.0943,
#   'valence': 0.624,
#   'tempo': 120.022,
#   'type': 'audio_features',
#   'id': '2gdCsIBocQ3c20KxMa0z8J',
#   'uri': 'spotify:track:2gdCsIBocQ3c20KxMa0z8J',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gdCsIBocQ3c20KxMa0z8J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gdCsIBocQ3c20KxMa0z8J',
#   'duration_ms': 231827,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.494,
#   'key': 1,
#   'loudness': -8.635,
#   'mode': 1,
#   'speechiness': 0.073,
#   'acousticness': 0.00231,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.339,
#   'valence': 0.67,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '41xM6iQXk0cRhhFagxqPon',
#   'uri': 'spotify:track:41xM6iQXk0cRhhFagxqPon',
#   'track_href': 'https://api.spotify.com/v1/tracks/41xM6iQXk0cRhhFagxqPon',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41xM6iQXk0cRhhFagxqPon',
#   'duration_ms': 253573,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.662,
#   'key': 6,
#   'loudness': -5.04,
#   'mode': 0,
#   'speechiness': 0.0271,
#   'acousticness': 0.0161,
#   'instrumentalness': 1.88e-06,
#   'liveness': 0.048,
#   'valence': 0.0936,
#   'tempo': 82.468,
#   'type': 'audio_features',
#   'id': '5DhND1K80SygVUxb8Pu4Jy',
#   'uri': 'spotify:track:5DhND1K80SygVUxb8Pu4Jy',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DhND1K80SygVUxb8Pu4Jy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DhND1K80SygVUxb8Pu4Jy',
#   'duration_ms': 295907,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.889,
#   'key': 0,
#   'loudness': -4.922,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.608,
#   'tempo': 126.996,
#   'type': 'audio_features',
#   'id': '56TjuKXiwp7fvxzwWAwJs8',
#   'uri': 'spotify:track:56TjuKXiwp7fvxzwWAwJs8',
#   'track_href': 'https://api.spotify.com/v1/tracks/56TjuKXiwp7fvxzwWAwJs8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56TjuKXiwp7fvxzwWAwJs8',
#   'duration_ms': 283040,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.641,
#   'key': 5,
#   'loudness': -6.581,
#   'mode': 0,
#   'speechiness': 0.0289,
#   'acousticness': 0.000235,
#   'instrumentalness': 5.81e-05,
#   'liveness': 0.0561,
#   'valence': 0.596,
#   'tempo': 124.961,
#   'type': 'audio_features',
#   'id': '2nqYNxOVS5rg0Ce7vFDkEk',
#   'uri': 'spotify:track:2nqYNxOVS5rg0Ce7vFDkEk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nqYNxOVS5rg0Ce7vFDkEk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nqYNxOVS5rg0Ce7vFDkEk',
#   'duration_ms': 237747,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.815,
#   'key': 5,
#   'loudness': -4.934,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.000583,
#   'instrumentalness': 0.000245,
#   'liveness': 0.141,
#   'valence': 0.63,
#   'tempo': 116.002,
#   'type': 'audio_features',
#   'id': '5uBKgdpgQrommAhbFGZFYW',
#   'uri': 'spotify:track:5uBKgdpgQrommAhbFGZFYW',
#   'track_href': 'https://api.spotify.com/v1/tracks/5uBKgdpgQrommAhbFGZFYW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uBKgdpgQrommAhbFGZFYW',
#   'duration_ms': 195973,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.649,
#   'key': 6,
#   'loudness': -6.914,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'acousticness': 0.00638,
#   'instrumentalness': 0.0078,
#   'liveness': 0.0891,
#   'valence': 0.226,
#   'tempo': 111.913,
#   'type': 'audio_features',
#   'id': '6njZoQz1itZlkLBvOECNMp',
#   'uri': 'spotify:track:6njZoQz1itZlkLBvOECNMp',
#   'track_href': 'https://api.spotify.com/v1/tracks/6njZoQz1itZlkLBvOECNMp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6njZoQz1itZlkLBvOECNMp',
#   'duration_ms': 365293,
#   'time_signature': 4},
#  {'danceability': 0.253,
#   'energy': 0.738,
#   'key': 2,
#   'loudness': -5.731,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.167,
#   'instrumentalness': 0.0156,
#   'liveness': 0.0584,
#   'valence': 0.0646,
#   'tempo': 106.015,
#   'type': 'audio_features',
#   'id': '5hINQzUsqOlhrjKtKhbowI',
#   'uri': 'spotify:track:5hINQzUsqOlhrjKtKhbowI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hINQzUsqOlhrjKtKhbowI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hINQzUsqOlhrjKtKhbowI',
#   'duration_ms': 347667,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.488,
#   'key': 5,
#   'loudness': -11.389,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.000148,
#   'instrumentalness': 0.00156,
#   'liveness': 0.105,
#   'valence': 0.142,
#   'tempo': 114.973,
#   'type': 'audio_features',
#   'id': '7lnpXGATCUqPfHT9WG3Anf',
#   'uri': 'spotify:track:7lnpXGATCUqPfHT9WG3Anf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lnpXGATCUqPfHT9WG3Anf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lnpXGATCUqPfHT9WG3Anf',
#   'duration_ms': 424153,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.694,
#   'key': 0,
#   'loudness': -7.095,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.000518,
#   'instrumentalness': 0.000174,
#   'liveness': 0.322,
#   'valence': 0.205,
#   'tempo': 121.925,
#   'type': 'audio_features',
#   'id': '1AEcZCZPbQkd6LiDZbk6Ss',
#   'uri': 'spotify:track:1AEcZCZPbQkd6LiDZbk6Ss',
#   'track_href': 'https://api.spotify.com/v1/tracks/1AEcZCZPbQkd6LiDZbk6Ss',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AEcZCZPbQkd6LiDZbk6Ss',
#   'duration_ms': 284240,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.638,
#   'key': 3,
#   'loudness': -7.155,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.00218,
#   'instrumentalness': 0.000181,
#   'liveness': 0.157,
#   'valence': 0.385,
#   'tempo': 160.043,
#   'type': 'audio_features',
#   'id': '06B5ZKGlgKVNkqJ7tBVwia',
#   'uri': 'spotify:track:06B5ZKGlgKVNkqJ7tBVwia',
#   'track_href': 'https://api.spotify.com/v1/tracks/06B5ZKGlgKVNkqJ7tBVwia',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06B5ZKGlgKVNkqJ7tBVwia',
#   'duration_ms': 266551,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.876,
#   'key': 4,
#   'loudness': -4.56,
#   'mode': 0,
#   'speechiness': 0.0385,
#   'acousticness': 0.00452,
#   'instrumentalness': 4.25e-06,
#   'liveness': 0.916,
#   'valence': 0.63,
#   'tempo': 112.981,
#   'type': 'audio_features',
#   'id': '3m68q8grLFaQDNmCI4NKgN',
#   'uri': 'spotify:track:3m68q8grLFaQDNmCI4NKgN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3m68q8grLFaQDNmCI4NKgN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3m68q8grLFaQDNmCI4NKgN',
#   'duration_ms': 261135,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.726,
#   'key': 9,
#   'loudness': -6.126,
#   'mode': 0,
#   'speechiness': 0.0598,
#   'acousticness': 0.000576,
#   'instrumentalness': 0.00171,
#   'liveness': 0.0943,
#   'valence': 0.624,
#   'tempo': 120.022,
#   'type': 'audio_features',
#   'id': '0EgYRavs84ourrrtlkbZVw',
#   'uri': 'spotify:track:0EgYRavs84ourrrtlkbZVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0EgYRavs84ourrrtlkbZVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EgYRavs84ourrrtlkbZVw',
#   'duration_ms': 231827,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.494,
#   'key': 1,
#   'loudness': -8.635,
#   'mode': 1,
#   'speechiness': 0.073,
#   'acousticness': 0.00231,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.339,
#   'valence': 0.67,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '6JLVf3JMmRMTjjQ9TxFg7G',
#   'uri': 'spotify:track:6JLVf3JMmRMTjjQ9TxFg7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JLVf3JMmRMTjjQ9TxFg7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JLVf3JMmRMTjjQ9TxFg7G',
#   'duration_ms': 253573,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.662,
#   'key': 6,
#   'loudness': -5.04,
#   'mode': 0,
#   'speechiness': 0.0271,
#   'acousticness': 0.0161,
#   'instrumentalness': 1.88e-06,
#   'liveness': 0.048,
#   'valence': 0.0936,
#   'tempo': 82.468,
#   'type': 'audio_features',
#   'id': '3gd8B742JF9s0iX1pj7lUa',
#   'uri': 'spotify:track:3gd8B742JF9s0iX1pj7lUa',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gd8B742JF9s0iX1pj7lUa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gd8B742JF9s0iX1pj7lUa',
#   'duration_ms': 295907,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.889,
#   'key': 0,
#   'loudness': -4.922,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.608,
#   'tempo': 126.996,
#   'type': 'audio_features',
#   'id': '77ApkbymCEPM8cBgx8klhS',
#   'uri': 'spotify:track:77ApkbymCEPM8cBgx8klhS',
#   'track_href': 'https://api.spotify.com/v1/tracks/77ApkbymCEPM8cBgx8klhS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77ApkbymCEPM8cBgx8klhS',
#   'duration_ms': 283040,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.641,
#   'key': 5,
#   'loudness': -6.581,
#   'mode': 0,
#   'speechiness': 0.0289,
#   'acousticness': 0.000235,
#   'instrumentalness': 5.81e-05,
#   'liveness': 0.0561,
#   'valence': 0.596,
#   'tempo': 124.961,
#   'type': 'audio_features',
#   'id': '11cK0Z7AzOQBwVGolkBqZS',
#   'uri': 'spotify:track:11cK0Z7AzOQBwVGolkBqZS',
#   'track_href': 'https://api.spotify.com/v1/tracks/11cK0Z7AzOQBwVGolkBqZS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11cK0Z7AzOQBwVGolkBqZS',
#   'duration_ms': 237747,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.815,
#   'key': 5,
#   'loudness': -4.934,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.000583,
#   'instrumentalness': 0.000245,
#   'liveness': 0.141,
#   'valence': 0.63,
#   'tempo': 116.002,
#   'type': 'audio_features',
#   'id': '2cvurI62d7nLddhBn0rdIM',
#   'uri': 'spotify:track:2cvurI62d7nLddhBn0rdIM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2cvurI62d7nLddhBn0rdIM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2cvurI62d7nLddhBn0rdIM',
#   'duration_ms': 195973,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.649,
#   'key': 6,
#   'loudness': -6.914,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'acousticness': 0.00638,
#   'instrumentalness': 0.0078,
#   'liveness': 0.0891,
#   'valence': 0.226,
#   'tempo': 111.913,
#   'type': 'audio_features',
#   'id': '5A65avO0ukFHcOg0TP278c',
#   'uri': 'spotify:track:5A65avO0ukFHcOg0TP278c',
#   'track_href': 'https://api.spotify.com/v1/tracks/5A65avO0ukFHcOg0TP278c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5A65avO0ukFHcOg0TP278c',
#   'duration_ms': 365293,
#   'time_signature': 4},
#  {'danceability': 0.253,
#   'energy': 0.738,
#   'key': 2,
#   'loudness': -5.731,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.167,
#   'instrumentalness': 0.0156,
#   'liveness': 0.0584,
#   'valence': 0.0646,
#   'tempo': 106.015,
#   'type': 'audio_features',
#   'id': '2RD4wl61I0tHGAgap2AIkT',
#   'uri': 'spotify:track:2RD4wl61I0tHGAgap2AIkT',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RD4wl61I0tHGAgap2AIkT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RD4wl61I0tHGAgap2AIkT',
#   'duration_ms': 347667,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.899,
#   'key': 7,
#   'loudness': -5.715,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.000407,
#   'instrumentalness': 0.000125,
#   'liveness': 0.101,
#   'valence': 0.728,
#   'tempo': 127.981,
#   'type': 'audio_features',
#   'id': '0rX7X1SdztjhGBxoXI8AoT',
#   'uri': 'spotify:track:0rX7X1SdztjhGBxoXI8AoT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rX7X1SdztjhGBxoXI8AoT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rX7X1SdztjhGBxoXI8AoT',
#   'duration_ms': 229813,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.695,
#   'key': 7,
#   'loudness': -6.677,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.000705,
#   'instrumentalness': 0.0154,
#   'liveness': 0.112,
#   'valence': 0.569,
#   'tempo': 118.009,
#   'type': 'audio_features',
#   'id': '72vOcoeyDnWiesIhzwcjpO',
#   'uri': 'spotify:track:72vOcoeyDnWiesIhzwcjpO',
#   'track_href': 'https://api.spotify.com/v1/tracks/72vOcoeyDnWiesIhzwcjpO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72vOcoeyDnWiesIhzwcjpO',
#   'duration_ms': 210493,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.733,
#   'key': 5,
#   'loudness': -6.966,
#   'mode': 0,
#   'speechiness': 0.0702,
#   'acousticness': 0.00237,
#   'instrumentalness': 0.00251,
#   'liveness': 0.312,
#   'valence': 0.218,
#   'tempo': 109.957,
#   'type': 'audio_features',
#   'id': '4znujJVuAxRKOw9RGYQnXY',
#   'uri': 'spotify:track:4znujJVuAxRKOw9RGYQnXY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4znujJVuAxRKOw9RGYQnXY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4znujJVuAxRKOw9RGYQnXY',
#   'duration_ms': 313667,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.669,
#   'key': 11,
#   'loudness': -5.743,
#   'mode': 0,
#   'speechiness': 0.0398,
#   'acousticness': 0.00113,
#   'instrumentalness': 0,
#   'liveness': 0.933,
#   'valence': 0.267,
#   'tempo': 78.204,
#   'type': 'audio_features',
#   'id': '7J6SHMEAnxY7p0CUlRB8Zx',
#   'uri': 'spotify:track:7J6SHMEAnxY7p0CUlRB8Zx',
#   'track_href': 'https://api.spotify.com/v1/tracks/7J6SHMEAnxY7p0CUlRB8Zx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J6SHMEAnxY7p0CUlRB8Zx',
#   'duration_ms': 258213,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.976,
#   'key': 0,
#   'loudness': -4.726,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.000115,
#   'instrumentalness': 0.0262,
#   'liveness': 0.97,
#   'valence': 0.141,
#   'tempo': 131.611,
#   'type': 'audio_features',
#   'id': '2mDbYQEo7MJLFE3WIGAvBZ',
#   'uri': 'spotify:track:2mDbYQEo7MJLFE3WIGAvBZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mDbYQEo7MJLFE3WIGAvBZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mDbYQEo7MJLFE3WIGAvBZ',
#   'duration_ms': 322587,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.935,
#   'key': 1,
#   'loudness': -4.282,
#   'mode': 1,
#   'speechiness': 0.0765,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.000757,
#   'liveness': 0.953,
#   'valence': 0.5,
#   'tempo': 125.458,
#   'type': 'audio_features',
#   'id': '1Y29I6MCdeaXLU36JsmmP3',
#   'uri': 'spotify:track:1Y29I6MCdeaXLU36JsmmP3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Y29I6MCdeaXLU36JsmmP3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y29I6MCdeaXLU36JsmmP3',
#   'duration_ms': 234720,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.953,
#   'key': 0,
#   'loudness': -4.475,
#   'mode': 1,
#   'speechiness': 0.0455,
#   'acousticness': 0.000642,
#   'instrumentalness': 0,
#   'liveness': 0.986,
#   'valence': 0.471,
#   'tempo': 122.006,
#   'type': 'audio_features',
#   'id': '756eJTQGmfJIA6rrTLWLkb',
#   'uri': 'spotify:track:756eJTQGmfJIA6rrTLWLkb',
#   'track_href': 'https://api.spotify.com/v1/tracks/756eJTQGmfJIA6rrTLWLkb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/756eJTQGmfJIA6rrTLWLkb',
#   'duration_ms': 276560,
#   'time_signature': 4}]

# %%
len(audio_feat_list)
# Out:
# 50

# %% [markdown]
#  Audio features only works for 100 elements, so we have to split our dataset into chunks of 100

# %% [markdown]
# ### Function to apply audio features to 31.243 songs

# %%
def audio_features_from_song_ids(song_ids):
    
    chunks = track_chunks_100(song_ids)
    
    audio_feat_list = []
    
    for i in chunks:
        audio_feat = sp.audio_features(tracks=i)
        audio_feat_list.append(audio_feat)
    
    flat_list = [i for sublist in audio_feat_list for i in sublist]
    
    return flat_list

# %%
audio_features_list = audio_features_from_song_ids(song_ids)

# %%
audio_features_list
# Out:
# [{'danceability': 0.307,
#   'energy': 0.153,
#   'key': 10,
#   'loudness': -25.952,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.883,
#   'instrumentalness': 0.971,
#   'liveness': 0.84,
#   'valence': 0.13,
#   'tempo': 79.853,
#   'type': 'audio_features',
#   'id': '3kjoAqJUsLs8TKZaofvPnd',
#   'uri': 'spotify:track:3kjoAqJUsLs8TKZaofvPnd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3kjoAqJUsLs8TKZaofvPnd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3kjoAqJUsLs8TKZaofvPnd',
#   'duration_ms': 171880,
#   'time_signature': 4},
#  {'danceability': 0.478,
#   'energy': 0.561,
#   'key': 10,
#   'loudness': -14.545,
#   'mode': 0,
#   'speechiness': 0.0754,
#   'acousticness': 0.121,
#   'instrumentalness': 0.0114,
#   'liveness': 0.881,
#   'valence': 0.257,
#   'tempo': 118.898,
#   'type': 'audio_features',
#   'id': '4NTNiAtUyadCRye3LlHnGY',
#   'uri': 'spotify:track:4NTNiAtUyadCRye3LlHnGY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NTNiAtUyadCRye3LlHnGY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NTNiAtUyadCRye3LlHnGY',
#   'duration_ms': 65200,
#   'time_signature': 4},
#  {'danceability': 0.501,
#   'energy': 0.927,
#   'key': 10,
#   'loudness': -6.744,
#   'mode': 0,
#   'speechiness': 0.069,
#   'acousticness': 0.0555,
#   'instrumentalness': 0.0477,
#   'liveness': 0.701,
#   'valence': 0.537,
#   'tempo': 118.744,
#   'type': 'audio_features',
#   'id': '1CqNphayCWFkjvVBM8Tc9y',
#   'uri': 'spotify:track:1CqNphayCWFkjvVBM8Tc9y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CqNphayCWFkjvVBM8Tc9y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CqNphayCWFkjvVBM8Tc9y',
#   'duration_ms': 227520,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.902,
#   'key': 6,
#   'loudness': -6.028,
#   'mode': 0,
#   'speechiness': 0.104,
#   'acousticness': 0.00157,
#   'instrumentalness': 0.0121,
#   'liveness': 0.697,
#   'valence': 0.245,
#   'tempo': 99.944,
#   'type': 'audio_features',
#   'id': '0r5JSBykFXMEbYkhapxZ3o',
#   'uri': 'spotify:track:0r5JSBykFXMEbYkhapxZ3o',
#   'track_href': 'https://api.spotify.com/v1/tracks/0r5JSBykFXMEbYkhapxZ3o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0r5JSBykFXMEbYkhapxZ3o',
#   'duration_ms': 347440,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.932,
#   'key': 7,
#   'loudness': -5.841,
#   'mode': 1,
#   'speechiness': 0.0711,
#   'acousticness': 0.0338,
#   'instrumentalness': 9.28e-06,
#   'liveness': 0.717,
#   'valence': 0.665,
#   'tempo': 128.864,
#   'type': 'audio_features',
#   'id': '2QUrwP0t7rWiD8Beit13h4',
#   'uri': 'spotify:track:2QUrwP0t7rWiD8Beit13h4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2QUrwP0t7rWiD8Beit13h4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2QUrwP0t7rWiD8Beit13h4',
#   'duration_ms': 204067,
#   'time_signature': 4},
#  {'danceability': 0.281,
#   'energy': 0.578,
#   'key': 2,
#   'loudness': -5.872,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.024,
#   'instrumentalness': 9.42e-06,
#   'liveness': 0.699,
#   'valence': 0.177,
#   'tempo': 129.021,
#   'type': 'audio_features',
#   'id': '0v20RVp8fqU8SALt8Pastg',
#   'uri': 'spotify:track:0v20RVp8fqU8SALt8Pastg',
#   'track_href': 'https://api.spotify.com/v1/tracks/0v20RVp8fqU8SALt8Pastg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0v20RVp8fqU8SALt8Pastg',
#   'duration_ms': 218707,
#   'time_signature': 4},
#  {'danceability': 0.494,
#   'energy': 0.837,
#   'key': 0,
#   'loudness': -5.354,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.00513,
#   'instrumentalness': 0.0162,
#   'liveness': 0.82,
#   'valence': 0.515,
#   'tempo': 128.941,
#   'type': 'audio_features',
#   'id': '0uu4WLNaELy4X3wGWx9qkq',
#   'uri': 'spotify:track:0uu4WLNaELy4X3wGWx9qkq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0uu4WLNaELy4X3wGWx9qkq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0uu4WLNaELy4X3wGWx9qkq',
#   'duration_ms': 313013,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.698,
#   'key': 8,
#   'loudness': -5.881,
#   'mode': 1,
#   'speechiness': 0.058,
#   'acousticness': 0.0271,
#   'instrumentalness': 3.05e-05,
#   'liveness': 0.776,
#   'valence': 0.337,
#   'tempo': 124.775,
#   'type': 'audio_features',
#   'id': '2TAUDaQbdaX6n2K0UzmbFQ',
#   'uri': 'spotify:track:2TAUDaQbdaX6n2K0UzmbFQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TAUDaQbdaX6n2K0UzmbFQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TAUDaQbdaX6n2K0UzmbFQ',
#   'duration_ms': 255467,
#   'time_signature': 4},
#  {'danceability': 0.505,
#   'energy': 0.701,
#   'key': 1,
#   'loudness': -7.299,
#   'mode': 0,
#   'speechiness': 0.0392,
#   'acousticness': 0.0419,
#   'instrumentalness': 0.00066,
#   'liveness': 0.989,
#   'valence': 0.331,
#   'tempo': 86.012,
#   'type': 'audio_features',
#   'id': '1ICYXdDq5B2R0B51opUHz1',
#   'uri': 'spotify:track:1ICYXdDq5B2R0B51opUHz1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ICYXdDq5B2R0B51opUHz1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ICYXdDq5B2R0B51opUHz1',
#   'duration_ms': 337147,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.689,
#   'key': 0,
#   'loudness': -6.674,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.0318,
#   'instrumentalness': 1.91e-06,
#   'liveness': 0.815,
#   'valence': 0.377,
#   'tempo': 113.644,
#   'type': 'audio_features',
#   'id': '3GwOxticDVhjKtx7J33tbz',
#   'uri': 'spotify:track:3GwOxticDVhjKtx7J33tbz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3GwOxticDVhjKtx7J33tbz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GwOxticDVhjKtx7J33tbz',
#   'duration_ms': 361147,
#   'time_signature': 4},
#  {'danceability': 0.508,
#   'energy': 0.733,
#   'key': 7,
#   'loudness': -6.379,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'acousticness': 0.0073,
#   'instrumentalness': 3.56e-05,
#   'liveness': 0.779,
#   'valence': 0.399,
#   'tempo': 96.011,
#   'type': 'audio_features',
#   'id': '0xYMDt67FFwsNqCb8jHVwG',
#   'uri': 'spotify:track:0xYMDt67FFwsNqCb8jHVwG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xYMDt67FFwsNqCb8jHVwG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xYMDt67FFwsNqCb8jHVwG',
#   'duration_ms': 337840,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.744,
#   'key': 9,
#   'loudness': -9.003,
#   'mode': 1,
#   'speechiness': 0.0249,
#   'acousticness': 0.0113,
#   'instrumentalness': 0.058,
#   'liveness': 0.946,
#   'valence': 0.335,
#   'tempo': 99.949,
#   'type': 'audio_features',
#   'id': '4MUNNsHJWFjM1aMQwJDdqG',
#   'uri': 'spotify:track:4MUNNsHJWFjM1aMQwJDdqG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4MUNNsHJWFjM1aMQwJDdqG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4MUNNsHJWFjM1aMQwJDdqG',
#   'duration_ms': 283573,
#   'time_signature': 3},
#  {'danceability': 0.404,
#   'energy': 0.778,
#   'key': 0,
#   'loudness': -6.368,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.129,
#   'instrumentalness': 6e-05,
#   'liveness': 0.692,
#   'valence': 0.376,
#   'tempo': 173.892,
#   'type': 'audio_features',
#   'id': '5ajQvWo3ZKBV9nsnM47f3T',
#   'uri': 'spotify:track:5ajQvWo3ZKBV9nsnM47f3T',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ajQvWo3ZKBV9nsnM47f3T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ajQvWo3ZKBV9nsnM47f3T',
#   'duration_ms': 326547,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.857,
#   'key': 9,
#   'loudness': -6.254,
#   'mode': 0,
#   'speechiness': 0.0632,
#   'acousticness': 0.0151,
#   'instrumentalness': 0.00276,
#   'liveness': 0.771,
#   'valence': 0.385,
#   'tempo': 138.235,
#   'type': 'audio_features',
#   'id': '0d1ZBMWqFGV3lDGIhxGtkt',
#   'uri': 'spotify:track:0d1ZBMWqFGV3lDGIhxGtkt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0d1ZBMWqFGV3lDGIhxGtkt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0d1ZBMWqFGV3lDGIhxGtkt',
#   'duration_ms': 262893,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.895,
#   'key': 7,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0768,
#   'acousticness': 0.0366,
#   'instrumentalness': 4.21e-05,
#   'liveness': 0.795,
#   'valence': 0.35,
#   'tempo': 126.232,
#   'type': 'audio_features',
#   'id': '6h2lDrHbhZj2wUpVX8OUFd',
#   'uri': 'spotify:track:6h2lDrHbhZj2wUpVX8OUFd',
#   'track_href': 'https://api.spotify.com/v1/tracks/6h2lDrHbhZj2wUpVX8OUFd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6h2lDrHbhZj2wUpVX8OUFd',
#   'duration_ms': 358680,
#   'time_signature': 4},
#  {'danceability': 0.436,
#   'energy': 0.939,
#   'key': 2,
#   'loudness': -5.556,
#   'mode': 1,
#   'speechiness': 0.0742,
#   'acousticness': 0.026,
#   'instrumentalness': 0.0299,
#   'liveness': 0.979,
#   'valence': 0.711,
#   'tempo': 161.792,
#   'type': 'audio_features',
#   'id': '7LwarhbK2SCOubSYT9Hxsf',
#   'uri': 'spotify:track:7LwarhbK2SCOubSYT9Hxsf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LwarhbK2SCOubSYT9Hxsf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LwarhbK2SCOubSYT9Hxsf',
#   'duration_ms': 223333,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -9.158,
#   'mode': 1,
#   'speechiness': 0.026,
#   'acousticness': 0.0279,
#   'instrumentalness': 1.87e-06,
#   'liveness': 0.728,
#   'valence': 0.178,
#   'tempo': 120.631,
#   'type': 'audio_features',
#   'id': '7edL9lqUDCxbMctSw5zG0y',
#   'uri': 'spotify:track:7edL9lqUDCxbMctSw5zG0y',
#   'track_href': 'https://api.spotify.com/v1/tracks/7edL9lqUDCxbMctSw5zG0y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7edL9lqUDCxbMctSw5zG0y',
#   'duration_ms': 398707,
#   'time_signature': 4},
#  {'danceability': 0.446,
#   'energy': 0.709,
#   'key': 1,
#   'loudness': -6.477,
#   'mode': 0,
#   'speechiness': 0.0328,
#   'acousticness': 0.048,
#   'instrumentalness': 4.69e-05,
#   'liveness': 0.561,
#   'valence': 0.334,
#   'tempo': 139.807,
#   'type': 'audio_features',
#   'id': '1H69q2ckMIeF6y7nagqxC3',
#   'uri': 'spotify:track:1H69q2ckMIeF6y7nagqxC3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1H69q2ckMIeF6y7nagqxC3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1H69q2ckMIeF6y7nagqxC3',
#   'duration_ms': 364893,
#   'time_signature': 4},
#  {'danceability': 0.428,
#   'energy': 0.955,
#   'key': 9,
#   'loudness': -5.901,
#   'mode': 1,
#   'speechiness': 0.19,
#   'acousticness': 0.0148,
#   'instrumentalness': 0.000185,
#   'liveness': 0.762,
#   'valence': 0.297,
#   'tempo': 140.926,
#   'type': 'audio_features',
#   'id': '0Cxb1MoV37Gn1nUAtFbuqP',
#   'uri': 'spotify:track:0Cxb1MoV37Gn1nUAtFbuqP',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Cxb1MoV37Gn1nUAtFbuqP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Cxb1MoV37Gn1nUAtFbuqP',
#   'duration_ms': 393813,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.488,
#   'key': 5,
#   'loudness': -11.389,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.000148,
#   'instrumentalness': 0.00156,
#   'liveness': 0.105,
#   'valence': 0.142,
#   'tempo': 114.973,
#   'type': 'audio_features',
#   'id': '3KDVFcme5CjSt3d6f4mbLZ',
#   'uri': 'spotify:track:3KDVFcme5CjSt3d6f4mbLZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KDVFcme5CjSt3d6f4mbLZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KDVFcme5CjSt3d6f4mbLZ',
#   'duration_ms': 424153,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.694,
#   'key': 0,
#   'loudness': -7.095,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.000518,
#   'instrumentalness': 0.000174,
#   'liveness': 0.322,
#   'valence': 0.205,
#   'tempo': 121.925,
#   'type': 'audio_features',
#   'id': '4DfvfbW1WokVPg2hfsuVPk',
#   'uri': 'spotify:track:4DfvfbW1WokVPg2hfsuVPk',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DfvfbW1WokVPg2hfsuVPk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DfvfbW1WokVPg2hfsuVPk',
#   'duration_ms': 284240,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.638,
#   'key': 3,
#   'loudness': -7.155,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.00218,
#   'instrumentalness': 0.000181,
#   'liveness': 0.157,
#   'valence': 0.385,
#   'tempo': 160.043,
#   'type': 'audio_features',
#   'id': '0NwwFE9EQpAluo1lEKVaO6',
#   'uri': 'spotify:track:0NwwFE9EQpAluo1lEKVaO6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0NwwFE9EQpAluo1lEKVaO6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NwwFE9EQpAluo1lEKVaO6',
#   'duration_ms': 266551,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.876,
#   'key': 4,
#   'loudness': -4.56,
#   'mode': 0,
#   'speechiness': 0.0385,
#   'acousticness': 0.00452,
#   'instrumentalness': 4.25e-06,
#   'liveness': 0.916,
#   'valence': 0.63,
#   'tempo': 112.981,
#   'type': 'audio_features',
#   'id': '5IqeUhO0rBh9Ob3lOSTeG9',
#   'uri': 'spotify:track:5IqeUhO0rBh9Ob3lOSTeG9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IqeUhO0rBh9Ob3lOSTeG9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IqeUhO0rBh9Ob3lOSTeG9',
#   'duration_ms': 261135,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.726,
#   'key': 9,
#   'loudness': -6.126,
#   'mode': 0,
#   'speechiness': 0.0598,
#   'acousticness': 0.000576,
#   'instrumentalness': 0.00171,
#   'liveness': 0.0943,
#   'valence': 0.624,
#   'tempo': 120.022,
#   'type': 'audio_features',
#   'id': '2gdCsIBocQ3c20KxMa0z8J',
#   'uri': 'spotify:track:2gdCsIBocQ3c20KxMa0z8J',
#   'track_href': 'https://api.spotify.com/v1/tracks/2gdCsIBocQ3c20KxMa0z8J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gdCsIBocQ3c20KxMa0z8J',
#   'duration_ms': 231827,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.494,
#   'key': 1,
#   'loudness': -8.635,
#   'mode': 1,
#   'speechiness': 0.073,
#   'acousticness': 0.00231,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.339,
#   'valence': 0.67,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '41xM6iQXk0cRhhFagxqPon',
#   'uri': 'spotify:track:41xM6iQXk0cRhhFagxqPon',
#   'track_href': 'https://api.spotify.com/v1/tracks/41xM6iQXk0cRhhFagxqPon',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41xM6iQXk0cRhhFagxqPon',
#   'duration_ms': 253573,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.662,
#   'key': 6,
#   'loudness': -5.04,
#   'mode': 0,
#   'speechiness': 0.0271,
#   'acousticness': 0.0161,
#   'instrumentalness': 1.88e-06,
#   'liveness': 0.048,
#   'valence': 0.0936,
#   'tempo': 82.468,
#   'type': 'audio_features',
#   'id': '5DhND1K80SygVUxb8Pu4Jy',
#   'uri': 'spotify:track:5DhND1K80SygVUxb8Pu4Jy',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DhND1K80SygVUxb8Pu4Jy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DhND1K80SygVUxb8Pu4Jy',
#   'duration_ms': 295907,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.889,
#   'key': 0,
#   'loudness': -4.922,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.608,
#   'tempo': 126.996,
#   'type': 'audio_features',
#   'id': '56TjuKXiwp7fvxzwWAwJs8',
#   'uri': 'spotify:track:56TjuKXiwp7fvxzwWAwJs8',
#   'track_href': 'https://api.spotify.com/v1/tracks/56TjuKXiwp7fvxzwWAwJs8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56TjuKXiwp7fvxzwWAwJs8',
#   'duration_ms': 283040,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.641,
#   'key': 5,
#   'loudness': -6.581,
#   'mode': 0,
#   'speechiness': 0.0289,
#   'acousticness': 0.000235,
#   'instrumentalness': 5.81e-05,
#   'liveness': 0.0561,
#   'valence': 0.596,
#   'tempo': 124.961,
#   'type': 'audio_features',
#   'id': '2nqYNxOVS5rg0Ce7vFDkEk',
#   'uri': 'spotify:track:2nqYNxOVS5rg0Ce7vFDkEk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2nqYNxOVS5rg0Ce7vFDkEk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2nqYNxOVS5rg0Ce7vFDkEk',
#   'duration_ms': 237747,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.815,
#   'key': 5,
#   'loudness': -4.934,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.000583,
#   'instrumentalness': 0.000245,
#   'liveness': 0.141,
#   'valence': 0.63,
#   'tempo': 116.002,
#   'type': 'audio_features',
#   'id': '5uBKgdpgQrommAhbFGZFYW',
#   'uri': 'spotify:track:5uBKgdpgQrommAhbFGZFYW',
#   'track_href': 'https://api.spotify.com/v1/tracks/5uBKgdpgQrommAhbFGZFYW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uBKgdpgQrommAhbFGZFYW',
#   'duration_ms': 195973,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.649,
#   'key': 6,
#   'loudness': -6.914,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'acousticness': 0.00638,
#   'instrumentalness': 0.0078,
#   'liveness': 0.0891,
#   'valence': 0.226,
#   'tempo': 111.913,
#   'type': 'audio_features',
#   'id': '6njZoQz1itZlkLBvOECNMp',
#   'uri': 'spotify:track:6njZoQz1itZlkLBvOECNMp',
#   'track_href': 'https://api.spotify.com/v1/tracks/6njZoQz1itZlkLBvOECNMp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6njZoQz1itZlkLBvOECNMp',
#   'duration_ms': 365293,
#   'time_signature': 4},
#  {'danceability': 0.253,
#   'energy': 0.738,
#   'key': 2,
#   'loudness': -5.731,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.167,
#   'instrumentalness': 0.0156,
#   'liveness': 0.0584,
#   'valence': 0.0646,
#   'tempo': 106.015,
#   'type': 'audio_features',
#   'id': '5hINQzUsqOlhrjKtKhbowI',
#   'uri': 'spotify:track:5hINQzUsqOlhrjKtKhbowI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5hINQzUsqOlhrjKtKhbowI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hINQzUsqOlhrjKtKhbowI',
#   'duration_ms': 347667,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.488,
#   'key': 5,
#   'loudness': -11.389,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.000148,
#   'instrumentalness': 0.00156,
#   'liveness': 0.105,
#   'valence': 0.142,
#   'tempo': 114.973,
#   'type': 'audio_features',
#   'id': '7lnpXGATCUqPfHT9WG3Anf',
#   'uri': 'spotify:track:7lnpXGATCUqPfHT9WG3Anf',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lnpXGATCUqPfHT9WG3Anf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lnpXGATCUqPfHT9WG3Anf',
#   'duration_ms': 424153,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.694,
#   'key': 0,
#   'loudness': -7.095,
#   'mode': 1,
#   'speechiness': 0.0275,
#   'acousticness': 0.000518,
#   'instrumentalness': 0.000174,
#   'liveness': 0.322,
#   'valence': 0.205,
#   'tempo': 121.925,
#   'type': 'audio_features',
#   'id': '1AEcZCZPbQkd6LiDZbk6Ss',
#   'uri': 'spotify:track:1AEcZCZPbQkd6LiDZbk6Ss',
#   'track_href': 'https://api.spotify.com/v1/tracks/1AEcZCZPbQkd6LiDZbk6Ss',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AEcZCZPbQkd6LiDZbk6Ss',
#   'duration_ms': 284240,
#   'time_signature': 4},
#  {'danceability': 0.578,
#   'energy': 0.638,
#   'key': 3,
#   'loudness': -7.155,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.00218,
#   'instrumentalness': 0.000181,
#   'liveness': 0.157,
#   'valence': 0.385,
#   'tempo': 160.043,
#   'type': 'audio_features',
#   'id': '06B5ZKGlgKVNkqJ7tBVwia',
#   'uri': 'spotify:track:06B5ZKGlgKVNkqJ7tBVwia',
#   'track_href': 'https://api.spotify.com/v1/tracks/06B5ZKGlgKVNkqJ7tBVwia',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06B5ZKGlgKVNkqJ7tBVwia',
#   'duration_ms': 266551,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.876,
#   'key': 4,
#   'loudness': -4.56,
#   'mode': 0,
#   'speechiness': 0.0385,
#   'acousticness': 0.00452,
#   'instrumentalness': 4.25e-06,
#   'liveness': 0.916,
#   'valence': 0.63,
#   'tempo': 112.981,
#   'type': 'audio_features',
#   'id': '3m68q8grLFaQDNmCI4NKgN',
#   'uri': 'spotify:track:3m68q8grLFaQDNmCI4NKgN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3m68q8grLFaQDNmCI4NKgN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3m68q8grLFaQDNmCI4NKgN',
#   'duration_ms': 261135,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.726,
#   'key': 9,
#   'loudness': -6.126,
#   'mode': 0,
#   'speechiness': 0.0598,
#   'acousticness': 0.000576,
#   'instrumentalness': 0.00171,
#   'liveness': 0.0943,
#   'valence': 0.624,
#   'tempo': 120.022,
#   'type': 'audio_features',
#   'id': '0EgYRavs84ourrrtlkbZVw',
#   'uri': 'spotify:track:0EgYRavs84ourrrtlkbZVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0EgYRavs84ourrrtlkbZVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0EgYRavs84ourrrtlkbZVw',
#   'duration_ms': 231827,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.494,
#   'key': 1,
#   'loudness': -8.635,
#   'mode': 1,
#   'speechiness': 0.073,
#   'acousticness': 0.00231,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.339,
#   'valence': 0.67,
#   'tempo': 124.023,
#   'type': 'audio_features',
#   'id': '6JLVf3JMmRMTjjQ9TxFg7G',
#   'uri': 'spotify:track:6JLVf3JMmRMTjjQ9TxFg7G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6JLVf3JMmRMTjjQ9TxFg7G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JLVf3JMmRMTjjQ9TxFg7G',
#   'duration_ms': 253573,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.662,
#   'key': 6,
#   'loudness': -5.04,
#   'mode': 0,
#   'speechiness': 0.0271,
#   'acousticness': 0.0161,
#   'instrumentalness': 1.88e-06,
#   'liveness': 0.048,
#   'valence': 0.0936,
#   'tempo': 82.468,
#   'type': 'audio_features',
#   'id': '3gd8B742JF9s0iX1pj7lUa',
#   'uri': 'spotify:track:3gd8B742JF9s0iX1pj7lUa',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gd8B742JF9s0iX1pj7lUa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gd8B742JF9s0iX1pj7lUa',
#   'duration_ms': 295907,
#   'time_signature': 4},
#  {'danceability': 0.625,
#   'energy': 0.889,
#   'key': 0,
#   'loudness': -4.922,
#   'mode': 1,
#   'speechiness': 0.0436,
#   'acousticness': 0.0101,
#   'instrumentalness': 0,
#   'liveness': 0.27,
#   'valence': 0.608,
#   'tempo': 126.996,
#   'type': 'audio_features',
#   'id': '77ApkbymCEPM8cBgx8klhS',
#   'uri': 'spotify:track:77ApkbymCEPM8cBgx8klhS',
#   'track_href': 'https://api.spotify.com/v1/tracks/77ApkbymCEPM8cBgx8klhS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77ApkbymCEPM8cBgx8klhS',
#   'duration_ms': 283040,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.641,
#   'key': 5,
#   'loudness': -6.581,
#   'mode': 0,
#   'speechiness': 0.0289,
#   'acousticness': 0.000235,
#   'instrumentalness': 5.81e-05,
#   'liveness': 0.0561,
#   'valence': 0.596,
#   'tempo': 124.961,
#   'type': 'audio_features',
#   'id': '11cK0Z7AzOQBwVGolkBqZS',
#   'uri': 'spotify:track:11cK0Z7AzOQBwVGolkBqZS',
#   'track_href': 'https://api.spotify.com/v1/tracks/11cK0Z7AzOQBwVGolkBqZS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11cK0Z7AzOQBwVGolkBqZS',
#   'duration_ms': 237747,
#   'time_signature': 4},
#  {'danceability': 0.731,
#   'energy': 0.815,
#   'key': 5,
#   'loudness': -4.934,
#   'mode': 0,
#   'speechiness': 0.0443,
#   'acousticness': 0.000583,
#   'instrumentalness': 0.000245,
#   'liveness': 0.141,
#   'valence': 0.63,
#   'tempo': 116.002,
#   'type': 'audio_features',
#   'id': '2cvurI62d7nLddhBn0rdIM',
#   'uri': 'spotify:track:2cvurI62d7nLddhBn0rdIM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2cvurI62d7nLddhBn0rdIM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2cvurI62d7nLddhBn0rdIM',
#   'duration_ms': 195973,
#   'time_signature': 4},
#  {'danceability': 0.611,
#   'energy': 0.649,
#   'key': 6,
#   'loudness': -6.914,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'acousticness': 0.00638,
#   'instrumentalness': 0.0078,
#   'liveness': 0.0891,
#   'valence': 0.226,
#   'tempo': 111.913,
#   'type': 'audio_features',
#   'id': '5A65avO0ukFHcOg0TP278c',
#   'uri': 'spotify:track:5A65avO0ukFHcOg0TP278c',
#   'track_href': 'https://api.spotify.com/v1/tracks/5A65avO0ukFHcOg0TP278c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5A65avO0ukFHcOg0TP278c',
#   'duration_ms': 365293,
#   'time_signature': 4},
#  {'danceability': 0.253,
#   'energy': 0.738,
#   'key': 2,
#   'loudness': -5.731,
#   'mode': 0,
#   'speechiness': 0.049,
#   'acousticness': 0.167,
#   'instrumentalness': 0.0156,
#   'liveness': 0.0584,
#   'valence': 0.0646,
#   'tempo': 106.015,
#   'type': 'audio_features',
#   'id': '2RD4wl61I0tHGAgap2AIkT',
#   'uri': 'spotify:track:2RD4wl61I0tHGAgap2AIkT',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RD4wl61I0tHGAgap2AIkT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RD4wl61I0tHGAgap2AIkT',
#   'duration_ms': 347667,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.899,
#   'key': 7,
#   'loudness': -5.715,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.000407,
#   'instrumentalness': 0.000125,
#   'liveness': 0.101,
#   'valence': 0.728,
#   'tempo': 127.981,
#   'type': 'audio_features',
#   'id': '0rX7X1SdztjhGBxoXI8AoT',
#   'uri': 'spotify:track:0rX7X1SdztjhGBxoXI8AoT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rX7X1SdztjhGBxoXI8AoT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rX7X1SdztjhGBxoXI8AoT',
#   'duration_ms': 229813,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.695,
#   'key': 7,
#   'loudness': -6.677,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.000705,
#   'instrumentalness': 0.0154,
#   'liveness': 0.112,
#   'valence': 0.569,
#   'tempo': 118.009,
#   'type': 'audio_features',
#   'id': '72vOcoeyDnWiesIhzwcjpO',
#   'uri': 'spotify:track:72vOcoeyDnWiesIhzwcjpO',
#   'track_href': 'https://api.spotify.com/v1/tracks/72vOcoeyDnWiesIhzwcjpO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72vOcoeyDnWiesIhzwcjpO',
#   'duration_ms': 210493,
#   'time_signature': 4},
#  {'danceability': 0.638,
#   'energy': 0.733,
#   'key': 5,
#   'loudness': -6.966,
#   'mode': 0,
#   'speechiness': 0.0702,
#   'acousticness': 0.00237,
#   'instrumentalness': 0.00251,
#   'liveness': 0.312,
#   'valence': 0.218,
#   'tempo': 109.957,
#   'type': 'audio_features',
#   'id': '4znujJVuAxRKOw9RGYQnXY',
#   'uri': 'spotify:track:4znujJVuAxRKOw9RGYQnXY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4znujJVuAxRKOw9RGYQnXY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4znujJVuAxRKOw9RGYQnXY',
#   'duration_ms': 313667,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.669,
#   'key': 11,
#   'loudness': -5.743,
#   'mode': 0,
#   'speechiness': 0.0398,
#   'acousticness': 0.00113,
#   'instrumentalness': 0,
#   'liveness': 0.933,
#   'valence': 0.267,
#   'tempo': 78.204,
#   'type': 'audio_features',
#   'id': '7J6SHMEAnxY7p0CUlRB8Zx',
#   'uri': 'spotify:track:7J6SHMEAnxY7p0CUlRB8Zx',
#   'track_href': 'https://api.spotify.com/v1/tracks/7J6SHMEAnxY7p0CUlRB8Zx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J6SHMEAnxY7p0CUlRB8Zx',
#   'duration_ms': 258213,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.976,
#   'key': 0,
#   'loudness': -4.726,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.000115,
#   'instrumentalness': 0.0262,
#   'liveness': 0.97,
#   'valence': 0.141,
#   'tempo': 131.611,
#   'type': 'audio_features',
#   'id': '2mDbYQEo7MJLFE3WIGAvBZ',
#   'uri': 'spotify:track:2mDbYQEo7MJLFE3WIGAvBZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mDbYQEo7MJLFE3WIGAvBZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mDbYQEo7MJLFE3WIGAvBZ',
#   'duration_ms': 322587,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.935,
#   'key': 1,
#   'loudness': -4.282,
#   'mode': 1,
#   'speechiness': 0.0765,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.000757,
#   'liveness': 0.953,
#   'valence': 0.5,
#   'tempo': 125.458,
#   'type': 'audio_features',
#   'id': '1Y29I6MCdeaXLU36JsmmP3',
#   'uri': 'spotify:track:1Y29I6MCdeaXLU36JsmmP3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Y29I6MCdeaXLU36JsmmP3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y29I6MCdeaXLU36JsmmP3',
#   'duration_ms': 234720,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.953,
#   'key': 0,
#   'loudness': -4.475,
#   'mode': 1,
#   'speechiness': 0.0455,
#   'acousticness': 0.000642,
#   'instrumentalness': 0,
#   'liveness': 0.986,
#   'valence': 0.471,
#   'tempo': 122.006,
#   'type': 'audio_features',
#   'id': '756eJTQGmfJIA6rrTLWLkb',
#   'uri': 'spotify:track:756eJTQGmfJIA6rrTLWLkb',
#   'track_href': 'https://api.spotify.com/v1/tracks/756eJTQGmfJIA6rrTLWLkb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/756eJTQGmfJIA6rrTLWLkb',
#   'duration_ms': 276560,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.946,
#   'key': 0,
#   'loudness': -4.138,
#   'mode': 0,
#   'speechiness': 0.0589,
#   'acousticness': 0.00358,
#   'instrumentalness': 2.76e-05,
#   'liveness': 0.99,
#   'valence': 0.635,
#   'tempo': 174.014,
#   'type': 'audio_features',
#   'id': '505rToJsDoVICCHDcUOXfK',
#   'uri': 'spotify:track:505rToJsDoVICCHDcUOXfK',
#   'track_href': 'https://api.spotify.com/v1/tracks/505rToJsDoVICCHDcUOXfK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/505rToJsDoVICCHDcUOXfK',
#   'duration_ms': 285880,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.966,
#   'key': 6,
#   'loudness': -3.924,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.000481,
#   'instrumentalness': 0.0169,
#   'liveness': 0.988,
#   'valence': 0.664,
#   'tempo': 145.046,
#   'type': 'audio_features',
#   'id': '7cv6ywatN9BZLdFBbxlUGC',
#   'uri': 'spotify:track:7cv6ywatN9BZLdFBbxlUGC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7cv6ywatN9BZLdFBbxlUGC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7cv6ywatN9BZLdFBbxlUGC',
#   'duration_ms': 258040,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.992,
#   'key': 0,
#   'loudness': -2.993,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.00199,
#   'instrumentalness': 0,
#   'liveness': 0.933,
#   'valence': 0.517,
#   'tempo': 127.026,
#   'type': 'audio_features',
#   'id': '6HFfMQUPy8EF5G2VOgLz87',
#   'uri': 'spotify:track:6HFfMQUPy8EF5G2VOgLz87',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HFfMQUPy8EF5G2VOgLz87',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HFfMQUPy8EF5G2VOgLz87',
#   'duration_ms': 314493,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.988,
#   'key': 1,
#   'loudness': -4.202,
#   'mode': 0,
#   'speechiness': 0.169,
#   'acousticness': 4.45e-05,
#   'instrumentalness': 0.0953,
#   'liveness': 0.98,
#   'valence': 0.384,
#   'tempo': 128.992,
#   'type': 'audio_features',
#   'id': '1CMwo9YMiXZMyFZ6J6J4uX',
#   'uri': 'spotify:track:1CMwo9YMiXZMyFZ6J6J4uX',
#   'track_href': 'https://api.spotify.com/v1/tracks/1CMwo9YMiXZMyFZ6J6J4uX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CMwo9YMiXZMyFZ6J6J4uX',
#   'duration_ms': 398680,
#   'time_signature': 4},
#  {'danceability': 0.322,
#   'energy': 0.754,
#   'key': 1,
#   'loudness': -5.149,
#   'mode': 0,
#   'speechiness': 0.0424,
#   'acousticness': 0.00208,
#   'instrumentalness': 0.000196,
#   'liveness': 0.982,
#   'valence': 0.325,
#   'tempo': 139.706,
#   'type': 'audio_features',
#   'id': '0MEiJuYQOFZKeoc9lVvdOH',
#   'uri': 'spotify:track:0MEiJuYQOFZKeoc9lVvdOH',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MEiJuYQOFZKeoc9lVvdOH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MEiJuYQOFZKeoc9lVvdOH',
#   'duration_ms': 372120,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.974,
#   'key': 0,
#   'loudness': -2.712,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.0494,
#   'instrumentalness': 0,
#   'liveness': 0.39,
#   'valence': 0.591,
#   'tempo': 106.599,
#   'type': 'audio_features',
#   'id': '1pkXWlpBjeOp9J6gGCHH02',
#   'uri': 'spotify:track:1pkXWlpBjeOp9J6gGCHH02',
#   'track_href': 'https://api.spotify.com/v1/tracks/1pkXWlpBjeOp9J6gGCHH02',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1pkXWlpBjeOp9J6gGCHH02',
#   'duration_ms': 239813,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.977,
#   'key': 0,
#   'loudness': -4.796,
#   'mode': 1,
#   'speechiness': 0.11,
#   'acousticness': 0.000221,
#   'instrumentalness': 0.000877,
#   'liveness': 0.873,
#   'valence': 0.505,
#   'tempo': 129.066,
#   'type': 'audio_features',
#   'id': '4NzLnMzRwECvAbTvN2gbQ4',
#   'uri': 'spotify:track:4NzLnMzRwECvAbTvN2gbQ4',
#   'track_href': 'https://api.spotify.com/v1/tracks/4NzLnMzRwECvAbTvN2gbQ4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NzLnMzRwECvAbTvN2gbQ4',
#   'duration_ms': 246480,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.974,
#   'key': 0,
#   'loudness': -4.069,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.00119,
#   'instrumentalness': 0.000752,
#   'liveness': 0.973,
#   'valence': 0.345,
#   'tempo': 129.989,
#   'type': 'audio_features',
#   'id': '0wTMwNsOprSsgRm68NmJaw',
#   'uri': 'spotify:track:0wTMwNsOprSsgRm68NmJaw',
#   'track_href': 'https://api.spotify.com/v1/tracks/0wTMwNsOprSsgRm68NmJaw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wTMwNsOprSsgRm68NmJaw',
#   'duration_ms': 334587,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.976,
#   'key': 7,
#   'loudness': -3.551,
#   'mode': 1,
#   'speechiness': 0.168,
#   'acousticness': 0.000446,
#   'instrumentalness': 0.000187,
#   'liveness': 0.966,
#   'valence': 0.277,
#   'tempo': 115.688,
#   'type': 'audio_features',
#   'id': '6ERHQwKRVFKk8ro91CSPHS',
#   'uri': 'spotify:track:6ERHQwKRVFKk8ro91CSPHS',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ERHQwKRVFKk8ro91CSPHS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ERHQwKRVFKk8ro91CSPHS',
#   'duration_ms': 356467,
#   'time_signature': 4},
#  {'danceability': 0.414,
#   'energy': 0.975,
#   'key': 9,
#   'loudness': -3.009,
#   'mode': 1,
#   'speechiness': 0.0981,
#   'acousticness': 0.00435,
#   'instrumentalness': 0.00185,
#   'liveness': 0.96,
#   'valence': 0.518,
#   'tempo': 140.982,
#   'type': 'audio_features',
#   'id': '5h0pA46Dw14yDiCbYuKmr3',
#   'uri': 'spotify:track:5h0pA46Dw14yDiCbYuKmr3',
#   'track_href': 'https://api.spotify.com/v1/tracks/5h0pA46Dw14yDiCbYuKmr3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5h0pA46Dw14yDiCbYuKmr3',
#   'duration_ms': 443600,
#   'time_signature': 4},
#  {'danceability': 0.315,
#   'energy': 0.669,
#   'key': 11,
#   'loudness': -5.743,
#   'mode': 0,
#   'speechiness': 0.0398,
#   'acousticness': 0.00113,
#   'instrumentalness': 0,
#   'liveness': 0.933,
#   'valence': 0.267,
#   'tempo': 78.204,
#   'type': 'audio_features',
#   'id': '6G8LMPejtNiLMer2rDyptP',
#   'uri': 'spotify:track:6G8LMPejtNiLMer2rDyptP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6G8LMPejtNiLMer2rDyptP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6G8LMPejtNiLMer2rDyptP',
#   'duration_ms': 258213,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.976,
#   'key': 0,
#   'loudness': -4.726,
#   'mode': 1,
#   'speechiness': 0.121,
#   'acousticness': 0.000115,
#   'instrumentalness': 0.0262,
#   'liveness': 0.97,
#   'valence': 0.141,
#   'tempo': 131.622,
#   'type': 'audio_features',
#   'id': '4cHTaGGwdEyKAfL7AVwDKc',
#   'uri': 'spotify:track:4cHTaGGwdEyKAfL7AVwDKc',
#   'track_href': 'https://api.spotify.com/v1/tracks/4cHTaGGwdEyKAfL7AVwDKc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4cHTaGGwdEyKAfL7AVwDKc',
#   'duration_ms': 322587,
#   'time_signature': 4},
#  {'danceability': 0.588,
#   'energy': 0.935,
#   'key': 1,
#   'loudness': -4.282,
#   'mode': 1,
#   'speechiness': 0.0765,
#   'acousticness': 0.00172,
#   'instrumentalness': 0.000757,
#   'liveness': 0.953,
#   'valence': 0.499,
#   'tempo': 125.458,
#   'type': 'audio_features',
#   'id': '2tE7poxpzLc0OOdCce9wpq',
#   'uri': 'spotify:track:2tE7poxpzLc0OOdCce9wpq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tE7poxpzLc0OOdCce9wpq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tE7poxpzLc0OOdCce9wpq',
#   'duration_ms': 234720,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.953,
#   'key': 0,
#   'loudness': -4.475,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.000642,
#   'instrumentalness': 0,
#   'liveness': 0.986,
#   'valence': 0.471,
#   'tempo': 122.007,
#   'type': 'audio_features',
#   'id': '1HM6hzLxTOvB0VBJwL9LlE',
#   'uri': 'spotify:track:1HM6hzLxTOvB0VBJwL9LlE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HM6hzLxTOvB0VBJwL9LlE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HM6hzLxTOvB0VBJwL9LlE',
#   'duration_ms': 276560,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.946,
#   'key': 0,
#   'loudness': -4.138,
#   'mode': 0,
#   'speechiness': 0.0589,
#   'acousticness': 0.00358,
#   'instrumentalness': 2.76e-05,
#   'liveness': 0.99,
#   'valence': 0.635,
#   'tempo': 174.015,
#   'type': 'audio_features',
#   'id': '5RTwFQv0ifeVqVtk4cIhq6',
#   'uri': 'spotify:track:5RTwFQv0ifeVqVtk4cIhq6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RTwFQv0ifeVqVtk4cIhq6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RTwFQv0ifeVqVtk4cIhq6',
#   'duration_ms': 285880,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.966,
#   'key': 6,
#   'loudness': -3.924,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.000481,
#   'instrumentalness': 0.0169,
#   'liveness': 0.988,
#   'valence': 0.664,
#   'tempo': 145.046,
#   'type': 'audio_features',
#   'id': '3AJb72jpJ0rptVu4SPHRxA',
#   'uri': 'spotify:track:3AJb72jpJ0rptVu4SPHRxA',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AJb72jpJ0rptVu4SPHRxA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AJb72jpJ0rptVu4SPHRxA',
#   'duration_ms': 258040,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.992,
#   'key': 0,
#   'loudness': -2.993,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.00199,
#   'instrumentalness': 0,
#   'liveness': 0.933,
#   'valence': 0.517,
#   'tempo': 127.026,
#   'type': 'audio_features',
#   'id': '7EYWm73J1ukOvLJWpHX7K8',
#   'uri': 'spotify:track:7EYWm73J1ukOvLJWpHX7K8',
#   'track_href': 'https://api.spotify.com/v1/tracks/7EYWm73J1ukOvLJWpHX7K8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EYWm73J1ukOvLJWpHX7K8',
#   'duration_ms': 314493,
#   'time_signature': 4},
#  {'danceability': 0.467,
#   'energy': 0.988,
#   'key': 1,
#   'loudness': -4.202,
#   'mode': 0,
#   'speechiness': 0.169,
#   'acousticness': 4.45e-05,
#   'instrumentalness': 0.0953,
#   'liveness': 0.98,
#   'valence': 0.384,
#   'tempo': 128.991,
#   'type': 'audio_features',
#   'id': '6yGKqg22bTZmCf8izwsoa3',
#   'uri': 'spotify:track:6yGKqg22bTZmCf8izwsoa3',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yGKqg22bTZmCf8izwsoa3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yGKqg22bTZmCf8izwsoa3',
#   'duration_ms': 398680,
#   'time_signature': 4},
#  {'danceability': 0.322,
#   'energy': 0.754,
#   'key': 1,
#   'loudness': -5.149,
#   'mode': 0,
#   'speechiness': 0.0424,
#   'acousticness': 0.00208,
#   'instrumentalness': 0.000196,
#   'liveness': 0.982,
#   'valence': 0.325,
#   'tempo': 139.696,
#   'type': 'audio_features',
#   'id': '5kFmXWDOulujZRyFjcaBy0',
#   'uri': 'spotify:track:5kFmXWDOulujZRyFjcaBy0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5kFmXWDOulujZRyFjcaBy0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kFmXWDOulujZRyFjcaBy0',
#   'duration_ms': 372120,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.974,
#   'key': 0,
#   'loudness': -2.712,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.0494,
#   'instrumentalness': 0,
#   'liveness': 0.39,
#   'valence': 0.591,
#   'tempo': 106.599,
#   'type': 'audio_features',
#   'id': '5pEzOXjNSfSNd3euSZLSd4',
#   'uri': 'spotify:track:5pEzOXjNSfSNd3euSZLSd4',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pEzOXjNSfSNd3euSZLSd4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pEzOXjNSfSNd3euSZLSd4',
#   'duration_ms': 239813,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.977,
#   'key': 0,
#   'loudness': -4.796,
#   'mode': 1,
#   'speechiness': 0.11,
#   'acousticness': 0.000221,
#   'instrumentalness': 0.000877,
#   'liveness': 0.873,
#   'valence': 0.505,
#   'tempo': 129.066,
#   'type': 'audio_features',
#   'id': '6d48CaGultITGne1hWBRTa',
#   'uri': 'spotify:track:6d48CaGultITGne1hWBRTa',
#   'track_href': 'https://api.spotify.com/v1/tracks/6d48CaGultITGne1hWBRTa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6d48CaGultITGne1hWBRTa',
#   'duration_ms': 246480,
#   'time_signature': 4},
#  {'danceability': 0.459,
#   'energy': 0.974,
#   'key': 0,
#   'loudness': -4.069,
#   'mode': 1,
#   'speechiness': 0.118,
#   'acousticness': 0.00119,
#   'instrumentalness': 0.000752,
#   'liveness': 0.973,
#   'valence': 0.345,
#   'tempo': 129.982,
#   'type': 'audio_features',
#   'id': '4uAngYdSK3op9wBU3xoSAB',
#   'uri': 'spotify:track:4uAngYdSK3op9wBU3xoSAB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4uAngYdSK3op9wBU3xoSAB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uAngYdSK3op9wBU3xoSAB',
#   'duration_ms': 334587,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.976,
#   'key': 7,
#   'loudness': -3.551,
#   'mode': 1,
#   'speechiness': 0.168,
#   'acousticness': 0.000446,
#   'instrumentalness': 0.000187,
#   'liveness': 0.966,
#   'valence': 0.277,
#   'tempo': 115.688,
#   'type': 'audio_features',
#   'id': '67BH3Ng6cRi7Opcan15TSZ',
#   'uri': 'spotify:track:67BH3Ng6cRi7Opcan15TSZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/67BH3Ng6cRi7Opcan15TSZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67BH3Ng6cRi7Opcan15TSZ',
#   'duration_ms': 356467,
#   'time_signature': 4},
#  {'danceability': 0.414,
#   'energy': 0.975,
#   'key': 9,
#   'loudness': -3.009,
#   'mode': 1,
#   'speechiness': 0.0981,
#   'acousticness': 0.00435,
#   'instrumentalness': 0.00185,
#   'liveness': 0.96,
#   'valence': 0.518,
#   'tempo': 140.98,
#   'type': 'audio_features',
#   'id': '2JzCwSmozpeaNwRYwUFGA2',
#   'uri': 'spotify:track:2JzCwSmozpeaNwRYwUFGA2',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JzCwSmozpeaNwRYwUFGA2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JzCwSmozpeaNwRYwUFGA2',
#   'duration_ms': 443600,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.665,
#   'key': 11,
#   'loudness': -5.765,
#   'mode': 0,
#   'speechiness': 0.043,
#   'acousticness': 0.00104,
#   'instrumentalness': 0,
#   'liveness': 0.891,
#   'valence': 0.259,
#   'tempo': 78.252,
#   'type': 'audio_features',
#   'id': '3XHykIf1ghY1O8rAJql5VK',
#   'uri': 'spotify:track:3XHykIf1ghY1O8rAJql5VK',
#   'track_href': 'https://api.spotify.com/v1/tracks/3XHykIf1ghY1O8rAJql5VK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XHykIf1ghY1O8rAJql5VK',
#   'duration_ms': 258213,
#   'time_signature': 4},
#  {'danceability': 0.49,
#   'energy': 0.975,
#   'key': 0,
#   'loudness': -4.708,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 9.88e-05,
#   'instrumentalness': 0.0186,
#   'liveness': 0.97,
#   'valence': 0.138,
#   'tempo': 131.608,
#   'type': 'audio_features',
#   'id': '4PlIcGmTVOFI5SCs3nhpZa',
#   'uri': 'spotify:track:4PlIcGmTVOFI5SCs3nhpZa',
#   'track_href': 'https://api.spotify.com/v1/tracks/4PlIcGmTVOFI5SCs3nhpZa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4PlIcGmTVOFI5SCs3nhpZa',
#   'duration_ms': 322587,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.935,
#   'key': 1,
#   'loudness': -4.275,
#   'mode': 1,
#   'speechiness': 0.0667,
#   'acousticness': 0.00135,
#   'instrumentalness': 0.000947,
#   'liveness': 0.951,
#   'valence': 0.527,
#   'tempo': 125.458,
#   'type': 'audio_features',
#   'id': '7770Mf1zbfbxTJ2OTjpaBB',
#   'uri': 'spotify:track:7770Mf1zbfbxTJ2OTjpaBB',
#   'track_href': 'https://api.spotify.com/v1/tracks/7770Mf1zbfbxTJ2OTjpaBB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7770Mf1zbfbxTJ2OTjpaBB',
#   'duration_ms': 234720,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.95,
#   'key': 0,
#   'loudness': -4.481,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'acousticness': 0.000502,
#   'instrumentalness': 0,
#   'liveness': 0.987,
#   'valence': 0.513,
#   'tempo': 122.029,
#   'type': 'audio_features',
#   'id': '1lFI5jcmW3NUJ82m5FpoHa',
#   'uri': 'spotify:track:1lFI5jcmW3NUJ82m5FpoHa',
#   'track_href': 'https://api.spotify.com/v1/tracks/1lFI5jcmW3NUJ82m5FpoHa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1lFI5jcmW3NUJ82m5FpoHa',
#   'duration_ms': 276560,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.941,
#   'key': 0,
#   'loudness': -4.163,
#   'mode': 0,
#   'speechiness': 0.0606,
#   'acousticness': 0.00362,
#   'instrumentalness': 1.67e-05,
#   'liveness': 0.99,
#   'valence': 0.66,
#   'tempo': 173.978,
#   'type': 'audio_features',
#   'id': '5BBgA17NzHZJk8Qqls0QI0',
#   'uri': 'spotify:track:5BBgA17NzHZJk8Qqls0QI0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BBgA17NzHZJk8Qqls0QI0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BBgA17NzHZJk8Qqls0QI0',
#   'duration_ms': 285880,
#   'time_signature': 4},
#  {'danceability': 0.556,
#   'energy': 0.966,
#   'key': 6,
#   'loudness': -3.922,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'acousticness': 0.000447,
#   'instrumentalness': 0.0139,
#   'liveness': 0.988,
#   'valence': 0.664,
#   'tempo': 145.055,
#   'type': 'audio_features',
#   'id': '3Jv6tvPBYGuCLroVaZEMLL',
#   'uri': 'spotify:track:3Jv6tvPBYGuCLroVaZEMLL',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Jv6tvPBYGuCLroVaZEMLL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Jv6tvPBYGuCLroVaZEMLL',
#   'duration_ms': 258040,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.992,
#   'key': 0,
#   'loudness': -3.019,
#   'mode': 1,
#   'speechiness': 0.123,
#   'acousticness': 0.00201,
#   'instrumentalness': 0,
#   'liveness': 0.944,
#   'valence': 0.573,
#   'tempo': 127.012,
#   'type': 'audio_features',
#   'id': '2ghhutGLhE7HeCk1x3guRL',
#   'uri': 'spotify:track:2ghhutGLhE7HeCk1x3guRL',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ghhutGLhE7HeCk1x3guRL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ghhutGLhE7HeCk1x3guRL',
#   'duration_ms': 314493,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.989,
#   'key': 4,
#   'loudness': -4.184,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 4.34e-05,
#   'instrumentalness': 0.0667,
#   'liveness': 0.982,
#   'valence': 0.344,
#   'tempo': 128.989,
#   'type': 'audio_features',
#   'id': '3DNxjRtj42RyJuKsc2yNd6',
#   'uri': 'spotify:track:3DNxjRtj42RyJuKsc2yNd6',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DNxjRtj42RyJuKsc2yNd6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DNxjRtj42RyJuKsc2yNd6',
#   'duration_ms': 398680,
#   'time_signature': 4},
#  {'danceability': 0.314,
#   'energy': 0.749,
#   'key': 1,
#   'loudness': -5.146,
#   'mode': 0,
#   'speechiness': 0.0378,
#   'acousticness': 0.00291,
#   'instrumentalness': 0.000207,
#   'liveness': 0.983,
#   'valence': 0.322,
#   'tempo': 139.692,
#   'type': 'audio_features',
#   'id': '6dJU94I0eSrPUFkmnUcC6p',
#   'uri': 'spotify:track:6dJU94I0eSrPUFkmnUcC6p',
#   'track_href': 'https://api.spotify.com/v1/tracks/6dJU94I0eSrPUFkmnUcC6p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dJU94I0eSrPUFkmnUcC6p',
#   'duration_ms': 372120,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.977,
#   'key': 0,
#   'loudness': -2.721,
#   'mode': 1,
#   'speechiness': 0.156,
#   'acousticness': 0.0486,
#   'instrumentalness': 0,
#   'liveness': 0.393,
#   'valence': 0.593,
#   'tempo': 106.591,
#   'type': 'audio_features',
#   'id': '01jmzODwDzHPPTtWvvcdq0',
#   'uri': 'spotify:track:01jmzODwDzHPPTtWvvcdq0',
#   'track_href': 'https://api.spotify.com/v1/tracks/01jmzODwDzHPPTtWvvcdq0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01jmzODwDzHPPTtWvvcdq0',
#   'duration_ms': 239813,
#   'time_signature': 4},
#  {'danceability': 0.503,
#   'energy': 0.974,
#   'key': 9,
#   'loudness': -4.814,
#   'mode': 0,
#   'speechiness': 0.129,
#   'acousticness': 0.00022,
#   'instrumentalness': 0.00119,
#   'liveness': 0.874,
#   'valence': 0.467,
#   'tempo': 129.081,
#   'type': 'audio_features',
#   'id': '0avo3ah1pUF3K5lGuRNvPF',
#   'uri': 'spotify:track:0avo3ah1pUF3K5lGuRNvPF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0avo3ah1pUF3K5lGuRNvPF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0avo3ah1pUF3K5lGuRNvPF',
#   'duration_ms': 246480,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.977,
#   'key': 0,
#   'loudness': -4.048,
#   'mode': 1,
#   'speechiness': 0.119,
#   'acousticness': 0.00129,
#   'instrumentalness': 0.000989,
#   'liveness': 0.972,
#   'valence': 0.344,
#   'tempo': 129.955,
#   'type': 'audio_features',
#   'id': '1UiRhN1y1ML67E7oTjKtlZ',
#   'uri': 'spotify:track:1UiRhN1y1ML67E7oTjKtlZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1UiRhN1y1ML67E7oTjKtlZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1UiRhN1y1ML67E7oTjKtlZ',
#   'duration_ms': 334587,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.977,
#   'key': 7,
#   'loudness': -3.534,
#   'mode': 1,
#   'speechiness': 0.167,
#   'acousticness': 0.000469,
#   'instrumentalness': 0.00018,
#   'liveness': 0.952,
#   'valence': 0.261,
#   'tempo': 115.69,
# ...
#   'loudness': -10.01,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'acousticness': 0.0702,
#   'instrumentalness': 0.0305,
#   'liveness': 0.0568,
#   'valence': 0.864,
#   'tempo': 92.361,
#   'type': 'audio_features',
#   'id': '2leLW4hgVA2MEG02PB3TN3',
#   'uri': 'spotify:track:2leLW4hgVA2MEG02PB3TN3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2leLW4hgVA2MEG02PB3TN3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2leLW4hgVA2MEG02PB3TN3',
#   'duration_ms': 247691,
#   'time_signature': 4},
#  {'danceability': 0.841,
#   'energy': 0.747,
#   'key': 1,
#   'loudness': -11.218,
#   'mode': 0,
#   'speechiness': 0.0471,
#   'acousticness': 0.00631,
#   'instrumentalness': 0.228,
#   'liveness': 0.0392,
#   'valence': 0.876,
#   'tempo': 117.047,
#   'type': 'audio_features',
#   'id': '4yQ2J750Zg0baA6MeQ556u',
#   'uri': 'spotify:track:4yQ2J750Zg0baA6MeQ556u',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yQ2J750Zg0baA6MeQ556u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yQ2J750Zg0baA6MeQ556u',
#   'duration_ms': 302980,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.897,
#   'key': 5,
#   'loudness': -7.32,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.165,
#   'instrumentalness': 1.9e-05,
#   'liveness': 0.0668,
#   'valence': 0.894,
#   'tempo': 91.775,
#   'type': 'audio_features',
#   'id': '0YuqaTaX6wdAI3mSR6LPQt',
#   'uri': 'spotify:track:0YuqaTaX6wdAI3mSR6LPQt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0YuqaTaX6wdAI3mSR6LPQt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0YuqaTaX6wdAI3mSR6LPQt',
#   'duration_ms': 321803,
#   'time_signature': 4},
#  {'danceability': 0.377,
#   'energy': 0.468,
#   'key': 1,
#   'loudness': -14.7,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.0712,
#   'instrumentalness': 0.000453,
#   'liveness': 0.176,
#   'valence': 0.272,
#   'tempo': 127.851,
#   'type': 'audio_features',
#   'id': '6dDYckwvmMGZO1qB1tiuWv',
#   'uri': 'spotify:track:6dDYckwvmMGZO1qB1tiuWv',
#   'track_href': 'https://api.spotify.com/v1/tracks/6dDYckwvmMGZO1qB1tiuWv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dDYckwvmMGZO1qB1tiuWv',
#   'duration_ms': 276389,
#   'time_signature': 3},
#  {'danceability': 0.457,
#   'energy': 0.545,
#   'key': 3,
#   'loudness': -9.459,
#   'mode': 1,
#   'speechiness': 0.0561,
#   'acousticness': 0.527,
#   'instrumentalness': 0.000628,
#   'liveness': 0.292,
#   'valence': 0.368,
#   'tempo': 138.178,
#   'type': 'audio_features',
#   'id': '2mpPu9931WS9IDrhS6tE1x',
#   'uri': 'spotify:track:2mpPu9931WS9IDrhS6tE1x',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mpPu9931WS9IDrhS6tE1x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mpPu9931WS9IDrhS6tE1x',
#   'duration_ms': 246870,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.901,
#   'key': 7,
#   'loudness': -8.536,
#   'mode': 0,
#   'speechiness': 0.118,
#   'acousticness': 0.0222,
#   'instrumentalness': 0.28,
#   'liveness': 0.27,
#   'valence': 0.844,
#   'tempo': 196.768,
#   'type': 'audio_features',
#   'id': '4fW718TtzWhIfGMc6owKzZ',
#   'uri': 'spotify:track:4fW718TtzWhIfGMc6owKzZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4fW718TtzWhIfGMc6owKzZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fW718TtzWhIfGMc6owKzZ',
#   'duration_ms': 230893,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.843,
#   'key': 10,
#   'loudness': -9.264,
#   'mode': 0,
#   'speechiness': 0.0591,
#   'acousticness': 0.0253,
#   'instrumentalness': 0.00363,
#   'liveness': 0.356,
#   'valence': 0.67,
#   'tempo': 161.355,
#   'type': 'audio_features',
#   'id': '5UOkz2bU1PO6GzzTir8Yiw',
#   'uri': 'spotify:track:5UOkz2bU1PO6GzzTir8Yiw',
#   'track_href': 'https://api.spotify.com/v1/tracks/5UOkz2bU1PO6GzzTir8Yiw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UOkz2bU1PO6GzzTir8Yiw',
#   'duration_ms': 360950,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.921,
#   'key': 1,
#   'loudness': -9.777,
#   'mode': 1,
#   'speechiness': 0.0384,
#   'acousticness': 0.0924,
#   'instrumentalness': 0.203,
#   'liveness': 0.106,
#   'valence': 0.895,
#   'tempo': 126.22,
#   'type': 'audio_features',
#   'id': '7maJwv0eHozssxFLU63AlO',
#   'uri': 'spotify:track:7maJwv0eHozssxFLU63AlO',
#   'track_href': 'https://api.spotify.com/v1/tracks/7maJwv0eHozssxFLU63AlO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7maJwv0eHozssxFLU63AlO',
#   'duration_ms': 289507,
#   'time_signature': 4},
#  {'danceability': 0.797,
#   'energy': 0.855,
#   'key': 7,
#   'loudness': -8.56,
#   'mode': 1,
#   'speechiness': 0.077,
#   'acousticness': 0.00198,
#   'instrumentalness': 0.0561,
#   'liveness': 0.0372,
#   'valence': 0.735,
#   'tempo': 98.429,
#   'type': 'audio_features',
#   'id': '6U0YEjLHmGbDC0yEHNaaSa',
#   'uri': 'spotify:track:6U0YEjLHmGbDC0yEHNaaSa',
#   'track_href': 'https://api.spotify.com/v1/tracks/6U0YEjLHmGbDC0yEHNaaSa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6U0YEjLHmGbDC0yEHNaaSa',
#   'duration_ms': 249418,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.92,
#   'key': 7,
#   'loudness': -8.685,
#   'mode': 0,
#   'speechiness': 0.0609,
#   'acousticness': 0.0143,
#   'instrumentalness': 0.278,
#   'liveness': 0.216,
#   'valence': 0.759,
#   'tempo': 98.374,
#   'type': 'audio_features',
#   'id': '6i8xgkKI9Hy583JkVGOyJz',
#   'uri': 'spotify:track:6i8xgkKI9Hy583JkVGOyJz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6i8xgkKI9Hy583JkVGOyJz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6i8xgkKI9Hy583JkVGOyJz',
#   'duration_ms': 339947,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.573,
#   'key': 10,
#   'loudness': -13.144,
#   'mode': 0,
#   'speechiness': 0.0449,
#   'acousticness': 0.0244,
#   'instrumentalness': 0.000226,
#   'liveness': 0.0792,
#   'valence': 0.822,
#   'tempo': 98.248,
#   'type': 'audio_features',
#   'id': '4kdVNFSxFM5FjbDEXrrqs8',
#   'uri': 'spotify:track:4kdVNFSxFM5FjbDEXrrqs8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4kdVNFSxFM5FjbDEXrrqs8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4kdVNFSxFM5FjbDEXrrqs8',
#   'duration_ms': 355040,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.771,
#   'key': 6,
#   'loudness': -9.537,
#   'mode': 0,
#   'speechiness': 0.0535,
#   'acousticness': 0.00258,
#   'instrumentalness': 0.264,
#   'liveness': 0.0462,
#   'valence': 0.91,
#   'tempo': 117.857,
#   'type': 'audio_features',
#   'id': '4xTjhIFjK1iF91dHIJ6MLJ',
#   'uri': 'spotify:track:4xTjhIFjK1iF91dHIJ6MLJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xTjhIFjK1iF91dHIJ6MLJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xTjhIFjK1iF91dHIJ6MLJ',
#   'duration_ms': 272372,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.53,
#   'key': 2,
#   'loudness': -9.535,
#   'mode': 1,
#   'speechiness': 0.0251,
#   'acousticness': 0.568,
#   'instrumentalness': 0,
#   'liveness': 0.193,
#   'valence': 0.589,
#   'tempo': 104.976,
#   'type': 'audio_features',
#   'id': '4PPvcFVmgJq7bJrAAa6hDe',
#   'uri': 'spotify:track:4PPvcFVmgJq7bJrAAa6hDe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4PPvcFVmgJq7bJrAAa6hDe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4PPvcFVmgJq7bJrAAa6hDe',
#   'duration_ms': 285257,
#   'time_signature': 4},
#  {'danceability': 0.714,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -14.612,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.13,
#   'instrumentalness': 2.34e-05,
#   'liveness': 0.107,
#   'valence': 0.62,
#   'tempo': 129.604,
#   'type': 'audio_features',
#   'id': '12mgkzfizFiWfrhr4EOKfn',
#   'uri': 'spotify:track:12mgkzfizFiWfrhr4EOKfn',
#   'track_href': 'https://api.spotify.com/v1/tracks/12mgkzfizFiWfrhr4EOKfn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12mgkzfizFiWfrhr4EOKfn',
#   'duration_ms': 201135,
#   'time_signature': 4},
#  {'danceability': 0.186,
#   'energy': 0.415,
#   'key': 0,
#   'loudness': -10.433,
#   'mode': 0,
#   'speechiness': 0.046,
#   'acousticness': 0.76,
#   'instrumentalness': 3.06e-06,
#   'liveness': 0.988,
#   'valence': 0.153,
#   'tempo': 72.726,
#   'type': 'audio_features',
#   'id': '5VdrZRxY1OpK9ZkYcSOS2K',
#   'uri': 'spotify:track:5VdrZRxY1OpK9ZkYcSOS2K',
#   'track_href': 'https://api.spotify.com/v1/tracks/5VdrZRxY1OpK9ZkYcSOS2K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VdrZRxY1OpK9ZkYcSOS2K',
#   'duration_ms': 309813,
#   'time_signature': 4},
#  {'danceability': 0.541,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -8.989,
#   'mode': 1,
#   'speechiness': 0.108,
#   'acousticness': 0.158,
#   'instrumentalness': 0,
#   'liveness': 0.98,
#   'valence': 0.595,
#   'tempo': 145.711,
#   'type': 'audio_features',
#   'id': '5XWvGAx7lFUm98EraGSCoE',
#   'uri': 'spotify:track:5XWvGAx7lFUm98EraGSCoE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XWvGAx7lFUm98EraGSCoE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XWvGAx7lFUm98EraGSCoE',
#   'duration_ms': 116741,
#   'time_signature': 4},
#  {'danceability': 0.498,
#   'energy': 0.266,
#   'key': 5,
#   'loudness': -15.23,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.852,
#   'instrumentalness': 0.00381,
#   'liveness': 0.718,
#   'valence': 0.342,
#   'tempo': 100.353,
#   'type': 'audio_features',
#   'id': '2UviQmXcpUTVkneqszQqn3',
#   'uri': 'spotify:track:2UviQmXcpUTVkneqszQqn3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UviQmXcpUTVkneqszQqn3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UviQmXcpUTVkneqszQqn3',
#   'duration_ms': 254181,
#   'time_signature': 4},
#  {'danceability': 0.552,
#   'energy': 0.554,
#   'key': 9,
#   'loudness': -9.619,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.0838,
#   'instrumentalness': 0,
#   'liveness': 0.994,
#   'valence': 0.18,
#   'tempo': 127.929,
#   'type': 'audio_features',
#   'id': '0fQDbOYcVFnxXrD4XBXAyL',
#   'uri': 'spotify:track:0fQDbOYcVFnxXrD4XBXAyL',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fQDbOYcVFnxXrD4XBXAyL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fQDbOYcVFnxXrD4XBXAyL',
#   'duration_ms': 298052,
#   'time_signature': 4},
#  {'danceability': 0.431,
#   'energy': 0.138,
#   'key': 8,
#   'loudness': -13.763,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.921,
#   'instrumentalness': 0,
#   'liveness': 0.936,
#   'valence': 0.438,
#   'tempo': 117.818,
#   'type': 'audio_features',
#   'id': '6trqPmc6OT7FVWKViMMChW',
#   'uri': 'spotify:track:6trqPmc6OT7FVWKViMMChW',
#   'track_href': 'https://api.spotify.com/v1/tracks/6trqPmc6OT7FVWKViMMChW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6trqPmc6OT7FVWKViMMChW',
#   'duration_ms': 230508,
#   'time_signature': 4},
#  {'danceability': 0.263,
#   'energy': 0.188,
#   'key': 10,
#   'loudness': -13.481,
#   'mode': 0,
#   'speechiness': 0.0311,
#   'acousticness': 0.851,
#   'instrumentalness': 0.106,
#   'liveness': 0.947,
#   'valence': 0.1,
#   'tempo': 135.248,
#   'type': 'audio_features',
#   'id': '1k2lnqwmNfINUkBCl148C5',
#   'uri': 'spotify:track:1k2lnqwmNfINUkBCl148C5',
#   'track_href': 'https://api.spotify.com/v1/tracks/1k2lnqwmNfINUkBCl148C5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1k2lnqwmNfINUkBCl148C5',
#   'duration_ms': 324338,
#   'time_signature': 4},
#  {'danceability': 0.429,
#   'energy': 0.824,
#   'key': 4,
#   'loudness': -8.331,
#   'mode': 0,
#   'speechiness': 0.129,
#   'acousticness': 0.102,
#   'instrumentalness': 0,
#   'liveness': 0.954,
#   'valence': 0.412,
#   'tempo': 118.629,
#   'type': 'audio_features',
#   'id': '71Z3DZX7GV7TebplvVawmp',
#   'uri': 'spotify:track:71Z3DZX7GV7TebplvVawmp',
#   'track_href': 'https://api.spotify.com/v1/tracks/71Z3DZX7GV7TebplvVawmp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71Z3DZX7GV7TebplvVawmp',
#   'duration_ms': 195958,
#   'time_signature': 3},
#  {'danceability': 0.69,
#   'energy': 0.436,
#   'key': 0,
#   'loudness': -9.948,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.0842,
#   'instrumentalness': 0,
#   'liveness': 0.981,
#   'valence': 0.192,
#   'tempo': 109.966,
#   'type': 'audio_features',
#   'id': '4OTIHBzjdtzrxAORGMIcOW',
#   'uri': 'spotify:track:4OTIHBzjdtzrxAORGMIcOW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4OTIHBzjdtzrxAORGMIcOW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4OTIHBzjdtzrxAORGMIcOW',
#   'duration_ms': 271353,
#   'time_signature': 4},
#  {'danceability': 0.322,
#   'energy': 0.449,
#   'key': 1,
#   'loudness': -9.932,
#   'mode': 1,
#   'speechiness': 0.0352,
#   'acousticness': 0.818,
#   'instrumentalness': 0,
#   'liveness': 0.946,
#   'valence': 0.336,
#   'tempo': 115.997,
#   'type': 'audio_features',
#   'id': '0RjhYRl1EVoqJmSHNNFEGn',
#   'uri': 'spotify:track:0RjhYRl1EVoqJmSHNNFEGn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0RjhYRl1EVoqJmSHNNFEGn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RjhYRl1EVoqJmSHNNFEGn',
#   'duration_ms': 314696,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.596,
#   'key': 10,
#   'loudness': -10.517,
#   'mode': 0,
#   'speechiness': 0.0376,
#   'acousticness': 0.18,
#   'instrumentalness': 0.000161,
#   'liveness': 0.753,
#   'valence': 0.259,
#   'tempo': 128.932,
#   'type': 'audio_features',
#   'id': '5P4j0KhOSwt6rqsMZTiXbT',
#   'uri': 'spotify:track:5P4j0KhOSwt6rqsMZTiXbT',
#   'track_href': 'https://api.spotify.com/v1/tracks/5P4j0KhOSwt6rqsMZTiXbT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5P4j0KhOSwt6rqsMZTiXbT',
#   'duration_ms': 444088,
#   'time_signature': 3},
#  {'danceability': 0.583,
#   'energy': 0.387,
#   'key': 4,
#   'loudness': -11.994,
#   'mode': 0,
#   'speechiness': 0.0398,
#   'acousticness': 0.473,
#   'instrumentalness': 0,
#   'liveness': 0.972,
#   'valence': 0.163,
#   'tempo': 119.889,
#   'type': 'audio_features',
#   'id': '5g6LhIuy6juvdi1pW9xmqj',
#   'uri': 'spotify:track:5g6LhIuy6juvdi1pW9xmqj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5g6LhIuy6juvdi1pW9xmqj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5g6LhIuy6juvdi1pW9xmqj',
#   'duration_ms': 269891,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.464,
#   'key': 11,
#   'loudness': -9.763,
#   'mode': 0,
#   'speechiness': 0.0329,
#   'acousticness': 0.501,
#   'instrumentalness': 2.04e-06,
#   'liveness': 0.982,
#   'valence': 0.0899,
#   'tempo': 94.464,
#   'type': 'audio_features',
#   'id': '3p43d8uAeA9xwm8xXDZ9Ej',
#   'uri': 'spotify:track:3p43d8uAeA9xwm8xXDZ9Ej',
#   'track_href': 'https://api.spotify.com/v1/tracks/3p43d8uAeA9xwm8xXDZ9Ej',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3p43d8uAeA9xwm8xXDZ9Ej',
#   'duration_ms': 291072,
#   'time_signature': 3},
#  {'danceability': 0.168,
#   'energy': 0.181,
#   'key': 9,
#   'loudness': -15.846,
#   'mode': 0,
#   'speechiness': 0.0334,
#   'acousticness': 0.645,
#   'instrumentalness': 0.00208,
#   'liveness': 0.978,
#   'valence': 0.116,
#   'tempo': 179.012,
#   'type': 'audio_features',
#   'id': '53DsrfqbVyq8mYTrzbUWo6',
#   'uri': 'spotify:track:53DsrfqbVyq8mYTrzbUWo6',
#   'track_href': 'https://api.spotify.com/v1/tracks/53DsrfqbVyq8mYTrzbUWo6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53DsrfqbVyq8mYTrzbUWo6',
#   'duration_ms': 255278,
#   'time_signature': 3},
#  {'danceability': 0.294,
#   'energy': 0.252,
#   'key': 0,
#   'loudness': -15.111,
#   'mode': 1,
#   'speechiness': 0.0351,
#   'acousticness': 0.746,
#   'instrumentalness': 5.5e-06,
#   'liveness': 0.977,
#   'valence': 0.0706,
#   'tempo': 58.735,
#   'type': 'audio_features',
#   'id': '71tg7302BygxJwEl7Tca1z',
#   'uri': 'spotify:track:71tg7302BygxJwEl7Tca1z',
#   'track_href': 'https://api.spotify.com/v1/tracks/71tg7302BygxJwEl7Tca1z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71tg7302BygxJwEl7Tca1z',
#   'duration_ms': 284754,
#   'time_signature': 4},
#  {'danceability': 0.185,
#   'energy': 0.412,
#   'key': 0,
#   'loudness': -10.431,
#   'mode': 0,
#   'speechiness': 0.0459,
#   'acousticness': 0.759,
#   'instrumentalness': 3.09e-06,
#   'liveness': 0.987,
#   'valence': 0.153,
#   'tempo': 72.599,
#   'type': 'audio_features',
#   'id': '6B8vO1gto58lY9cPVNLRee',
#   'uri': 'spotify:track:6B8vO1gto58lY9cPVNLRee',
#   'track_href': 'https://api.spotify.com/v1/tracks/6B8vO1gto58lY9cPVNLRee',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6B8vO1gto58lY9cPVNLRee',
#   'duration_ms': 309822,
#   'time_signature': 4},
#  ...]

# %%
len(audio_features_list)
# Out:
# 34243

# %% [markdown]
# ### We truncate it to 20.000 songs

# %%
af = audio_features_from_song_ids(song_ids[:20000])

# %%
#songs_2000 = song_ids[:2000]

# %%
audio_features_df=pd.DataFrame(af)

# %%
audio_features_df
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.307   0.153   10   -25.952     0       0.0443       0.88300
# 1             0.478   0.561   10   -14.545     0       0.0754       0.12100
# 2             0.501   0.927   10    -6.744     0       0.0690       0.05550
# 3             0.542   0.902    6    -6.028     0       0.1040       0.00157
# 4             0.574   0.932    7    -5.841     1       0.0711       0.03380
# ...             ...     ...  ...       ...   ...          ...           ...
# 19995         0.550   0.543    2   -11.067     1       0.0333       0.50100
# 19996         0.645   0.610    6   -12.163     1       0.0556       0.10500
# 19997         0.599   0.455   11   -11.865     0       0.0288       0.11300
# 19998         0.456   0.550    2   -10.303     1       0.0367       0.44600
# 19999         0.549   0.800    6    -9.823     1       0.0899       0.06420
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.971000     0.840    0.130   79.853  audio_features
# 1              0.011400     0.881    0.257  118.898  audio_features
# 2              0.047700     0.701    0.537  118.744  audio_features
# 3              0.012100     0.697    0.245   99.944  audio_features
# 4              0.000009     0.717    0.665  128.864  audio_features
# ...                 ...       ...      ...      ...             ...
# 19995          0.000000     0.206    0.434  104.126  audio_features
# 19996          0.000000     0.413    0.846  120.043  audio_features
# 19997          0.000000     0.142    0.367  110.043  audio_features
# 19998          0.000000     0.150    0.594  159.935  audio_features
# 19999          0.000000     0.192    0.506  139.706  audio_features
#
#                            id                                   uri  \
# 0      3kjoAqJUsLs8TKZaofvPnd  spotify:track:3kjoAqJUsLs8TKZaofvPnd
# 1      4NTNiAtUyadCRye3LlHnGY  spotify:track:4NTNiAtUyadCRye3LlHnGY
# 2      1CqNphayCWFkjvVBM8Tc9y  spotify:track:1CqNphayCWFkjvVBM8Tc9y
# 3      0r5JSBykFXMEbYkhapxZ3o  spotify:track:0r5JSBykFXMEbYkhapxZ3o
# 4      2QUrwP0t7rWiD8Beit13h4  spotify:track:2QUrwP0t7rWiD8Beit13h4
# ...                       ...                                   ...
# 19995  2d45Y8BRDOlpxFkQMQNmPa  spotify:track:2d45Y8BRDOlpxFkQMQNmPa
# 19996  76N07dzLLE6AvuO89c5mxu  spotify:track:76N07dzLLE6AvuO89c5mxu
# 19997  4WYFiOhnCawe4AlAXzCsJY  spotify:track:4WYFiOhnCawe4AlAXzCsJY
# 19998  55jv3qZBi6OPCwA0gLfGEZ  spotify:track:55jv3qZBi6OPCwA0gLfGEZ
# 19999  24VEFrVKfddSc1IUhgpEvr  spotify:track:24VEFrVKfddSc1IUhgpEvr
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3kjoAqJUsLs8...
# 1      https://api.spotify.com/v1/tracks/4NTNiAtUyadC...
# 2      https://api.spotify.com/v1/tracks/1CqNphayCWFk...
# 3      https://api.spotify.com/v1/tracks/0r5JSBykFXME...
# 4      https://api.spotify.com/v1/tracks/2QUrwP0t7rWi...
# ...                                                  ...
# 19995  https://api.spotify.com/v1/tracks/2d45Y8BRDOlp...
# 19996  https://api.spotify.com/v1/tracks/76N07dzLLE6A...
# 19997  https://api.spotify.com/v1/tracks/4WYFiOhnCawe...
# 19998  https://api.spotify.com/v1/tracks/55jv3qZBi6OP...
# 19999  https://api.spotify.com/v1/tracks/24VEFrVKfddS...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3kjo...       171880
# 1      https://api.spotify.com/v1/audio-analysis/4NTN...        65200
# 2      https://api.spotify.com/v1/audio-analysis/1CqN...       227520
# 3      https://api.spotify.com/v1/audio-analysis/0r5J...       347440
# 4      https://api.spotify.com/v1/audio-analysis/2QUr...       204067
# ...                                                  ...          ...
# 19995  https://api.spotify.com/v1/audio-analysis/2d45...       295627
# 19996  https://api.spotify.com/v1/audio-analysis/76N0...       260960
# 19997  https://api.spotify.com/v1/audio-analysis/4WYF...       328853
# 19998  https://api.spotify.com/v1/audio-analysis/55jv...       292493
# 19999  https://api.spotify.com/v1/audio-analysis/24VE...       275693
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 19995               4
# 19996               4
# 19997               4
# 19998               4
# 19999               4
#
# [20000 rows x 18 columns]

# %%
# truncate song_ids:

song_ids_20000 = song_ids[:20000]

# %%
titles_artists_df = titles_artists_df[:20000]

# %%
titles_artists_df.shape
# Out:
# (20000, 2)

# %%
# concatenate title_artist df with audio features df

df_80s = pd.concat([titles_artists_df, audio_features_df], axis=1)

# %%
df_80s.head()
# Out:
#                          title       artist  danceability  energy  key  \
# 0               Opening - Live  Duran Duran         0.307   0.153   10
# 1                 Intro - Live  Duran Duran         0.478   0.561   10
# 2           Medazzaland - Live  Duran Duran         0.501   0.927   10
# 3   Big Bang Generation - Live  Duran Duran         0.542   0.902    6
# 4  Hungry Like the Wolf - Live  Duran Duran         0.574   0.932    7
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -25.952     0       0.0443       0.88300          0.971000     0.840
# 1   -14.545     0       0.0754       0.12100          0.011400     0.881
# 2    -6.744     0       0.0690       0.05550          0.047700     0.701
# 3    -6.028     0       0.1040       0.00157          0.012100     0.697
# 4    -5.841     1       0.0711       0.03380          0.000009     0.717
#
#    valence    tempo            type                      id  \
# 0    0.130   79.853  audio_features  3kjoAqJUsLs8TKZaofvPnd
# 1    0.257  118.898  audio_features  4NTNiAtUyadCRye3LlHnGY
# 2    0.537  118.744  audio_features  1CqNphayCWFkjvVBM8Tc9y
# 3    0.245   99.944  audio_features  0r5JSBykFXMEbYkhapxZ3o
# 4    0.665  128.864  audio_features  2QUrwP0t7rWiD8Beit13h4
#
#                                     uri  \
# 0  spotify:track:3kjoAqJUsLs8TKZaofvPnd
# 1  spotify:track:4NTNiAtUyadCRye3LlHnGY
# 2  spotify:track:1CqNphayCWFkjvVBM8Tc9y
# 3  spotify:track:0r5JSBykFXMEbYkhapxZ3o
# 4  spotify:track:2QUrwP0t7rWiD8Beit13h4
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3kjoAqJUsLs8...
# 1  https://api.spotify.com/v1/tracks/4NTNiAtUyadC...
# 2  https://api.spotify.com/v1/tracks/1CqNphayCWFk...
# 3  https://api.spotify.com/v1/tracks/0r5JSBykFXME...
# 4  https://api.spotify.com/v1/tracks/2QUrwP0t7rWi...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3kjo...       171880
# 1  https://api.spotify.com/v1/audio-analysis/4NTN...        65200
# 2  https://api.spotify.com/v1/audio-analysis/1CqN...       227520
# 3  https://api.spotify.com/v1/audio-analysis/0r5J...       347440
# 4  https://api.spotify.com/v1/audio-analysis/2QUr...       204067
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
df_80s.shape
# Out:
# (20000, 20)

# %%
df_80s.to_csv('80s_playlist.csv')

# %% [markdown]
# # CLUSTERING

# %%
playlist_80s = pd.read_csv('80s_playlist.csv')

# %%
playlist_80s.drop('Unnamed: 0', axis='columns', inplace=True)

# %%
playlist_80s.head()
# Out:
#                          title       artist  danceability  energy  key  \
# 0               Opening - Live  Duran Duran         0.307   0.153   10
# 1                 Intro - Live  Duran Duran         0.478   0.561   10
# 2           Medazzaland - Live  Duran Duran         0.501   0.927   10
# 3   Big Bang Generation - Live  Duran Duran         0.542   0.902    6
# 4  Hungry Like the Wolf - Live  Duran Duran         0.574   0.932    7
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -25.952     0       0.0443       0.88300          0.971000     0.840
# 1   -14.545     0       0.0754       0.12100          0.011400     0.881
# 2    -6.744     0       0.0690       0.05550          0.047700     0.701
# 3    -6.028     0       0.1040       0.00157          0.012100     0.697
# 4    -5.841     1       0.0711       0.03380          0.000009     0.717
#
#    valence    tempo            type                      id  \
# 0    0.130   79.853  audio_features  3kjoAqJUsLs8TKZaofvPnd
# 1    0.257  118.898  audio_features  4NTNiAtUyadCRye3LlHnGY
# 2    0.537  118.744  audio_features  1CqNphayCWFkjvVBM8Tc9y
# 3    0.245   99.944  audio_features  0r5JSBykFXMEbYkhapxZ3o
# 4    0.665  128.864  audio_features  2QUrwP0t7rWiD8Beit13h4
#
#                                     uri  \
# 0  spotify:track:3kjoAqJUsLs8TKZaofvPnd
# 1  spotify:track:4NTNiAtUyadCRye3LlHnGY
# 2  spotify:track:1CqNphayCWFkjvVBM8Tc9y
# 3  spotify:track:0r5JSBykFXMEbYkhapxZ3o
# 4  spotify:track:2QUrwP0t7rWiD8Beit13h4
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3kjoAqJUsLs8...
# 1  https://api.spotify.com/v1/tracks/4NTNiAtUyadC...
# 2  https://api.spotify.com/v1/tracks/1CqNphayCWFk...
# 3  https://api.spotify.com/v1/tracks/0r5JSBykFXME...
# 4  https://api.spotify.com/v1/tracks/2QUrwP0t7rWi...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3kjo...       171880
# 1  https://api.spotify.com/v1/audio-analysis/4NTN...        65200
# 2  https://api.spotify.com/v1/audio-analysis/1CqN...       227520
# 3  https://api.spotify.com/v1/audio-analysis/0r5J...       347440
# 4  https://api.spotify.com/v1/audio-analysis/2QUr...       204067
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
playlist_80s.shape
# Out:
# (20000, 20)

# %% [markdown]
# #### Deleting parameters we don't need

# %%
playlist_80s = playlist_80s.drop(columns = ['key','mode','type','id','uri','track_href','analysis_url','duration_ms','time_signature'])

# %%
playlist_80s
# Out:
#                              title       artist  danceability  energy  \
# 0                   Opening - Live  Duran Duran         0.307   0.153
# 1                     Intro - Live  Duran Duran         0.478   0.561
# 2               Medazzaland - Live  Duran Duran         0.501   0.927
# 3       Big Bang Generation - Live  Duran Duran         0.542   0.902
# 4      Hungry Like the Wolf - Live  Duran Duran         0.574   0.932
# ...                            ...          ...           ...     ...
# 19995              Never Surrender   Corey Hart         0.550   0.543
# 19996    Sunny Place, Shady People   Corey Hart         0.645   0.610
# 19997                Eurasian Eyes   Corey Hart         0.599   0.455
# 19998       Everything in My Heart   Corey Hart         0.456   0.550
# 19999               Silent Talking   Corey Hart         0.549   0.800
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0       -25.952       0.0443       0.88300          0.971000     0.840
# 1       -14.545       0.0754       0.12100          0.011400     0.881
# 2        -6.744       0.0690       0.05550          0.047700     0.701
# 3        -6.028       0.1040       0.00157          0.012100     0.697
# 4        -5.841       0.0711       0.03380          0.000009     0.717
# ...         ...          ...           ...               ...       ...
# 19995   -11.067       0.0333       0.50100          0.000000     0.206
# 19996   -12.163       0.0556       0.10500          0.000000     0.413
# 19997   -11.865       0.0288       0.11300          0.000000     0.142
# 19998   -10.303       0.0367       0.44600          0.000000     0.150
# 19999    -9.823       0.0899       0.06420          0.000000     0.192
#
#        valence    tempo
# 0        0.130   79.853
# 1        0.257  118.898
# 2        0.537  118.744
# 3        0.245   99.944
# 4        0.665  128.864
# ...        ...      ...
# 19995    0.434  104.126
# 19996    0.846  120.043
# 19997    0.367  110.043
# 19998    0.594  159.935
# 19999    0.506  139.706
#
# [20000 rows x 11 columns]

# %%
playlist_80s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             20000 non-null  object
#  1   artist            20000 non-null  object
#  2   danceability      20000 non-null  float64
#  3   energy            20000 non-null  float64
#  4   loudness          20000 non-null  float64
#  5   speechiness       20000 non-null  float64
#  6   acousticness      20000 non-null  float64
#  7   instrumentalness  20000 non-null  float64
#  8   liveness          20000 non-null  float64
#  9   valence           20000 non-null  float64
#  10  tempo             20000 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Get numeric data

# %%
X = playlist_80s._get_numeric_data()

# %%
X.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.307   0.153   -25.952       0.0443       0.88300
# 1         0.478   0.561   -14.545       0.0754       0.12100
# 2         0.501   0.927    -6.744       0.0690       0.05550
# 3         0.542   0.902    -6.028       0.1040       0.00157
# 4         0.574   0.932    -5.841       0.0711       0.03380
#
#    instrumentalness  liveness  valence    tempo
# 0          0.971000     0.840    0.130   79.853
# 1          0.011400     0.881    0.257  118.898
# 2          0.047700     0.701    0.537  118.744
# 3          0.012100     0.697    0.245   99.944
# 4          0.000009     0.717    0.665  128.864

# %% [markdown]
# - Looking for null values

# %%
X.isnull().sum()
# Out:
# danceability        0
# energy              0
# loudness            0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# dtype: int64

# %%
X.hist(figsize=(10,10));

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scale your data with the standard scaler
X_prep = StandardScaler().fit_transform(X)

# %%
X_prep
# Out:
# array([[-1.4699512 , -2.33656595, -4.03366484, ...,  1.90879394,
#         -1.60827177, -1.57000719],
#        [-0.44195875, -0.50710896, -1.32515775, ...,  2.05251399,
#         -1.10238118, -0.11490159],
#        [-0.30369076,  1.13402157,  0.52713153, ...,  1.42154791,
#          0.01296815, -0.12064077],
#        ...,
#        [ 0.28545111, -0.98240906, -0.68881174, ..., -0.53795232,
#         -0.66420823, -0.44490441],
#        [-0.57421509, -0.55643256, -0.31792648, ..., -0.50990939,
#          0.2400214 ,  1.41444066],
#        [-0.01513148,  0.56455825, -0.20395406, ..., -0.36268397,
#         -0.11051696,  0.66055844]])

# %%
X.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo'],
#       dtype='object')

# %%
X_prep_df = pd.DataFrame(X_prep, columns=X.columns)

X_prep_df.head()
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -1.469951 -2.336566 -4.033665    -0.257123      2.567964
# 1     -0.441959 -0.507109 -1.325158    -0.056428     -0.349151
# 2     -0.303691  1.134022  0.527132    -0.097729     -0.599900
# 3     -0.057213  1.021922  0.697140     0.128133     -0.806357
# 4      0.135160  1.156441  0.741542    -0.084177     -0.682973
#
#    instrumentalness  liveness   valence     tempo
# 0          4.170001  1.908794 -1.608272 -1.570007
# 1         -0.335227  2.052514 -1.102381 -0.114902
# 2         -0.164802  1.421548  0.012968 -0.120641
# 3         -0.331940  1.407526 -1.150182 -0.821268
# 4         -0.388705  1.477634  0.522842  0.256505

# %%
X_prep_df.hist(figsize=(10,10));

# %% [markdown]
# ### KMEANS

# %%
from sklearn.cluster import KMeans

#define the model, fit the model to your data 

kmeans = KMeans(n_clusters=8, random_state=40)
kmeans.fit(X_prep)
# Out:
# KMeans(random_state=40)

# %%
#look at the cluster centres 
kmeans.cluster_centers_
# Out:
# array([[ 1.35860872e-02,  1.16252316e-01, -2.47733088e-01,
#         -1.79399450e-01, -2.53949704e-01,  3.04716409e+00,
#         -1.28939461e-01, -3.68909112e-02, -1.78041019e-02],
#        [-7.18381064e-01,  3.83064094e-01,  3.72157170e-01,
#         -1.01942347e-01, -3.76863527e-01, -2.86783249e-01,
#         -3.35008063e-01,  1.37696785e-02,  1.41747457e+00],
#        [-7.63544728e-01,  7.08847445e-01,  4.08610820e-01,
#         -4.03345387e-03, -3.32720347e-01, -2.20309369e-01,
#          1.97350560e+00, -5.34855722e-01,  8.32147605e-02],
#        [-7.50766718e-01, -1.64930381e+00, -1.08679155e+00,
#         -2.80904387e-01,  1.94880717e+00,  1.30716368e-01,
#         -1.71733932e-01, -1.10195709e+00, -2.64348120e-01],
#        [ 9.77189499e-01, -5.51094583e-01, -7.53340767e-01,
#         -1.79756774e-01, -6.22008226e-02, -2.51666255e-01,
#         -4.77755878e-01,  8.00650970e-01, -1.58187665e-01],
#        [ 8.24590659e-01, -1.90401953e+00, -2.44779853e+00,
#          5.39947154e+00,  1.59877009e+00, -3.81781799e-01,
#         -2.57684011e-01,  1.60322641e-01, -6.54565700e-01],
#        [-2.28758287e-01, -4.01078895e-03,  3.27200200e-01,
#         -2.45086355e-01, -2.48968692e-01, -2.94953153e-01,
#         -3.84995754e-01, -7.30164245e-01, -5.81146383e-01],
#        [ 6.52336936e-01,  6.49984946e-01,  6.52204362e-01,
#         -1.74170474e-01, -4.05737102e-01, -2.81428014e-01,
#         -3.49507015e-01,  8.47306763e-01, -7.06303023e-02]])

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# %%
# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    1386
# 1    2379
# 2    2878
# 3    2114
# 4    2748
# 5     592
# 6    3228
# 7    4675
# dtype: int64

# %%
# Explore the cluster assignment by placing it in the original dataset
X_cluster=pd.DataFrame(X)
X_cluster['cluster']=clusters
X_cluster.head(30)
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.307   0.153   -25.952       0.0443      0.883000
# 1          0.478   0.561   -14.545       0.0754      0.121000
# 2          0.501   0.927    -6.744       0.0690      0.055500
# 3          0.542   0.902    -6.028       0.1040      0.001570
# 4          0.574   0.932    -5.841       0.0711      0.033800
# 5          0.281   0.578    -5.872       0.0306      0.024000
# 6          0.494   0.837    -5.354       0.0434      0.005130
# 7          0.550   0.698    -5.881       0.0580      0.027100
# 8          0.505   0.701    -7.299       0.0392      0.041900
# 9          0.534   0.689    -6.674       0.0267      0.031800
# 10         0.508   0.733    -6.379       0.0392      0.007300
# 11         0.619   0.744    -9.003       0.0249      0.011300
# 12         0.404   0.778    -6.368       0.0464      0.129000
# 13         0.470   0.857    -6.254       0.0632      0.015100
# 14         0.436   0.895    -5.157       0.0768      0.036600
# 15         0.436   0.939    -5.556       0.0742      0.026000
# 16         0.542   0.445    -9.158       0.0260      0.027900
# 17         0.446   0.709    -6.477       0.0328      0.048000
# 18         0.428   0.955    -5.901       0.1900      0.014800
# 19         0.646   0.488   -11.389       0.0311      0.000148
# 20         0.599   0.694    -7.095       0.0275      0.000518
# 21         0.578   0.638    -7.155       0.0286      0.002180
# 22         0.733   0.876    -4.560       0.0385      0.004520
# 23         0.652   0.726    -6.126       0.0598      0.000576
# 24         0.770   0.494    -8.635       0.0730      0.002310
# 25         0.441   0.662    -5.040       0.0271      0.016100
# 26         0.625   0.889    -4.922       0.0436      0.010100
# 27         0.656   0.641    -6.581       0.0289      0.000235
# 28         0.731   0.815    -4.934       0.0443      0.000583
# 29         0.611   0.649    -6.914       0.0596      0.006380
#
#     instrumentalness  liveness  valence    tempo  cluster
# 0           0.971000    0.8400   0.1300   79.853        3
# 1           0.011400    0.8810   0.2570  118.898        2
# 2           0.047700    0.7010   0.5370  118.744        2
# 3           0.012100    0.6970   0.2450   99.944        2
# 4           0.000009    0.7170   0.6650  128.864        2
# 5           0.000009    0.6990   0.1770  129.021        2
# 6           0.016200    0.8200   0.5150  128.941        2
# 7           0.000030    0.7760   0.3370  124.775        2
# 8           0.000660    0.9890   0.3310   86.012        2
# 9           0.000002    0.8150   0.3770  113.644        2
# 10          0.000036    0.7790   0.3990   96.011        2
# 11          0.058000    0.9460   0.3350   99.949        2
# 12          0.000060    0.6920   0.3760  173.892        1
# 13          0.002760    0.7710   0.3850  138.235        2
# 14          0.000042    0.7950   0.3500  126.232        2
# 15          0.029900    0.9790   0.7110  161.792        2
# 16          0.000002    0.7280   0.1780  120.631        2
# 17          0.000047    0.5610   0.3340  139.807        2
# 18          0.000185    0.7620   0.2970  140.926        2
# 19          0.001560    0.1050   0.1420  114.973        6
# 20          0.000174    0.3220   0.2050  121.925        6
# 21          0.000181    0.1570   0.3850  160.043        1
# 22          0.000004    0.9160   0.6300  112.981        2
# 23          0.001710    0.0943   0.6240  120.022        7
# 24          0.000001    0.3390   0.6700  124.023        4
# 25          0.000002    0.0480   0.0936   82.468        6
# 26          0.000000    0.2700   0.6080  126.996        7
# 27          0.000058    0.0561   0.5960  124.961        7
# 28          0.000245    0.1410   0.6300  116.002        7
# 29          0.007800    0.0891   0.2260  111.913        6

# %%
#X_cluster.shape

# %%
# checking total inertia of all the centroids:

kmeans.inertia_
# Out:
# 74080.59293514094

# %%
#changing parameters to look for the lowest inertia

# %%
# Try to run Kmeans with all values of K, from 55 to 65 (we have tested before 25-45 , 35-45, 45-55 ...)
K = range(55, 65)

# For each model, store the inertia in a list
inertia = []

for k in K:
    kmeans=KMeans(n_clusters=k, random_state=40)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)
    
print(inertia)
# Out:
# [36776.18599965236, 36484.69107569195, 36379.67296049524, 36188.099839655326, 35911.6476402222, 35773.73902528863, 35633.6058513546, 35379.42387249509, 35154.83948704639, 35021.20694905032]

# %%
# Plot the results: Elbow method
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# Silhouette method
from sklearn.metrics import silhouette_score

K = range(55, 65)

silhouettes = []

for k in K: 
    kmeans=KMeans(n_clusters=k, random_state=40)
    kmeans.fit(X_prep)
    silhouettes.append(silhouette_score(X_prep, kmeans.predict(X_prep)))

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(16,8))
plt.plot(K, silhouettes, 'bo-')
plt.xlabel('k (number of clusters)')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.ylabel('silhouette score')
# Out:
# Text(0, 0.5, 'silhouette score')

# %% [markdown]
# - Comparing Elbow method and Silhouette and considering we got 20.000 songs, we decide to chooose **k=63**

# %%
kmeans = KMeans(n_clusters=63,
                init="random",
                n_init=10,  
                max_iter=200,
                tol=0,
                algorithm="full",
                random_state=40)
kmeans.fit(X_prep)
print(kmeans.inertia_)
# Out:
# 35274.84114997015

# %%
clusters = kmeans.predict(X_prep)

# %%
# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     417
# 1     184
# 2     328
# 3     812
# 4     255
#      ...
# 58    327
# 59    177
# 60    329
# 61    370
# 62    153
# Length: 63, dtype: int64

# %%
kmeans
# Out:
# KMeans(algorithm='full', init='random', max_iter=200, n_clusters=63,
#        random_state=40, tol=0)

# %%
cluster_list = kmeans.predict(X_prep)

# %%
X_prep_df
# Out:
#        danceability    energy  loudness  speechiness  acousticness  \
# 0         -1.469951 -2.336566 -4.033665    -0.257123      2.567964
# 1         -0.441959 -0.507109 -1.325158    -0.056428     -0.349151
# 2         -0.303691  1.134022  0.527132    -0.097729     -0.599900
# 3         -0.057213  1.021922  0.697140     0.128133     -0.806357
# 4          0.135160  1.156441  0.741542    -0.084177     -0.682973
# ...             ...       ...       ...          ...           ...
# 19995     -0.009120 -0.587820 -0.499333    -0.328109      1.105578
# 19996      0.561987 -0.287395 -0.759570    -0.184202     -0.410403
# 19997      0.285451 -0.982409 -0.688812    -0.357148     -0.379777
# 19998     -0.574215 -0.556433 -0.317926    -0.306168      0.895025
# 19999     -0.015131  0.564558 -0.203954     0.037143     -0.566595
#
#        instrumentalness  liveness   valence     tempo
# 0              4.170001  1.908794 -1.608272 -1.570007
# 1             -0.335227  2.052514 -1.102381 -0.114902
# 2             -0.164802  1.421548  0.012968 -0.120641
# 3             -0.331940  1.407526 -1.150182 -0.821268
# 4             -0.388705  1.477634  0.522842  0.256505
# ...                 ...       ...       ...       ...
# 19995         -0.388749 -0.313609 -0.397321 -0.665416
# 19996         -0.388749  0.412002  1.243836 -0.072230
# 19997         -0.388749 -0.537952 -0.664208 -0.444904
# 19998         -0.388749 -0.509909  0.240021  1.414441
# 19999         -0.388749 -0.362684 -0.110517  0.660558
#
# [20000 rows x 9 columns]

# %%
X_prep_df['cluster'] = cluster_list.tolist()

# %%
X_prep_df
# Out:
#        danceability    energy  loudness  speechiness  acousticness  \
# 0         -1.469951 -2.336566 -4.033665    -0.257123      2.567964
# 1         -0.441959 -0.507109 -1.325158    -0.056428     -0.349151
# 2         -0.303691  1.134022  0.527132    -0.097729     -0.599900
# 3         -0.057213  1.021922  0.697140     0.128133     -0.806357
# 4          0.135160  1.156441  0.741542    -0.084177     -0.682973
# ...             ...       ...       ...          ...           ...
# 19995     -0.009120 -0.587820 -0.499333    -0.328109      1.105578
# 19996      0.561987 -0.287395 -0.759570    -0.184202     -0.410403
# 19997      0.285451 -0.982409 -0.688812    -0.357148     -0.379777
# 19998     -0.574215 -0.556433 -0.317926    -0.306168      0.895025
# 19999     -0.015131  0.564558 -0.203954     0.037143     -0.566595
#
#        instrumentalness  liveness   valence     tempo  cluster
# 0              4.170001  1.908794 -1.608272 -1.570007       42
# 1             -0.335227  2.052514 -1.102381 -0.114902        1
# 2             -0.164802  1.421548  0.012968 -0.120641       24
# 3             -0.331940  1.407526 -1.150182 -0.821268       41
# 4             -0.388705  1.477634  0.522842  0.256505       40
# ...                 ...       ...       ...       ...      ...
# 19995         -0.388749 -0.313609 -0.397321 -0.665416       39
# 19996         -0.388749  0.412002  1.243836 -0.072230        0
# 19997         -0.388749 -0.537952 -0.664208 -0.444904       16
# 19998         -0.388749 -0.509909  0.240021  1.414441       21
# 19999         -0.388749 -0.362684 -0.110517  0.660558       38
#
# [20000 rows x 10 columns]

# %%
playlist_80s
# Out:
#                              title       artist  danceability  energy  \
# 0                   Opening - Live  Duran Duran         0.307   0.153
# 1                     Intro - Live  Duran Duran         0.478   0.561
# 2               Medazzaland - Live  Duran Duran         0.501   0.927
# 3       Big Bang Generation - Live  Duran Duran         0.542   0.902
# 4      Hungry Like the Wolf - Live  Duran Duran         0.574   0.932
# ...                            ...          ...           ...     ...
# 19995              Never Surrender   Corey Hart         0.550   0.543
# 19996    Sunny Place, Shady People   Corey Hart         0.645   0.610
# 19997                Eurasian Eyes   Corey Hart         0.599   0.455
# 19998       Everything in My Heart   Corey Hart         0.456   0.550
# 19999               Silent Talking   Corey Hart         0.549   0.800
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0       -25.952       0.0443       0.88300          0.971000     0.840
# 1       -14.545       0.0754       0.12100          0.011400     0.881
# 2        -6.744       0.0690       0.05550          0.047700     0.701
# 3        -6.028       0.1040       0.00157          0.012100     0.697
# 4        -5.841       0.0711       0.03380          0.000009     0.717
# ...         ...          ...           ...               ...       ...
# 19995   -11.067       0.0333       0.50100          0.000000     0.206
# 19996   -12.163       0.0556       0.10500          0.000000     0.413
# 19997   -11.865       0.0288       0.11300          0.000000     0.142
# 19998   -10.303       0.0367       0.44600          0.000000     0.150
# 19999    -9.823       0.0899       0.06420          0.000000     0.192
#
#        valence    tempo
# 0        0.130   79.853
# 1        0.257  118.898
# 2        0.537  118.744
# 3        0.245   99.944
# 4        0.665  128.864
# ...        ...      ...
# 19995    0.434  104.126
# 19996    0.846  120.043
# 19997    0.367  110.043
# 19998    0.594  159.935
# 19999    0.506  139.706
#
# [20000 rows x 11 columns]

# %%
df1 = playlist_80s[['title', 'artist']]

# %%
df1
# Out:
#                              title       artist
# 0                   Opening - Live  Duran Duran
# 1                     Intro - Live  Duran Duran
# 2               Medazzaland - Live  Duran Duran
# 3       Big Bang Generation - Live  Duran Duran
# 4      Hungry Like the Wolf - Live  Duran Duran
# ...                            ...          ...
# 19995              Never Surrender   Corey Hart
# 19996    Sunny Place, Shady People   Corey Hart
# 19997                Eurasian Eyes   Corey Hart
# 19998       Everything in My Heart   Corey Hart
# 19999               Silent Talking   Corey Hart
#
# [20000 rows x 2 columns]

# %%
playlist_80s_clust = pd.concat([playlist_80s[['title', 'artist']], X_prep_df], axis=1)

# %%
playlist_80s_clust
# Out:
#                              title       artist  danceability    energy  \
# 0                   Opening - Live  Duran Duran     -1.469951 -2.336566
# 1                     Intro - Live  Duran Duran     -0.441959 -0.507109
# 2               Medazzaland - Live  Duran Duran     -0.303691  1.134022
# 3       Big Bang Generation - Live  Duran Duran     -0.057213  1.021922
# 4      Hungry Like the Wolf - Live  Duran Duran      0.135160  1.156441
# ...                            ...          ...           ...       ...
# 19995              Never Surrender   Corey Hart     -0.009120 -0.587820
# 19996    Sunny Place, Shady People   Corey Hart      0.561987 -0.287395
# 19997                Eurasian Eyes   Corey Hart      0.285451 -0.982409
# 19998       Everything in My Heart   Corey Hart     -0.574215 -0.556433
# 19999               Silent Talking   Corey Hart     -0.015131  0.564558
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 0     -4.033665    -0.257123      2.567964          4.170001  1.908794
# 1     -1.325158    -0.056428     -0.349151         -0.335227  2.052514
# 2      0.527132    -0.097729     -0.599900         -0.164802  1.421548
# 3      0.697140     0.128133     -0.806357         -0.331940  1.407526
# 4      0.741542    -0.084177     -0.682973         -0.388705  1.477634
# ...         ...          ...           ...               ...       ...
# 19995 -0.499333    -0.328109      1.105578         -0.388749 -0.313609
# 19996 -0.759570    -0.184202     -0.410403         -0.388749  0.412002
# 19997 -0.688812    -0.357148     -0.379777         -0.388749 -0.537952
# 19998 -0.317926    -0.306168      0.895025         -0.388749 -0.509909
# 19999 -0.203954     0.037143     -0.566595         -0.388749 -0.362684
#
#         valence     tempo  cluster
# 0     -1.608272 -1.570007       42
# 1     -1.102381 -0.114902        1
# 2      0.012968 -0.120641       24
# 3     -1.150182 -0.821268       41
# 4      0.522842  0.256505       40
# ...         ...       ...      ...
# 19995 -0.397321 -0.665416       39
# 19996  1.243836 -0.072230        0
# 19997 -0.664208 -0.444904       16
# 19998  0.240021  1.414441       21
# 19999 -0.110517  0.660558       38
#
# [20000 rows x 12 columns]

# %%
playlist_80s_clust.to_csv('clustered_80s_playlist.csv')

# %%
# results = sp.search(q='Sunrise', limit=50)
